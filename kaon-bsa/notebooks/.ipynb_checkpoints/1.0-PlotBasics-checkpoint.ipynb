# %%
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd 

# %matplotlib inline

# %%
data = pd.read_csv('../database/phi/sys.csv')

# %%
data.head()
# Out:
#   axis  axis_bin  axis_max  axis_min  counts_neg  counts_pos    phi  phi_bin  \
# 0    x         0   0.17558  0.106815       16611       16653 -165.0        0
# 1    x         0   0.17558  0.106815        7833        7840 -135.0        1
# 2    x         0   0.17558  0.106815       12951       12955 -105.0        2
# 3    x         0   0.17558  0.106815        6837        6667  -75.0        3
# 4    x         0   0.17558  0.106815        6935        6596  -45.0        4
#
#        stat     sys_0    ...        sys_13         sys_2     sys_3     sys_4  \
# 0  0.005483  0.000040    ...     -0.000900  4.416914e-05  0.002196  0.003643
# 1  0.007988  0.000014    ...      0.004054  1.108870e-03  0.003387  0.000581
# 2  0.006213  0.000005    ...     -0.001134  9.946962e-08  0.000060 -0.002725
# 3  0.008604  0.000403    ...     -0.000904  2.408102e-04 -0.001130  0.002724
# 4  0.008592  0.000803    ...      0.009064 -5.599894e-04 -0.003815  0.002246
#
#       sys_5     sys_6     sys_7     sys_8     sys_9  sys_total
# 0 -0.001026  0.000238 -0.002564 -0.004903 -0.000680   0.007152
# 1 -0.001529 -0.003651  0.000619 -0.003745 -0.004333   0.011670
# 2  0.000747 -0.001487  0.003337 -0.006620 -0.002821   0.010893
# 3  0.006140 -0.001052 -0.003147  0.001425  0.006519   0.010711
# 4 -0.008326 -0.004002 -0.004750 -0.005517 -0.000458   0.017021
#
# [5 rows x 26 columns]

# %%
font_settings = {'size' : 18}
text_settings = {'usetex' : True}
plt.rc('font', **font_settings)
plt.rc('text', **text_settings)

# %%
def plot_simple_asym(data, axis, bin):
    
    d = data.query('axis == "{}" and axis_bin == {}'.format(
            axis, bin)
        )
        
    plt.errorbar(
        d['phi'], d['value'], d['stat'],
        linestyle='', marker='o', color = 'k')
    
    plt.axhline(0, linestyle='--', alpha=0.8, 
        linewidth=0.5, color='k')
        
    plt.ylim([-0.08, 0.08])

# %%
plt.figure(figsize=(8,6))
plot_simple_asym(data, 'x', 2)
