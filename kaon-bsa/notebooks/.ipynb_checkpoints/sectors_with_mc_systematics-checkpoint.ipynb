# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import glob
import os
import sys

# %matplotlib inline

# %%
os.listdir('../database/phi/random')
# Out:
# ['systematics_4.csv',
#  'sector_6_87.csv',
#  'sector_6_93.csv',
#  'sector_1_71.csv',
#  'sector_6_78.csv',
#  'sector_1_6.csv',
#  'sector_1_65.csv',
#  'sector_6_44.csv',
#  'sector_4_110.csv',
#  'sector_4_104.csv',
#  'sector_6_50.csv',
#  'sector_1_59.csv',
#  'sector_5_15.csv',
#  'sector_3_4.csv',
#  'sector_2_20.csv',
#  'sector_5_101.csv',
#  'sector_5_29.csv',
#  'sector_2_34.csv',
#  'sector_5_115.csv',
#  'sector_5_2.csv',
#  'sector_4_82.csv',
#  'sector_4_96.csv',
#  'sector_1_109.csv',
#  'sector_3_74.csv',
#  'sector_3_60.csv',
#  'sector_4_69.csv',
#  'sector_4_41.csv',
#  'sector_3_48.csv',
#  'sector_4_55.csv',
#  'sector_1_121.csv',
#  'sector_1_120.csv',
#  'sector_4_54.csv',
#  'sector_4_40.csv',
#  'sector_3_49.csv',
#  'sector_3_61.csv',
#  'sector_4_68.csv',
#  'sector_1_108.csv',
#  'sector_3_75.csv',
#  'sector_4_97.csv',
#  'sector_4_83.csv',
#  'sector_5_3.csv',
#  'sector_5_114.csv',
#  'sector_2_35.csv',
#  'sector_5_100.csv',
#  'sector_2_21.csv',
#  'sector_5_28.csv',
#  'sector_3_5.csv',
#  'sector_5_14.csv',
#  'sector_6_51.csv',
#  'sector_4_105.csv',
#  'sector_1_58.csv',
#  'sector_4_111.csv',
#  'sector_6_45.csv',
#  'sector_1_7.csv',
#  'sector_1_64.csv',
#  'sector_1_70.csv',
#  'sector_6_79.csv',
#  'sector_6_92.csv',
#  'sector_6_86.csv',
#  'systematics_5.csv',
#  'sector_1_99.csv',
#  'sector_6_90.csv',
#  'sector_6_84.csv',
#  'sector_1_66.csv',
#  'sector_1_5.csv',
#  'sector_1_72.csv',
#  'sector_4_107.csv',
#  'sector_6_53.csv',
#  'sector_6_47.csv',
#  'sector_4_113.csv',
#  'sector_3_7.csv',
#  'sector_5_16.csv',
#  'sector_2_37.csv',
#  'sector_5_116.csv',
#  'sector_2_23.csv',
#  'sector_5_102.csv',
#  'sector_5_1.csv',
#  'sector_4_95.csv',
#  'sector_3_88.csv',
#  'sector_4_81.csv',
#  'sector_3_63.csv',
#  'sector_3_77.csv',
#  'sector_4_56.csv',
#  'sector_1_122.csv',
#  'sector_4_42.csv',
#  'sector_4_43.csv',
#  'sector_1_123.csv',
#  'sector_4_57.csv',
#  'sector_3_76.csv',
#  'sector_3_62.csv',
#  'sector_3_89.csv',
#  'sector_4_80.csv',
#  'sector_4_94.csv',
#  'sector_5_0.csv',
#  'sector_5_103.csv',
#  'sector_2_22.csv',
#  'sector_5_117.csv',
#  'sector_2_36.csv',
#  'sector_5_17.csv',
#  'sector_3_6.csv',
#  'sector_4_112.csv',
#  'sector_6_46.csv',
#  'sector_6_52.csv',
#  'sector_4_106.csv',
#  'sector_1_73.csv',
#  'sector_1_67.csv',
#  'sector_1_4.csv',
#  'sector_6_85.csv',
#  'systematics_6.csv',
#  'sector_1_98.csv',
#  'sector_6_91.csv',
#  'sector_6_95.csv',
#  'sector_1_88.csv',
#  'systematics_2.csv',
#  'sector_6_81.csv',
#  'sector_4_102.csv',
#  'sector_6_56.csv',
#  'sector_6_42.csv',
#  'sector_4_116.csv',
#  'sector_1_0.csv',
#  'sector_1_63.csv',
#  'sector_1_77.csv',
#  'sector_2_32.csv',
#  'sector_5_113.csv',
#  'sector_2_26.csv',
#  'sector_5_107.csv',
#  'sector_3_2.csv',
#  'sector_5_13.csv',
#  'sector_5_4.csv',
#  'sector_3_99.csv',
#  'sector_4_90.csv',
#  'sector_4_84.csv',
#  'sector_4_53.csv',
#  'sector_1_127.csv',
#  'sector_4_47.csv',
#  'sector_3_66.csv',
#  'sector_3_72.csv',
#  'sector_3_73.csv',
#  'sector_3_67.csv',
#  'sector_4_46.csv',
#  'sector_1_126.csv',
#  'sector_4_52.csv',
#  'sector_4_85.csv',
#  'sector_3_98.csv',
#  'sector_4_91.csv',
#  'sector_5_5.csv',
#  'sector_5_12.csv',
#  'sector_3_3.csv',
#  'sector_5_106.csv',
#  'sector_2_27.csv',
#  'sector_5_112.csv',
#  'sector_2_33.csv',
#  'sector_1_76.csv',
#  'sector_1_1.csv',
#  'sector_1_62.csv',
#  'sector_4_117.csv',
#  'sector_6_43.csv',
#  'sector_6_57.csv',
#  'sector_4_103.csv',
#  'sector_1_89.csv',
#  'sector_6_80.csv',
#  'systematics_3.csv',
#  'sector_6_94.csv',
#  'systematics_1.csv',
#  'sector_6_82.csv',
#  'sector_6_96.csv',
#  'sector_6_41.csv',
#  'sector_4_115.csv',
#  'sector_1_48.csv',
#  'sector_4_101.csv',
#  'sector_6_55.csv',
#  'sector_1_74.csv',
#  'sector_1_60.csv',
#  'sector_6_69.csv',
#  'sector_1_3.csv',
#  'sector_2_25.csv',
#  'sector_5_104.csv',
#  'sector_2_31.csv',
#  'sector_5_110.csv',
#  'sector_5_38.csv',
#  'sector_5_10.csv',
#  'sector_2_19.csv',
#  'sector_3_1.csv',
#  'sector_5_7.csv',
#  'sector_4_87.csv',
#  'sector_4_93.csv',
#  'sector_4_44.csv',
#  'sector_4_50.csv',
#  'sector_1_124.csv',
#  'sector_3_59.csv',
#  'sector_3_71.csv',
#  'sector_4_78.csv',
#  'sector_1_118.csv',
#  'sector_3_65.csv',
#  'sector_1_119.csv',
#  'sector_3_64.csv',
#  'sector_3_70.csv',
#  'sector_4_79.csv',
#  'sector_1_125.csv',
#  'sector_4_51.csv',
#  'sector_3_58.csv',
#  'sector_4_45.csv',
#  'sector_4_92.csv',
#  'sector_4_86.csv',
#  'sector_5_6.csv',
#  'sector_3_0.csv',
#  'sector_5_11.csv',
#  'sector_2_18.csv',
#  'sector_5_111.csv',
#  'sector_2_30.csv',
#  'sector_5_39.csv',
#  'sector_5_105.csv',
#  'sector_2_24.csv',
#  'sector_1_61.csv',
#  'sector_6_68.csv',
#  'sector_1_2.csv',
#  'sector_1_75.csv',
#  'sector_6_54.csv',
#  'sector_4_100.csv',
#  'sector_4_114.csv',
#  'sector_6_40.csv',
#  'sector_1_49.csv',
#  'sector_6_97.csv',
#  'sector_6_83.csv',
#  'sector_2_122.csv',
#  'sector_1_12.csv',
#  'sector_6_3.csv',
#  'sector_6_27.csv',
#  'sector_6_33.csv',
#  'sector_5_89.csv',
#  'sector_2_80.csv',
#  'sector_2_94.csv',
#  'sector_3_127.csv',
#  'sector_5_76.csv',
#  'sector_5_62.csv',
#  'sector_4_1.csv',
#  'sector_2_43.csv',
#  'sector_2_57.csv',
#  'sector_6_116.csv',
#  'sector_6_102.csv',
#  'sector_2_7.csv',
#  'sector_3_17.csv',
#  'sector_4_22.csv',
#  'sector_4_36.csv',
#  'sector_4_37.csv',
#  'sector_4_23.csv',
#  'sector_3_16.csv',
#  'sector_2_6.csv',
#  'sector_6_103.csv',
#  'sector_6_117.csv',
#  'sector_2_56.csv',
#  'sector_2_42.csv',
#  'sector_4_0.csv',
#  'sector_5_63.csv',
#  'sector_5_77.csv',
#  'sector_2_95.csv',
#  'sector_3_126.csv',
#  'sector_5_88.csv',
#  'sector_2_81.csv',
#  'sector_6_32.csv',
#  'sector_6_26.csv',
#  'sector_6_2.csv',
#  'sector_1_13.csv',
#  'sector_2_123.csv',
#  'sector_2_109.csv',
#  'sector_2_121.csv',
#  'sector_6_0.csv',
#  'sector_1_11.csv',
#  'sector_6_18.csv',
#  'sector_6_30.csv',
#  'sector_1_39.csv',
#  'sector_6_24.csv',
#  'sector_3_118.csv',
#  'sector_3_124.csv',
#  'sector_2_97.csv',
#  'sector_2_83.csv',
#  'sector_5_61.csv',
#  'sector_4_2.csv',
#  'sector_2_68.csv',
#  'sector_5_75.csv',
#  'sector_2_54.csv',
#  'sector_2_40.csv',
#  'sector_5_49.csv',
#  'sector_6_101.csv',
#  'sector_6_115.csv',
#  'sector_2_4.csv',
#  'sector_3_14.csv',
#  'sector_4_35.csv',
#  'sector_4_21.csv',
#  'sector_3_28.csv',
#  'sector_4_20.csv',
#  'sector_3_29.csv',
#  'sector_4_34.csv',
#  'sector_3_15.csv',
#  'sector_2_5.csv',
#  'sector_6_114.csv',
#  'sector_6_100.csv',
#  'sector_2_41.csv',
#  'sector_5_48.csv',
#  'sector_2_55.csv',
#  'sector_5_74.csv',
#  'sector_4_3.csv',
#  'sector_5_60.csv',
#  'sector_2_69.csv',
#  'sector_2_82.csv',
#  'sector_3_125.csv',
#  'sector_2_96.csv',
#  'sector_3_119.csv',
#  'sector_6_25.csv',
#  'sector_6_31.csv',
#  'sector_1_38.csv',
#  'sector_1_10.csv',
#  'sector_6_19.csv',
#  'sector_6_1.csv',
#  'sector_2_120.csv',
#  'sector_2_108.csv',
#  'sector_2_124.csv',
#  'sector_2_118.csv',
#  'sector_6_35.csv',
#  'sector_6_21.csv',
#  'sector_1_28.csv',
#  'sector_6_5.csv',
#  'sector_1_14.csv',
#  'sector_2_92.csv',
#  'sector_3_121.csv',
#  'sector_2_86.csv',
#  'sector_3_109.csv',
#  'sector_2_51.csv',
#  'sector_5_58.csv',
#  'sector_2_45.csv',
#  'sector_5_64.csv',
#  'sector_4_7.csv',
#  'sector_5_70.csv',
#  'sector_2_79.csv',
#  'sector_6_104.csv',
#  'sector_6_110.csv',
#  'sector_2_1.csv',
#  'sector_4_30.csv',
#  'sector_3_39.csv',
#  'sector_4_24.csv',
#  'sector_3_11.csv',
#  'sector_4_18.csv',
#  'sector_3_10.csv',
#  'sector_4_19.csv',
#  'sector_4_25.csv',
#  'sector_4_31.csv',
#  'sector_3_38.csv',
#  'sector_2_0.csv',
#  'sector_6_111.csv',
#  'sector_6_105.csv',
#  'sector_5_71.csv',
#  'sector_2_78.csv',
#  'sector_4_6.csv',
#  'sector_5_65.csv',
#  'sector_2_44.csv',
#  'sector_2_50.csv',
#  'sector_5_59.csv',
#  'sector_3_108.csv',
#  'sector_2_87.csv',
#  'sector_2_93.csv',
#  'sector_3_120.csv',
#  'sector_1_15.csv',
#  'sector_6_4.csv',
#  'sector_6_20.csv',
#  'sector_1_29.csv',
#  'sector_6_34.csv',
#  'sector_2_119.csv',
#  'sector_2_125.csv',
#  'sector_2_127.csv',
#  'sector_6_22.csv',
#  'sector_6_36.csv',
#  'sector_1_17.csv',
#  'sector_6_6.csv',
#  'sector_2_85.csv',
#  'sector_3_122.csv',
#  'sector_5_98.csv',
#  'sector_2_91.csv',
#  'sector_2_46.csv',
#  'sector_2_52.csv',
#  'sector_5_73.csv',
#  'sector_5_67.csv',
#  'sector_4_4.csv',
#  'sector_6_113.csv',
#  'sector_6_107.csv',
#  'sector_2_2.csv',
#  'sector_4_27.csv',
#  'sector_4_33.csv',
#  'sector_3_12.csv',
#  'sector_3_13.csv',
#  'sector_4_32.csv',
#  'sector_4_26.csv',
#  'sector_2_3.csv',
#  'sector_6_106.csv',
#  'sector_6_112.csv',
#  'sector_4_5.csv',
#  'sector_5_66.csv',
#  'sector_5_72.csv',
#  'sector_2_53.csv',
#  'sector_2_47.csv',
#  'sector_5_99.csv',
#  'sector_3_123.csv',
#  'sector_2_90.csv',
#  'sector_2_84.csv',
#  'sector_6_7.csv',
#  'sector_1_16.csv',
#  'sector_6_37.csv',
#  'sector_6_23.csv',
#  'sector_2_126.csv',
#  'sector_2_103.csv',
#  'sector_2_117.csv',
#  'sector_1_33.csv',
#  'sector_1_27.csv',
#  'sector_6_12.csv',
#  'sector_5_94.csv',
#  'sector_2_89.csv',
#  'sector_5_80.csv',
#  'sector_3_112.csv',
#  'sector_3_106.csv',
#  'sector_5_57.csv',
#  'sector_5_43.csv',
#  'sector_4_8.csv',
#  'sector_2_62.csv',
#  'sector_2_76.csv',
#  'sector_6_123.csv',
#  'sector_3_36.csv',
#  'sector_3_22.csv',
#  'sector_4_17.csv',
#  'sector_4_16.csv',
#  'sector_3_23.csv',
#  'sector_3_37.csv',
#  'sector_6_122.csv',
#  'sector_2_77.csv',
#  'sector_4_9.csv',
#  'sector_2_63.csv',
#  'sector_5_42.csv',
#  'sector_5_56.csv',
#  'sector_3_107.csv',
#  'sector_3_113.csv',
#  'sector_2_88.csv',
#  'sector_5_81.csv',
#  'sector_5_95.csv',
#  'sector_6_13.csv',
#  'sector_1_26.csv',
#  'sector_1_32.csv',
#  'sector_2_116.csv',
#  'sector_2_102.csv',
#  'sector_2_114.csv',
#  'sector_2_100.csv',
#  'sector_1_24.csv',
#  'sector_1_30.csv',
#  'sector_6_39.csv',
#  'sector_6_11.csv',
#  'sector_1_18.csv',
#  'sector_6_9.csv',
#  'sector_5_83.csv',
#  'sector_5_97.csv',
#  'sector_3_105.csv',
#  'sector_3_111.csv',
#  'sector_5_40.csv',
#  'sector_2_49.csv',
#  'sector_5_54.csv',
#  'sector_2_75.csv',
#  'sector_2_61.csv',
#  'sector_5_68.csv',
#  'sector_6_108.csv',
#  'sector_6_120.csv',
#  'sector_3_21.csv',
#  'sector_4_28.csv',
#  'sector_3_35.csv',
#  'sector_4_14.csv',
#  'sector_4_15.csv',
#  'sector_3_34.csv',
#  'sector_3_20.csv',
#  'sector_4_29.csv',
#  'sector_6_121.csv',
#  'sector_6_109.csv',
#  'sector_2_60.csv',
#  'sector_5_69.csv',
#  'sector_2_74.csv',
#  'sector_5_55.csv',
#  'sector_5_41.csv',
#  'sector_2_48.csv',
#  'sector_3_110.csv',
#  'sector_3_104.csv',
#  'sector_5_96.csv',
#  'sector_5_82.csv',
#  'sector_6_8.csv',
#  'sector_6_10.csv',
#  'sector_1_19.csv',
#  'sector_1_31.csv',
#  'sector_6_38.csv',
#  'sector_1_25.csv',
#  'sector_2_101.csv',
#  'sector_2_115.csv',
#  'sector_2_111.csv',
#  'sector_2_105.csv',
#  'sector_6_14.csv',
#  'sector_1_21.csv',
#  'sector_6_28.csv',
#  'sector_1_35.csv',
#  'sector_3_100.csv',
#  'sector_3_114.csv',
#  'sector_5_86.csv',
#  'sector_5_92.csv',
#  'sector_2_70.csv',
#  'sector_5_79.csv',
#  'sector_2_64.csv',
#  'sector_5_45.csv',
#  'sector_5_51.csv',
#  'sector_2_58.csv',
#  'sector_6_125.csv',
#  'sector_6_119.csv',
#  'sector_2_8.csv',
#  'sector_4_11.csv',
#  'sector_3_18.csv',
#  'sector_3_24.csv',
#  'sector_3_30.csv',
#  'sector_4_39.csv',
#  'sector_3_31.csv',
#  'sector_4_38.csv',
#  'sector_3_25.csv',
#  'sector_4_10.csv',
#  'sector_3_19.csv',
#  'sector_2_9.csv',
#  'sector_6_118.csv',
#  'sector_6_124.csv',
#  'sector_5_50.csv',
#  'sector_2_59.csv',
#  'sector_5_44.csv',
#  'sector_2_65.csv',
#  'sector_2_71.csv',
#  'sector_5_78.csv',
#  'sector_5_93.csv',
#  'sector_5_87.csv',
#  'sector_3_115.csv',
#  'sector_3_101.csv',
#  'sector_1_34.csv',
#  'sector_1_20.csv',
#  'sector_6_29.csv',
#  'sector_6_15.csv',
#  'sector_2_104.csv',
#  'sector_2_110.csv',
#  'sector_2_106.csv',
#  'sector_2_112.csv',
#  'sector_6_17.csv',
#  'sector_1_36.csv',
#  'sector_1_22.csv',
#  'sector_3_117.csv',
#  'sector_3_103.csv',
#  'sector_2_98.csv',
#  'sector_5_91.csv',
#  'sector_5_85.csv',
#  'sector_2_67.csv',
#  'sector_2_73.csv',
#  'sector_5_52.csv',
#  'sector_5_46.csv',
#  'sector_6_126.csv',
#  'sector_4_12.csv',
#  'sector_3_33.csv',
#  'sector_3_27.csv',
#  'sector_3_26.csv',
#  'sector_3_32.csv',
#  'sector_4_13.csv',
#  'sector_6_127.csv',
#  'sector_5_47.csv',
#  'sector_5_53.csv',
#  'sector_2_72.csv',
#  'sector_2_66.csv',
#  'sector_5_84.csv',
#  'sector_2_99.csv',
#  'sector_5_90.csv',
#  'sector_3_102.csv',
#  'sector_3_116.csv',
#  'sector_1_23.csv',
#  'sector_1_37.csv',
#  'sector_6_16.csv',
#  'sector_2_113.csv',
#  'sector_2_107.csv',
#  'sector_1_93.csv',
#  'sector_1_87.csv',
#  'sector_1_50.csv',
#  'sector_6_59.csv',
#  'sector_4_119.csv',
#  'sector_1_44.csv',
#  'sector_6_65.csv',
#  'sector_6_71.csv',
#  'sector_4_125.csv',
#  'sector_1_78.csv',
#  'sector_5_34.csv',
#  'sector_5_20.csv',
#  'sector_2_29.csv',
#  'sector_5_108.csv',
#  'sector_5_120.csv',
#  'sector_2_15.csv',
#  'sector_3_96.csv',
#  'sector_3_82.csv',
#  'sector_3_55.csv',
#  'sector_3_41.csv',
#  'sector_4_48.csv',
#  'sector_4_60.csv',
#  'sector_1_114.csv',
#  'sector_3_69.csv',
#  'sector_4_74.csv',
#  'sector_1_100.csv',
#  'sector_1_101.csv',
#  'sector_4_75.csv',
#  'sector_1_115.csv',
#  'sector_4_61.csv',
#  'sector_3_68.csv',
#  'sector_3_40.csv',
#  'sector_4_49.csv',
#  'sector_3_54.csv',
#  'sector_3_83.csv',
#  'sector_3_97.csv',
#  'sector_2_14.csv',
#  'sector_5_121.csv',
#  'sector_5_21.csv',
#  'sector_5_109.csv',
#  'sector_2_28.csv',
#  'sector_5_35.csv',
#  'sector_4_124.csv',
#  'sector_6_70.csv',
#  'sector_1_79.csv',
#  'sector_6_64.csv',
#  'sector_4_118.csv',
#  'sector_1_45.csv',
#  'sector_1_51.csv',
#  'sector_6_58.csv',
#  'sector_1_86.csv',
#  'sector_1_92.csv',
#  'sector_1_84.csv',
#  'sector_6_99.csv',
#  'sector_1_90.csv',
#  'sector_1_47.csv',
#  'sector_1_53.csv',
#  'sector_6_72.csv',
#  'sector_4_126.csv',
#  'sector_6_66.csv',
#  'sector_5_23.csv',
#  'sector_5_37.csv',
#  'sector_2_16.csv',
#  'sector_5_123.csv',
#  'sector_5_8.csv',
#  'sector_4_88.csv',
#  'sector_3_81.csv',
#  'sector_3_95.csv',
#  'sector_3_42.csv',
#  'sector_3_56.csv',
#  'sector_4_77.csv',
#  'sector_1_103.csv',
#  'sector_4_63.csv',
#  'sector_1_117.csv',
#  'sector_1_116.csv',
#  'sector_4_62.csv',
#  'sector_1_102.csv',
#  'sector_4_76.csv',
#  'sector_3_57.csv',
#  'sector_3_43.csv',
#  'sector_3_94.csv',
#  'sector_4_89.csv',
#  'sector_3_80.csv',
#  'sector_5_9.csv',
#  'sector_5_122.csv',
#  'sector_2_17.csv',
#  'sector_5_36.csv',
#  'sector_5_22.csv',
#  'sector_6_67.csv',
#  'sector_4_127.csv',
#  'sector_6_73.csv',
#  'sector_1_52.csv',
#  'sector_1_46.csv',
#  'sector_6_98.csv',
#  'sector_1_91.csv',
#  'sector_1_85.csv',
#  'sector_6_88.csv',
#  'sector_1_81.csv',
#  'sector_1_95.csv',
#  'sector_6_77.csv',
#  'sector_4_123.csv',
#  'sector_1_9.csv',
#  'sector_6_63.csv',
#  'sector_1_42.csv',
#  'sector_1_56.csv',
#  'sector_2_13.csv',
#  'sector_5_126.csv',
#  'sector_5_26.csv',
#  'sector_5_32.csv',
#  'sector_3_84.csv',
#  'sector_4_99.csv',
#  'sector_3_90.csv',
#  'sector_4_72.csv',
#  'sector_1_106.csv',
#  'sector_4_66.csv',
#  'sector_1_112.csv',
#  'sector_3_47.csv',
#  'sector_3_53.csv',
#  'sector_3_52.csv',
#  'sector_3_46.csv',
#  'sector_1_113.csv',
#  'sector_4_67.csv',
#  'sector_1_107.csv',
#  'sector_4_73.csv',
#  'sector_4_98.csv',
#  'sector_3_91.csv',
#  'sector_3_85.csv',
#  'sector_5_33.csv',
#  'sector_5_27.csv',
#  'sector_5_127.csv',
#  'sector_2_12.csv',
#  'sector_1_57.csv',
#  'sector_1_43.csv',
#  'sector_1_8.csv',
#  'sector_6_62.csv',
#  'sector_4_122.csv',
#  'sector_6_76.csv',
#  'sector_1_94.csv',
#  'sector_6_89.csv',
#  'sector_1_80.csv',
#  'sector_1_96.csv',
#  'sector_1_82.csv',
#  'sector_6_60.csv',
#  'sector_1_69.csv',
#  'sector_6_74.csv',
#  'sector_4_120.csv',
#  'sector_4_108.csv',
#  'sector_1_55.csv',
#  'sector_1_41.csv',
#  'sector_6_48.csv',
#  'sector_3_8.csv',
#  'sector_5_125.csv',
#  'sector_2_10.csv',
#  'sector_5_19.csv',
#  'sector_5_31.csv',
#  'sector_2_38.csv',
#  'sector_5_119.csv',
#  'sector_5_25.csv',
#  'sector_3_93.csv',
#  'sector_3_87.csv',
#  'sector_4_65.csv',
#  'sector_1_111.csv',
#  'sector_4_71.csv',
#  'sector_1_105.csv',
#  'sector_3_78.csv',
#  'sector_3_50.csv',
#  'sector_4_59.csv',
#  'sector_3_44.csv',
#  'sector_3_45.csv',
#  'sector_3_51.csv',
#  'sector_4_58.csv',
#  'sector_1_104.csv',
#  'sector_4_70.csv',
#  'sector_3_79.csv',
#  'sector_1_110.csv',
#  'sector_4_64.csv',
#  'sector_3_86.csv',
#  'sector_3_92.csv',
#  'sector_5_24.csv',
#  'sector_5_30.csv',
#  'sector_5_118.csv',
#  'sector_2_39.csv',
#  'sector_2_11.csv',
#  'sector_5_18.csv',
#  'sector_5_124.csv',
#  'sector_3_9.csv',
#  'sector_1_40.csv',
#  'sector_6_49.csv',
#  'sector_4_109.csv',
#  'sector_1_54.csv',
#  'sector_4_121.csv',
#  'sector_6_75.csv',
#  'sector_6_61.csv',
#  'sector_1_68.csv',
#  'sector_1_83.csv',
#  'sector_1_97.csv']

# %%
data = {}

for sector in range(1,7):
    data[sector] = []
    
    for f in glob.glob('../database/phi/random/sector_{}_*'.format(sector)):
        data[sector].append(pd.read_csv(f))

# %%
data[1][0]
# Out:
#     axis  axis_min  axis_max  axis_bin  counts_pos  counts_neg     value  \
# 0      x  0.106815  0.178027         0        2659        2716 -0.014158
# 1      x  0.106815  0.178027         0        1357        1328  0.014420
# 2      x  0.106815  0.178027         0        2123        2050  0.023356
# 3      x  0.106815  0.178027         0        1338        1326  0.006014
# 4      x  0.106815  0.178027         0        1173        1292 -0.064454
# ..   ...       ...       ...       ...         ...         ...       ...
# 235   q2  2.320887  4.740613         4        1014         995  0.012627
# 236   q2  2.320887  4.740613         4        1487        1531 -0.019465
# 237   q2  2.320887  4.740613         4        1586        1521  0.027931
# 238   q2  2.320887  4.740613         4        1564        1581 -0.007217
# 239   q2  2.320887  4.740613         4        2425        2472 -0.012814
#
#          stat     sys_0    phi  phi_bin  global_index
# 0    0.013639  0.000340 -165.0        0             0
# 1    0.019297  0.000346 -135.0        1             1
# 2    0.015476  0.000561 -105.0        2             2
# 3    0.019374  0.000144  -75.0        3             3
# 4    0.020100  0.001547  -45.0        4             4
# ..        ...       ...    ...      ...           ...
# 235  0.022309  0.000303   45.0        7            55
# 236  0.018199  0.000467   75.0        8            56
# 237  0.017933  0.000670  105.0        9            57
# 238  0.017831  0.000173  135.0       10            58
# 239  0.014289  0.000308  165.0       11            59
#
# [240 rows x 12 columns]

# %%
data[1][3].head(24)
# Out:
#    axis  axis_min  axis_max  axis_bin  counts_pos  counts_neg     value  \
# 0     x  0.106815  0.178027         0        2428        2484 -0.015221
# 1     x  0.106815  0.178027         0        1219        1204  0.008265
# 2     x  0.106815  0.178027         0        1944        1908  0.012478
# 3     x  0.106815  0.178027         0        1202        1181  0.011766
# 4     x  0.106815  0.178027         0        1070        1204 -0.078674
# 5     x  0.106815  0.178027         0         510         549 -0.049168
# 6     x  0.106815  0.178027         0         530         545 -0.018629
# 7     x  0.106815  0.178027         0        1175        1197 -0.012383
# 8     x  0.106815  0.178027         0        1247        1215  0.017353
# 9     x  0.106815  0.178027         0        2073        1946  0.042189
# 10    x  0.106815  0.178027         0        1267        1226  0.021957
# 11    x  0.106815  0.178027         0        2564        2490  0.019549
# 12    x  0.178027  0.227745         1        2476        2546 -0.018610
# 13    x  0.178027  0.227745         1        1338        1411 -0.035454
# 14    x  0.178027  0.227745         1        1787        1900 -0.040919
# 15    x  0.178027  0.227745         1        1474        1489 -0.006759
# 16    x  0.178027  0.227745         1         966        1052 -0.056898
# 17    x  0.178027  0.227745         1         464         466 -0.002871
# 18    x  0.178027  0.227745         1         460         468 -0.011510
# 19    x  0.178027  0.227745         1        1062         976  0.056339
# 20    x  0.178027  0.227745         1        1424        1364  0.028733
# 21    x  0.178027  0.227745         1        1798        1842 -0.016139
# 22    x  0.178027  0.227745         1        1419        1340  0.038229
# 23    x  0.178027  0.227745         1        2582        2501  0.021276
#
#         stat     sys_0    phi  phi_bin  global_index
# 0   0.014267  0.000365 -165.0        0             0
# 1   0.020315  0.000198 -135.0        1             1
# 2   0.016111  0.000299 -105.0        2             2
# 3   0.020484  0.000282  -75.0        3             3
# 4   0.020905  0.001888  -45.0        4             4
# 5   0.030692  0.001180  -15.0        5             5
# 6   0.030494  0.000447   15.0        6             6
# 7   0.020531  0.000297   45.0        7             7
# 8   0.020151  0.000416   75.0        8             8
# 9   0.015760  0.001013  105.0        9             9
# 10  0.020023  0.000527  135.0       10            10
# 11  0.014064  0.000469  165.0       11            11
# 12  0.014109  0.000447 -165.0        0            12
# 13  0.019061  0.000851 -135.0        1            13
# 14  0.016455  0.000982 -105.0        2            14
# 15  0.018371  0.000162  -75.0        3            15
# 16  0.022225  0.001366  -45.0        4            16
# 17  0.032791  0.000069  -15.0        5            17
# 18  0.032824  0.000276   15.0        6            18
# 19  0.022116  0.001352   45.0        7            19
# 20  0.018931  0.000690   75.0        8            20
# 21  0.016573  0.000387  105.0        9            21
# 22  0.019024  0.000917  135.0       10            22
# 23  0.014023  0.000511  165.0       11            23

# %%
data[1][2]['axis'].unique()
# Out:
# array(['x', 'z', 'pt', 'q2'], dtype=object)

# %%
4 * 5 * 12
# Out:
# 240

# %% [markdown]
# ### This Matrix
# 6 - Number of sectors
# 240 - Number of datapoints per trial (per sector)
# 128 - Number of MC trials

# %%
nsamples = 128
results = np.empty(shape=(6, 240, nsamples))

# %%
for sector in range(1, 7):
    for subfile in range(nsamples):
        results[sector - 1, :, subfile] = data[sector][subfile]['value']

# %%
results.shape
# Out:
# (6, 240, 128)

# %% [markdown]
# ### Exercise 1:
# Calculate the average value over all trials of the 3rd sector and 12th datapoint.

# %%
np.mean(results[2, 12, :]), np.std(results[2, 12, :])
# Out:
# (0.01470241631921875, 0.01029454662677876)

# %% [markdown]
# ### Exercise 2:
# Histogram the values for the same datapoint.

# %%
mu = np.mean(results[2, 12, :])
sig = np.std(results[2, 12, :])
plt.hist(results[2, 12, :], bins=np.linspace(mu - 4 * sig, mu + 4 * sig, 40), 
        edgecolor='k');
plt.grid(alpha=0.2)
plt.xlabel('Asymmetry')
plt.savefig('../image/mc_sys_asymmetry_example.pdf', bbox_inches='tight')

# %% [markdown]
# ### Exercise 3:
# Create an errorbar plot where the x-axis values are the 240 datapoints and the y-axis displays the mean and std for sector 1.

# %%
s1_mu = np.mean(results, axis = 2)[0]
s1_std = np.std(results, axis = 2)[0]

plt.figure(figsize=(12,6))
plt.errorbar(np.arange(240), s1_mu, s1_std, marker='.', linestyle='')
plt.xlabel('Datapoint')
plt.ylabel('Measured Value (+/- Std. Dev.)')
# Out:
# Text(0, 0.5, 'Measured Value (+/- Std. Dev.)')

# %% [markdown]
# ### Exercise 4:
# Create the same plot as above, but superimpose all sectors.  This will look messy (it's okay).

# %%
mu = np.mean(results, axis = 2)
sig = np.std(results, axis = 2)

plt.figure(figsize=(12,6))

for sector in range(1,7):
    plt.errorbar(np.arange(240), 
                 mu[sector-1], 
                 sig[sector-1], 
                 marker='.', linestyle='')

plt.xlabel('Datapoint')
plt.ylabel('Measured Value (+/- Std. Dev.)')
# Out:
# Text(0, 0.5, 'Measured Value (+/- Std. Dev.)')

# %% [markdown]
# ### Exercise 5:
# For datapoint 15, choose two sectors and create a scatterplot of the results from all random trials.

# %%
plt.scatter(results[1, 15, :], results[2, 15, :], edgecolor='k')
plt.axvline(results[1, 15, :].mean(), alpha=0.6)
plt.axhline(results[2, 15, :].mean(), alpha=0.6)
plt.grid(alpha = 0.5)
plt.title('Sectors 1 ({0:6.4f}) and 2 ({1:6.4f})'.format(
    results[1, 15, :].mean(), results[2, 15, :].mean()
))
# Out:
# Text(0.5, 1.0, 'Sectors 1 (-0.0340) and 2 (-0.0433)')

# %% [markdown]
# ### Exercise 6:
# Write a function that performs the above and accepts the sectors and datapoint as arguments.

# %%
def scatter_two_sectors(data, sectors, index, 
                       fig=None, ax=None):
    """ 
    Create a scatterplot of the MC trials 
    for a datapoint given by index.  Return the 
    figure. 
    
    Inputs:
    -------
    data - the results array from above indexed by (sector, datapoint, trial)
    sectors - a tuple of length 2 that specifies the two sectors to compare
    index - the datapoint to plot
    
    Returns: 
    --------
    fig - The figure object for drawing.
    ax - The axis object for drawing. 
    
    """
    
    assert(len(sectors) == 2)
    
    if fig is None:
        fig = plt.figure()
        ax = fig.add_subplot(1,1,1)
    
    if ax is None:
        ax = fig.add_subplot(1,1,1)
        
    ax.scatter(data[sectors[0]-1, index, :], data[sectors[1]-1, index, :], edgecolor='k')
    ax.axvline(data[sectors[0]-1, index, :].mean(), alpha=0.6)
    ax.axhline(data[sectors[1]-1, index, :].mean(), alpha=0.6)
    ax.grid(alpha = 0.5)
    ax.set_title('Sectors {0} ({1:6.4f}) and {2} ({3:6.4f})'.format(
        sectors[0],
        data[sectors[0]-1, index, :].mean(),
        sectors[1],
        data[sectors[1]-1, index, :].mean()
    ))
    
    # Set the scale for both axes the same so that
    # if there is disagreement the y-sector will be 
    # offset. 
    axisrange = (np.mean(data[sectors[0]-1, index, :]) - 12 * np.std(data[sectors[0]-1, index, :]),
                 np.mean(data[sectors[0]-1, index, :]) + 12 * np.std(data[sectors[0]-1, index, :]))
    ax.set_xlim(axisrange)
    ax.set_ylim(axisrange)
    
    return fig, ax

# %%
fig, ax = scatter_two_sectors(data=results, sectors=(1,2), index=15)

# %% [markdown]
# ### Exercise 7:
# Choose one datapoint and compare all the sectors using the function above.  Plot the results in a grid.

# %%
index = 5

fig = plt.figure(figsize=(24,24))

for isect in range(1,7):
    for jsect in range(1,7):
        iax = (jsect - 1) + 6 * (isect - 1) + 1
        ax = fig.add_subplot(6, 6, iax)
        fig, ax = scatter_two_sectors(data = results, 
                           sectors = (isect, jsect),
                           index = index, fig = fig, ax = ax)
        
fig.tight_layout()
fig.savefig('../image/sector_mc_systematics_{}.pdf'.format(index), bbox_inches='tight')

# %%
index = 15

fig = plt.figure(figsize=(24,24))

for isect in range(1,7):
    for jsect in range(1,7):
        iax = (jsect - 1) + 6 * (isect - 1) + 1
        ax = fig.add_subplot(6, 6, iax)
        fig, ax = scatter_two_sectors(data = results, 
                           sectors = (isect, jsect),
                           index = index, fig = fig, ax = ax)
        
fig.tight_layout()

# %%
results_mean = np.mean(results, axis=2)
results_std = np.std(results, axis=2)

# %%
def weighted_chi2(x, xerr):
    weights = 1.0 / xerr**2
    xbar = np.sum(x * weights) / np.sum(weights)
    chi2 = np.sum(weights * (x - xbar)**2)
    return chi2

# %%
psuedo_errors = np.sqrt(np.repeat(0.01, len(results_std[:,0]))**2 + results_std[:,0]**2)

# %%
weighted_chi2(results_mean[:, 0], results_std[:, 0])
# Out:
# 33.98328821918242

# %%
weighted_chi2(results_mean[:, 0], psuedo_errors)
# Out:
# 13.174384690861928

# %%
chi2 = [weighted_chi2(results_mean[:,i], results_std[:,i]) for i in range(240)]
chi2 = np.array(chi2)

# %%
chi2
# Out:
# array([ 33.98328822,  10.47730509,  26.08382022,  23.28181851,
#         57.22307445,   4.84387805,   3.36230412,  23.07238787,
#         42.70453005,  25.99456301,   5.47100771,  18.188564  ,
#         21.63392251,  48.20232104,  14.632088  ,  33.84729942,
#         16.54555347,  51.88903092,   8.77072443,  53.57853835,
#         30.04902995,  15.959349  ,  20.6899172 ,  41.30198976,
#         65.93925853,   2.60710351,  21.58287502,  91.38111508,
#         48.79183487,  86.02411646,  27.18046826,  41.75293369,
#         16.6710697 ,  48.99535776,  27.30645438,   7.95561047,
#         18.27259778,  23.66682136,   1.57404821,  37.99588927,
#         10.91794178,  14.89172826,  71.70167317,  47.65269813,
#         57.97786254,  47.17971562,  15.66127183,  84.85021172,
#         63.40407225,  99.09661969, 100.55378386,  46.62505118,
#         17.93697171,  31.26951355,  65.8160872 , 187.31059221,
#         85.41685359,  72.09358324,  64.13094263,  35.60461783,
#         33.08524846,  72.25592435,  40.95932525,  38.51929189,
#         16.34530323,  21.58727087,  50.77513851, 228.32929281,
#         46.88053688, 112.43398171,  50.29317335,  36.40058086,
#         98.34850354,  52.97824216,  45.38041253,  70.04611793,
#         33.46329622,  56.09452273,  26.92737436,  33.85441464,
#         35.39091253,  37.63531011,  34.69159653,  54.80194033,
#         50.85758012,  36.99820365,  28.75300467,  17.52379353,
#         44.67798986,  16.18726702,  56.81114658,  19.59392068,
#         88.92241315,  32.49033209,  32.79272915,  50.47175328,
#         37.55276578,  27.16992685,  20.52927065,  15.72225159,
#         51.69170297,  85.94094409,  39.66870325,  44.198425  ,
#         31.93892141,  39.75037517,  20.88966408,   6.86641067,
#          5.30820603,  15.74310512,  28.47736688,  22.15209077,
#         22.07691533,   9.6860894 ,  18.72961589,  12.95384748,
#         11.89831839,  56.32227854,   5.63428545,  26.63618986,
#         19.79405286,  54.04035142,  52.27347357,  53.63005018,
#         47.7129643 ,   6.53840975,  49.28316849, 107.92642188,
#         20.03855994,  26.13047995,  79.49266367,  15.12898824,
#         14.62941188,  31.39539778,  20.48834869,  49.01797923,
#         86.03320605,  56.04142142,  52.43205125,  10.83750642,
#         27.64268614,  57.56528028,  13.58781375,  15.68306159,
#         37.07150539,  20.75554681,  34.03023318,  41.17044397,
#         76.90316541,  26.98064177,  46.23926713,  37.82940725,
#         47.07530047,  26.65200134,  13.38515085,  33.96245268,
#         37.70139028,  27.03268157,  32.9805634 ,  21.2452293 ,
#         90.79533   ,  22.51588556, 111.97239955,  14.95034719,
#         39.42078615,  62.99724414,  27.15975123,  10.606843  ,
#          8.65710016,  66.84552254,  31.53224589,   7.01322312,
#         25.04060391,  23.72284023,  47.91401539,  50.71652985,
#         68.35259671,  22.49826676,  20.15336072,  26.08582639,
#          9.2738086 ,   3.85056831,  19.52813589,  13.83058667,
#         48.97203799,  14.4675717 ,  17.46818357,  28.65812744,
#         27.55363339,  53.22189446,   3.72320932,  11.17953954,
#         31.45296295,  23.93254903,  31.13995252,  90.2490982 ,
#         19.86866984,  23.72441577,  11.57421317,   9.47674295,
#         26.43323546,  12.73098289,  19.07182664,  20.0164741 ,
#         57.78318205,  96.97452385,  25.68904424,  78.50204552,
#         43.60050598,  18.33290664,  76.78097152,  40.73333179,
#         90.96583715,  62.6533284 ,  39.45932374,  28.36126999,
#         30.52317469,  17.12686042,  30.58976575,  24.58227768,
#         33.83315808,  85.96766522,  35.71260569,  15.86010502,
#         30.55072616,  15.35270419,  21.19725976,  82.22238656,
#        105.69303321,  65.24770503,  34.11630742,  64.53526197,
#         79.46918675,  24.09528995,  53.24281054, 173.75716741,
#        158.51614431, 115.99734068,  48.89484559,  19.56749975])

# %% [markdown]
# # Save Results

# %%
for isect in range(1,7):
    output = data[isect][0].copy()
    output['mc_mean'] = np.mean(results[isect-1, :, :], axis=1)
    output['mc_std'] = np.std(results[isect-1, :, :], axis=1)
    output.to_csv('../database/phi/random/systematics_{}.csv'.format(isect), index=False)

# %%
os.listdir('../database/phi/random')
# Out:
# ['systematics_4.csv',
#  'sector_6_87.csv',
#  'sector_6_93.csv',
#  'sector_1_71.csv',
#  'sector_6_78.csv',
#  'sector_1_6.csv',
#  'sector_1_65.csv',
#  'sector_6_44.csv',
#  'sector_4_110.csv',
#  'sector_4_104.csv',
#  'sector_6_50.csv',
#  'sector_1_59.csv',
#  'sector_5_15.csv',
#  'sector_3_4.csv',
#  'sector_2_20.csv',
#  'sector_5_101.csv',
#  'sector_5_29.csv',
#  'sector_2_34.csv',
#  'sector_5_115.csv',
#  'sector_5_2.csv',
#  'sector_4_82.csv',
#  'sector_4_96.csv',
#  'sector_1_109.csv',
#  'sector_3_74.csv',
#  'sector_3_60.csv',
#  'sector_4_69.csv',
#  'sector_4_41.csv',
#  'sector_3_48.csv',
#  'sector_4_55.csv',
#  'sector_1_121.csv',
#  'sector_1_120.csv',
#  'sector_4_54.csv',
#  'sector_4_40.csv',
#  'sector_3_49.csv',
#  'sector_3_61.csv',
#  'sector_4_68.csv',
#  'sector_1_108.csv',
#  'sector_3_75.csv',
#  'sector_4_97.csv',
#  'sector_4_83.csv',
#  'sector_5_3.csv',
#  'sector_5_114.csv',
#  'sector_2_35.csv',
#  'sector_5_100.csv',
#  'sector_2_21.csv',
#  'sector_5_28.csv',
#  'sector_3_5.csv',
#  'sector_5_14.csv',
#  'sector_6_51.csv',
#  'sector_4_105.csv',
#  'sector_1_58.csv',
#  'sector_4_111.csv',
#  'sector_6_45.csv',
#  'sector_1_7.csv',
#  'sector_1_64.csv',
#  'sector_1_70.csv',
#  'sector_6_79.csv',
#  'sector_6_92.csv',
#  'sector_6_86.csv',
#  'systematics_5.csv',
#  'sector_1_99.csv',
#  'sector_6_90.csv',
#  'sector_6_84.csv',
#  'sector_1_66.csv',
#  'sector_1_5.csv',
#  'sector_1_72.csv',
#  'sector_4_107.csv',
#  'sector_6_53.csv',
#  'sector_6_47.csv',
#  'sector_4_113.csv',
#  'sector_3_7.csv',
#  'sector_5_16.csv',
#  'sector_2_37.csv',
#  'sector_5_116.csv',
#  'sector_2_23.csv',
#  'sector_5_102.csv',
#  'sector_5_1.csv',
#  'sector_4_95.csv',
#  'sector_3_88.csv',
#  'sector_4_81.csv',
#  'sector_3_63.csv',
#  'sector_3_77.csv',
#  'sector_4_56.csv',
#  'sector_1_122.csv',
#  'sector_4_42.csv',
#  'sector_4_43.csv',
#  'sector_1_123.csv',
#  'sector_4_57.csv',
#  'sector_3_76.csv',
#  'sector_3_62.csv',
#  'sector_3_89.csv',
#  'sector_4_80.csv',
#  'sector_4_94.csv',
#  'sector_5_0.csv',
#  'sector_5_103.csv',
#  'sector_2_22.csv',
#  'sector_5_117.csv',
#  'sector_2_36.csv',
#  'sector_5_17.csv',
#  'sector_3_6.csv',
#  'sector_4_112.csv',
#  'sector_6_46.csv',
#  'sector_6_52.csv',
#  'sector_4_106.csv',
#  'sector_1_73.csv',
#  'sector_1_67.csv',
#  'sector_1_4.csv',
#  'sector_6_85.csv',
#  'systematics_6.csv',
#  'sector_1_98.csv',
#  'sector_6_91.csv',
#  'sector_6_95.csv',
#  'sector_1_88.csv',
#  'systematics_2.csv',
#  'sector_6_81.csv',
#  'sector_4_102.csv',
#  'sector_6_56.csv',
#  'sector_6_42.csv',
#  'sector_4_116.csv',
#  'sector_1_0.csv',
#  'sector_1_63.csv',
#  'sector_1_77.csv',
#  'sector_2_32.csv',
#  'sector_5_113.csv',
#  'sector_2_26.csv',
#  'sector_5_107.csv',
#  'sector_3_2.csv',
#  'sector_5_13.csv',
#  'sector_5_4.csv',
#  'sector_3_99.csv',
#  'sector_4_90.csv',
#  'sector_4_84.csv',
#  'sector_4_53.csv',
#  'sector_1_127.csv',
#  'sector_4_47.csv',
#  'sector_3_66.csv',
#  'sector_3_72.csv',
#  'sector_3_73.csv',
#  'sector_3_67.csv',
#  'sector_4_46.csv',
#  'sector_1_126.csv',
#  'sector_4_52.csv',
#  'sector_4_85.csv',
#  'sector_3_98.csv',
#  'sector_4_91.csv',
#  'sector_5_5.csv',
#  'sector_5_12.csv',
#  'sector_3_3.csv',
#  'sector_5_106.csv',
#  'sector_2_27.csv',
#  'sector_5_112.csv',
#  'sector_2_33.csv',
#  'sector_1_76.csv',
#  'sector_1_1.csv',
#  'sector_1_62.csv',
#  'sector_4_117.csv',
#  'sector_6_43.csv',
#  'sector_6_57.csv',
#  'sector_4_103.csv',
#  'sector_1_89.csv',
#  'sector_6_80.csv',
#  'systematics_3.csv',
#  'sector_6_94.csv',
#  'systematics_1.csv',
#  'sector_6_82.csv',
#  'sector_6_96.csv',
#  'sector_6_41.csv',
#  'sector_4_115.csv',
#  'sector_1_48.csv',
#  'sector_4_101.csv',
#  'sector_6_55.csv',
#  'sector_1_74.csv',
#  'sector_1_60.csv',
#  'sector_6_69.csv',
#  'sector_1_3.csv',
#  'sector_2_25.csv',
#  'sector_5_104.csv',
#  'sector_2_31.csv',
#  'sector_5_110.csv',
#  'sector_5_38.csv',
#  'sector_5_10.csv',
#  'sector_2_19.csv',
#  'sector_3_1.csv',
#  'sector_5_7.csv',
#  'sector_4_87.csv',
#  'sector_4_93.csv',
#  'sector_4_44.csv',
#  'sector_4_50.csv',
#  'sector_1_124.csv',
#  'sector_3_59.csv',
#  'sector_3_71.csv',
#  'sector_4_78.csv',
#  'sector_1_118.csv',
#  'sector_3_65.csv',
#  'sector_1_119.csv',
#  'sector_3_64.csv',
#  'sector_3_70.csv',
#  'sector_4_79.csv',
#  'sector_1_125.csv',
#  'sector_4_51.csv',
#  'sector_3_58.csv',
#  'sector_4_45.csv',
#  'sector_4_92.csv',
#  'sector_4_86.csv',
#  'sector_5_6.csv',
#  'sector_3_0.csv',
#  'sector_5_11.csv',
#  'sector_2_18.csv',
#  'sector_5_111.csv',
#  'sector_2_30.csv',
#  'sector_5_39.csv',
#  'sector_5_105.csv',
#  'sector_2_24.csv',
#  'sector_1_61.csv',
#  'sector_6_68.csv',
#  'sector_1_2.csv',
#  'sector_1_75.csv',
#  'sector_6_54.csv',
#  'sector_4_100.csv',
#  'sector_4_114.csv',
#  'sector_6_40.csv',
#  'sector_1_49.csv',
#  'sector_6_97.csv',
#  'sector_6_83.csv',
#  'sector_2_122.csv',
#  'sector_1_12.csv',
#  'sector_6_3.csv',
#  'sector_6_27.csv',
#  'sector_6_33.csv',
#  'sector_5_89.csv',
#  'sector_2_80.csv',
#  'sector_2_94.csv',
#  'sector_3_127.csv',
#  'sector_5_76.csv',
#  'sector_5_62.csv',
#  'sector_4_1.csv',
#  'sector_2_43.csv',
#  'sector_2_57.csv',
#  'sector_6_116.csv',
#  'sector_6_102.csv',
#  'sector_2_7.csv',
#  'sector_3_17.csv',
#  'sector_4_22.csv',
#  'sector_4_36.csv',
#  'sector_4_37.csv',
#  'sector_4_23.csv',
#  'sector_3_16.csv',
#  'sector_2_6.csv',
#  'sector_6_103.csv',
#  'sector_6_117.csv',
#  'sector_2_56.csv',
#  'sector_2_42.csv',
#  'sector_4_0.csv',
#  'sector_5_63.csv',
#  'sector_5_77.csv',
#  'sector_2_95.csv',
#  'sector_3_126.csv',
#  'sector_5_88.csv',
#  'sector_2_81.csv',
#  'sector_6_32.csv',
#  'sector_6_26.csv',
#  'sector_6_2.csv',
#  'sector_1_13.csv',
#  'sector_2_123.csv',
#  'sector_2_109.csv',
#  'sector_2_121.csv',
#  'sector_6_0.csv',
#  'sector_1_11.csv',
#  'sector_6_18.csv',
#  'sector_6_30.csv',
#  'sector_1_39.csv',
#  'sector_6_24.csv',
#  'sector_3_118.csv',
#  'sector_3_124.csv',
#  'sector_2_97.csv',
#  'sector_2_83.csv',
#  'sector_5_61.csv',
#  'sector_4_2.csv',
#  'sector_2_68.csv',
#  'sector_5_75.csv',
#  'sector_2_54.csv',
#  'sector_2_40.csv',
#  'sector_5_49.csv',
#  'sector_6_101.csv',
#  'sector_6_115.csv',
#  'sector_2_4.csv',
#  'sector_3_14.csv',
#  'sector_4_35.csv',
#  'sector_4_21.csv',
#  'sector_3_28.csv',
#  'sector_4_20.csv',
#  'sector_3_29.csv',
#  'sector_4_34.csv',
#  'sector_3_15.csv',
#  'sector_2_5.csv',
#  'sector_6_114.csv',
#  'sector_6_100.csv',
#  'sector_2_41.csv',
#  'sector_5_48.csv',
#  'sector_2_55.csv',
#  'sector_5_74.csv',
#  'sector_4_3.csv',
#  'sector_5_60.csv',
#  'sector_2_69.csv',
#  'sector_2_82.csv',
#  'sector_3_125.csv',
#  'sector_2_96.csv',
#  'sector_3_119.csv',
#  'sector_6_25.csv',
#  'sector_6_31.csv',
#  'sector_1_38.csv',
#  'sector_1_10.csv',
#  'sector_6_19.csv',
#  'sector_6_1.csv',
#  'sector_2_120.csv',
#  'sector_2_108.csv',
#  'sector_2_124.csv',
#  'sector_2_118.csv',
#  'sector_6_35.csv',
#  'sector_6_21.csv',
#  'sector_1_28.csv',
#  'sector_6_5.csv',
#  'sector_1_14.csv',
#  'sector_2_92.csv',
#  'sector_3_121.csv',
#  'sector_2_86.csv',
#  'sector_3_109.csv',
#  'sector_2_51.csv',
#  'sector_5_58.csv',
#  'sector_2_45.csv',
#  'sector_5_64.csv',
#  'sector_4_7.csv',
#  'sector_5_70.csv',
#  'sector_2_79.csv',
#  'sector_6_104.csv',
#  'sector_6_110.csv',
#  'sector_2_1.csv',
#  'sector_4_30.csv',
#  'sector_3_39.csv',
#  'sector_4_24.csv',
#  'sector_3_11.csv',
#  'sector_4_18.csv',
#  'sector_3_10.csv',
#  'sector_4_19.csv',
#  'sector_4_25.csv',
#  'sector_4_31.csv',
#  'sector_3_38.csv',
#  'sector_2_0.csv',
#  'sector_6_111.csv',
#  'sector_6_105.csv',
#  'sector_5_71.csv',
#  'sector_2_78.csv',
#  'sector_4_6.csv',
#  'sector_5_65.csv',
#  'sector_2_44.csv',
#  'sector_2_50.csv',
#  'sector_5_59.csv',
#  'sector_3_108.csv',
#  'sector_2_87.csv',
#  'sector_2_93.csv',
#  'sector_3_120.csv',
#  'sector_1_15.csv',
#  'sector_6_4.csv',
#  'sector_6_20.csv',
#  'sector_1_29.csv',
#  'sector_6_34.csv',
#  'sector_2_119.csv',
#  'sector_2_125.csv',
#  'sector_2_127.csv',
#  'sector_6_22.csv',
#  'sector_6_36.csv',
#  'sector_1_17.csv',
#  'sector_6_6.csv',
#  'sector_2_85.csv',
#  'sector_3_122.csv',
#  'sector_5_98.csv',
#  'sector_2_91.csv',
#  'sector_2_46.csv',
#  'sector_2_52.csv',
#  'sector_5_73.csv',
#  'sector_5_67.csv',
#  'sector_4_4.csv',
#  'sector_6_113.csv',
#  'sector_6_107.csv',
#  'sector_2_2.csv',
#  'sector_4_27.csv',
#  'sector_4_33.csv',
#  'sector_3_12.csv',
#  'sector_3_13.csv',
#  'sector_4_32.csv',
#  'sector_4_26.csv',
#  'sector_2_3.csv',
#  'sector_6_106.csv',
#  'sector_6_112.csv',
#  'sector_4_5.csv',
#  'sector_5_66.csv',
#  'sector_5_72.csv',
#  'sector_2_53.csv',
#  'sector_2_47.csv',
#  'sector_5_99.csv',
#  'sector_3_123.csv',
#  'sector_2_90.csv',
#  'sector_2_84.csv',
#  'sector_6_7.csv',
#  'sector_1_16.csv',
#  'sector_6_37.csv',
#  'sector_6_23.csv',
#  'sector_2_126.csv',
#  'sector_2_103.csv',
#  'sector_2_117.csv',
#  'sector_1_33.csv',
#  'sector_1_27.csv',
#  'sector_6_12.csv',
#  'sector_5_94.csv',
#  'sector_2_89.csv',
#  'sector_5_80.csv',
#  'sector_3_112.csv',
#  'sector_3_106.csv',
#  'sector_5_57.csv',
#  'sector_5_43.csv',
#  'sector_4_8.csv',
#  'sector_2_62.csv',
#  'sector_2_76.csv',
#  'sector_6_123.csv',
#  'sector_3_36.csv',
#  'sector_3_22.csv',
#  'sector_4_17.csv',
#  'sector_4_16.csv',
#  'sector_3_23.csv',
#  'sector_3_37.csv',
#  'sector_6_122.csv',
#  'sector_2_77.csv',
#  'sector_4_9.csv',
#  'sector_2_63.csv',
#  'sector_5_42.csv',
#  'sector_5_56.csv',
#  'sector_3_107.csv',
#  'sector_3_113.csv',
#  'sector_2_88.csv',
#  'sector_5_81.csv',
#  'sector_5_95.csv',
#  'sector_6_13.csv',
#  'sector_1_26.csv',
#  'sector_1_32.csv',
#  'sector_2_116.csv',
#  'sector_2_102.csv',
#  'sector_2_114.csv',
#  'sector_2_100.csv',
#  'sector_1_24.csv',
#  'sector_1_30.csv',
#  'sector_6_39.csv',
#  'sector_6_11.csv',
#  'sector_1_18.csv',
#  'sector_6_9.csv',
#  'sector_5_83.csv',
#  'sector_5_97.csv',
#  'sector_3_105.csv',
#  'sector_3_111.csv',
#  'sector_5_40.csv',
#  'sector_2_49.csv',
#  'sector_5_54.csv',
#  'sector_2_75.csv',
#  'sector_2_61.csv',
#  'sector_5_68.csv',
#  'sector_6_108.csv',
#  'sector_6_120.csv',
#  'sector_3_21.csv',
#  'sector_4_28.csv',
#  'sector_3_35.csv',
#  'sector_4_14.csv',
#  'sector_4_15.csv',
#  'sector_3_34.csv',
#  'sector_3_20.csv',
#  'sector_4_29.csv',
#  'sector_6_121.csv',
#  'sector_6_109.csv',
#  'sector_2_60.csv',
#  'sector_5_69.csv',
#  'sector_2_74.csv',
#  'sector_5_55.csv',
#  'sector_5_41.csv',
#  'sector_2_48.csv',
#  'sector_3_110.csv',
#  'sector_3_104.csv',
#  'sector_5_96.csv',
#  'sector_5_82.csv',
#  'sector_6_8.csv',
#  'sector_6_10.csv',
#  'sector_1_19.csv',
#  'sector_1_31.csv',
#  'sector_6_38.csv',
#  'sector_1_25.csv',
#  'sector_2_101.csv',
#  'sector_2_115.csv',
#  'sector_2_111.csv',
#  'sector_2_105.csv',
#  'sector_6_14.csv',
#  'sector_1_21.csv',
#  'sector_6_28.csv',
#  'sector_1_35.csv',
#  'sector_3_100.csv',
#  'sector_3_114.csv',
#  'sector_5_86.csv',
#  'sector_5_92.csv',
#  'sector_2_70.csv',
#  'sector_5_79.csv',
#  'sector_2_64.csv',
#  'sector_5_45.csv',
#  'sector_5_51.csv',
#  'sector_2_58.csv',
#  'sector_6_125.csv',
#  'sector_6_119.csv',
#  'sector_2_8.csv',
#  'sector_4_11.csv',
#  'sector_3_18.csv',
#  'sector_3_24.csv',
#  'sector_3_30.csv',
#  'sector_4_39.csv',
#  'sector_3_31.csv',
#  'sector_4_38.csv',
#  'sector_3_25.csv',
#  'sector_4_10.csv',
#  'sector_3_19.csv',
#  'sector_2_9.csv',
#  'sector_6_118.csv',
#  'sector_6_124.csv',
#  'sector_5_50.csv',
#  'sector_2_59.csv',
#  'sector_5_44.csv',
#  'sector_2_65.csv',
#  'sector_2_71.csv',
#  'sector_5_78.csv',
#  'sector_5_93.csv',
#  'sector_5_87.csv',
#  'sector_3_115.csv',
#  'sector_3_101.csv',
#  'sector_1_34.csv',
#  'sector_1_20.csv',
#  'sector_6_29.csv',
#  'sector_6_15.csv',
#  'sector_2_104.csv',
#  'sector_2_110.csv',
#  'sector_2_106.csv',
#  'sector_2_112.csv',
#  'sector_6_17.csv',
#  'sector_1_36.csv',
#  'sector_1_22.csv',
#  'sector_3_117.csv',
#  'sector_3_103.csv',
#  'sector_2_98.csv',
#  'sector_5_91.csv',
#  'sector_5_85.csv',
#  'sector_2_67.csv',
#  'sector_2_73.csv',
#  'sector_5_52.csv',
#  'sector_5_46.csv',
#  'sector_6_126.csv',
#  'sector_4_12.csv',
#  'sector_3_33.csv',
#  'sector_3_27.csv',
#  'sector_3_26.csv',
#  'sector_3_32.csv',
#  'sector_4_13.csv',
#  'sector_6_127.csv',
#  'sector_5_47.csv',
#  'sector_5_53.csv',
#  'sector_2_72.csv',
#  'sector_2_66.csv',
#  'sector_5_84.csv',
#  'sector_2_99.csv',
#  'sector_5_90.csv',
#  'sector_3_102.csv',
#  'sector_3_116.csv',
#  'sector_1_23.csv',
#  'sector_1_37.csv',
#  'sector_6_16.csv',
#  'sector_2_113.csv',
#  'sector_2_107.csv',
#  'sector_1_93.csv',
#  'sector_1_87.csv',
#  'sector_1_50.csv',
#  'sector_6_59.csv',
#  'sector_4_119.csv',
#  'sector_1_44.csv',
#  'sector_6_65.csv',
#  'sector_6_71.csv',
#  'sector_4_125.csv',
#  'sector_1_78.csv',
#  'sector_5_34.csv',
#  'sector_5_20.csv',
#  'sector_2_29.csv',
#  'sector_5_108.csv',
#  'sector_5_120.csv',
#  'sector_2_15.csv',
#  'sector_3_96.csv',
#  'sector_3_82.csv',
#  'sector_3_55.csv',
#  'sector_3_41.csv',
#  'sector_4_48.csv',
#  'sector_4_60.csv',
#  'sector_1_114.csv',
#  'sector_3_69.csv',
#  'sector_4_74.csv',
#  'sector_1_100.csv',
#  'sector_1_101.csv',
#  'sector_4_75.csv',
#  'sector_1_115.csv',
#  'sector_4_61.csv',
#  'sector_3_68.csv',
#  'sector_3_40.csv',
#  'sector_4_49.csv',
#  'sector_3_54.csv',
#  'sector_3_83.csv',
#  'sector_3_97.csv',
#  'sector_2_14.csv',
#  'sector_5_121.csv',
#  'sector_5_21.csv',
#  'sector_5_109.csv',
#  'sector_2_28.csv',
#  'sector_5_35.csv',
#  'sector_4_124.csv',
#  'sector_6_70.csv',
#  'sector_1_79.csv',
#  'sector_6_64.csv',
#  'sector_4_118.csv',
#  'sector_1_45.csv',
#  'sector_1_51.csv',
#  'sector_6_58.csv',
#  'sector_1_86.csv',
#  'sector_1_92.csv',
#  'sector_1_84.csv',
#  'sector_6_99.csv',
#  'sector_1_90.csv',
#  'sector_1_47.csv',
#  'sector_1_53.csv',
#  'sector_6_72.csv',
#  'sector_4_126.csv',
#  'sector_6_66.csv',
#  'sector_5_23.csv',
#  'sector_5_37.csv',
#  'sector_2_16.csv',
#  'sector_5_123.csv',
#  'sector_5_8.csv',
#  'sector_4_88.csv',
#  'sector_3_81.csv',
#  'sector_3_95.csv',
#  'sector_3_42.csv',
#  'sector_3_56.csv',
#  'sector_4_77.csv',
#  'sector_1_103.csv',
#  'sector_4_63.csv',
#  'sector_1_117.csv',
#  'sector_1_116.csv',
#  'sector_4_62.csv',
#  'sector_1_102.csv',
#  'sector_4_76.csv',
#  'sector_3_57.csv',
#  'sector_3_43.csv',
#  'sector_3_94.csv',
#  'sector_4_89.csv',
#  'sector_3_80.csv',
#  'sector_5_9.csv',
#  'sector_5_122.csv',
#  'sector_2_17.csv',
#  'sector_5_36.csv',
#  'sector_5_22.csv',
#  'sector_6_67.csv',
#  'sector_4_127.csv',
#  'sector_6_73.csv',
#  'sector_1_52.csv',
#  'sector_1_46.csv',
#  'sector_6_98.csv',
#  'sector_1_91.csv',
#  'sector_1_85.csv',
#  'sector_6_88.csv',
#  'sector_1_81.csv',
#  'sector_1_95.csv',
#  'sector_6_77.csv',
#  'sector_4_123.csv',
#  'sector_1_9.csv',
#  'sector_6_63.csv',
#  'sector_1_42.csv',
#  'sector_1_56.csv',
#  'sector_2_13.csv',
#  'sector_5_126.csv',
#  'sector_5_26.csv',
#  'sector_5_32.csv',
#  'sector_3_84.csv',
#  'sector_4_99.csv',
#  'sector_3_90.csv',
#  'sector_4_72.csv',
#  'sector_1_106.csv',
#  'sector_4_66.csv',
#  'sector_1_112.csv',
#  'sector_3_47.csv',
#  'sector_3_53.csv',
#  'sector_3_52.csv',
#  'sector_3_46.csv',
#  'sector_1_113.csv',
#  'sector_4_67.csv',
#  'sector_1_107.csv',
#  'sector_4_73.csv',
#  'sector_4_98.csv',
#  'sector_3_91.csv',
#  'sector_3_85.csv',
#  'sector_5_33.csv',
#  'sector_5_27.csv',
#  'sector_5_127.csv',
#  'sector_2_12.csv',
#  'sector_1_57.csv',
#  'sector_1_43.csv',
#  'sector_1_8.csv',
#  'sector_6_62.csv',
#  'sector_4_122.csv',
#  'sector_6_76.csv',
#  'sector_1_94.csv',
#  'sector_6_89.csv',
#  'sector_1_80.csv',
#  'sector_1_96.csv',
#  'sector_1_82.csv',
#  'sector_6_60.csv',
#  'sector_1_69.csv',
#  'sector_6_74.csv',
#  'sector_4_120.csv',
#  'sector_4_108.csv',
#  'sector_1_55.csv',
#  'sector_1_41.csv',
#  'sector_6_48.csv',
#  'sector_3_8.csv',
#  'sector_5_125.csv',
#  'sector_2_10.csv',
#  'sector_5_19.csv',
#  'sector_5_31.csv',
#  'sector_2_38.csv',
#  'sector_5_119.csv',
#  'sector_5_25.csv',
#  'sector_3_93.csv',
#  'sector_3_87.csv',
#  'sector_4_65.csv',
#  'sector_1_111.csv',
#  'sector_4_71.csv',
#  'sector_1_105.csv',
#  'sector_3_78.csv',
#  'sector_3_50.csv',
#  'sector_4_59.csv',
#  'sector_3_44.csv',
#  'sector_3_45.csv',
#  'sector_3_51.csv',
#  'sector_4_58.csv',
#  'sector_1_104.csv',
#  'sector_4_70.csv',
#  'sector_3_79.csv',
#  'sector_1_110.csv',
#  'sector_4_64.csv',
#  'sector_3_86.csv',
#  'sector_3_92.csv',
#  'sector_5_24.csv',
#  'sector_5_30.csv',
#  'sector_5_118.csv',
#  'sector_2_39.csv',
#  'sector_2_11.csv',
#  'sector_5_18.csv',
#  'sector_5_124.csv',
#  'sector_3_9.csv',
#  'sector_1_40.csv',
#  'sector_6_49.csv',
#  'sector_4_109.csv',
#  'sector_1_54.csv',
#  'sector_4_121.csv',
#  'sector_6_75.csv',
#  'sector_6_61.csv',
#  'sector_1_68.csv',
#  'sector_1_83.csv',
#  'sector_1_97.csv']

# %%
results[0,:,:].shape
# Out:
# (240, 128)

# %%
X = results[0,:,:].transpose()
mu = X.mean(axis=0)

# %%
X.shape
# Out:
# (128, 240)

# %%
mu.shape
# Out:
# (240,)

# %%
C = np.matmul((X - mu).transpose(),(X - mu)) / (nsamples-1)

# %%
plt.imshow(C[:12,:12])
plt.colorbar()
plt.savefig('../image/covmatrix.pdf', bbox_inches='tight')

# %%
plt.figure(figsize=(12,12))
plt.imshow(C)

# %%
V = np.linalg.inv(C)

# %%
plt.imshow(V[:25,:25])

# %%
plt.plot(mu[:13])

# %%
for _ in range(100):
    plt.plot(np.random.multivariate_normal(mu[:49], C[:49,:49]), 
             linestyle='', marker='o', color='red', alpha=0.2)

# %%
plt.plot(results[0, :49, :], linestyle='',  marker='o', color='red', alpha=0.2);

# %%
counts_pos = np.empty(shape=(6,240,nsamples))
counts_neg = np.empty(shape=(6,240,nsamples))

for sector in range(1, 7):
    for subfile in range(nsamples):
        counts_pos[sector - 1, :, subfile] = data[sector][subfile]['counts_pos']
        counts_neg[sector - 1, :, subfile] = data[sector][subfile]['counts_neg']

# %%
def calculate_mean_covariance(X):
    nrows, ncols = X.shape
    mu = X.mean(axis=0)
    C = np.matmul((X - mu).transpose(), (X - mu)) / (nrows - 1)
    return mu, C

# %%
counts_mu, counts_C = calculate_mean_covariance(counts_pos[0, :, :].transpose())

# %%
counts_mu
# Out:
# array([2049.9921875, 1041.1328125, 1657.15625  , 1017.8203125,
#         920.765625 ,  446.84375  ,  457.6875   , 1018.1953125,
#        1046.015625 , 1726.453125 , 1067.1484375, 2175.6875   ,
#        2137.140625 , 1148.9375   , 1548.4375   , 1240.15625  ,
#         844.7421875,  408.625    ,  403.953125 ,  924.9453125,
#        1213.0390625, 1572.3359375, 1221.3828125, 2215.90625  ,
#        2189.2265625, 1223.5078125, 1439.4921875, 1214.6328125,
#         864.0703125,  420.5390625,  396.96875  ,  896.90625  ,
#        1344.640625 , 1466.1484375, 1311.0078125, 2128.859375 ,
#        2090.8984375, 1321.5859375, 1357.171875 , 1319.2421875,
#         863.5078125,  431.96875  ,  438.609375 ,  975.9453125,
#        1385.71875  , 1344.5546875, 1335.390625 , 2220.40625  ,
#        2169.84375  , 1344.5390625, 1296.78125  , 1333.3828125,
#         898.6640625,  447.9453125,  465.765625 ,  957.890625 ,
#        1376.28125  , 1424.859375 , 1453.34375  , 2159.15625  ,
#        2593.4296875, 1631.6171875, 1954.109375 , 1432.7890625,
#        1415.9140625, 1044.5390625, 1001.28125  , 1381.1171875,
#        1414.609375 , 1997.6015625, 1638.96875  , 2712.984375 ,
#        2601.1171875, 1501.890625 , 2084.7265625, 1565.7421875,
#        1305.453125 ,  683.796875 ,  692.1484375, 1405.546875 ,
#        1600.5234375, 2128.4921875, 1641.1484375, 2728.4453125,
#        2833.0234375, 1560.625    , 1989.3125   , 1539.8515625,
#        1135.75     ,  595.9609375,  594.2578125, 1292.28125  ,
#        1633.515625 , 2170.828125 , 1679.953125 , 2916.46875  ,
#        2625.1015625, 1492.3203125, 1721.7109375, 1497.3515625,
#         969.4765625,  427.3359375,  437.8203125, 1060.2890625,
#        1567.9765625, 1745.65625  , 1481.0625   , 2667.53125  ,
#        2395.2421875, 1417.34375  , 1366.375    , 1424.921875 ,
#         879.7109375,  389.546875 ,  393.171875 ,  932.140625 ,
#        1467.4140625, 1339.6328125, 1484.9453125, 2402.6875   ,
#        2163.6328125, 1444.9375   , 1188.96875  , 1323.125    ,
#         813.8828125,  555.5078125,  519.1015625,  897.203125 ,
#        1324.3203125, 1247.9765625, 1461.609375 , 2255.3515625,
#        2313.3984375, 1188.6640625, 1357.8203125, 1478.765625 ,
#         874.90625  ,  188.734375 ,  195.3359375,  931.5546875,
#        1596.3046875, 1478.359375 , 1302.8671875, 2317.5390625,
#        2120.3828125, 1166.109375 , 1545.3671875, 1307.8671875,
#         904.2734375,  400.7734375,  417.921875 ,  949.21875  ,
#        1360.9375   , 1604.9609375, 1233.6328125, 2190.6484375,
#        2074.5234375, 1158.890625 , 1573.953125 , 1071.6328125,
#         900.2421875,  488.140625 ,  445.0390625,  990.1953125,
#        1147.15625  , 1572.71875  , 1185.5      , 2120.59375  ,
#        1965.1640625, 1121.1015625, 1632.9296875,  943.84375  ,
#         898.4453125,  522.765625 ,  585.5859375, 1005.7109375,
#         936.9765625, 1630.3359375, 1204.6640625, 2015.8828125,
#        2050.78125  ,  985.921875 , 1553.2578125, 1061.7421875,
#         865.0390625,  421.0703125,  428.53125  ,  960.       ,
#        1081.9296875, 1561.6953125, 1027.8515625, 2127.6953125,
#        2070.7734375, 1182.7890625, 1477.8828125, 1234.6875   ,
#         817.0546875,  420.9140625,  428.9921875,  954.9140625,
#        1274.078125 , 1499.0546875, 1234.5390625, 2140.484375 ,
#        2203.546875 , 1264.71875  , 1467.125    , 1243.       ,
#         960.90625  ,  453.2421875,  429.484375 ,  962.125    ,
#        1284.4375   , 1474.6484375, 1333.4453125, 2251.109375 ,
#        2156.       , 1294.59375  , 1397.2578125, 1268.9921875,
#         916.21875  ,  458.65625  ,  461.46875  ,  978.6171875,
#        1376.578125 , 1556.3515625, 1372.359375 , 2194.578125 ,
#        2156.       , 1351.6796875, 1403.515625 , 1316.8125   ,
#         832.53125  ,  402.0390625,  414.5078125,  918.2265625,
#        1348.671875 , 1441.8203125, 1420.078125 , 2186.1484375])

# %%
counts_C
# Out:
# array([[61087.25190699, 30741.47348671, 46550.16658465, ...,
#         22061.68362451, 22645.99274114, 36114.5523499 ],
#        [30741.47348671, 16049.78537156, 24096.88459646, ...,
#         11123.37838337, 11453.81631398, 18269.45257136],
#        [46550.16658465, 24096.88459646, 36632.16437008, ...,
#         17001.20939961, 17564.61761811, 28009.01599409],
#        ...,
#        [22061.68362451, 11123.37838337, 17001.20939961, ...,
#         11919.10919045, 12165.36847933, 19444.34971703],
#        [22645.99274114, 11453.81631398, 17564.61761811, ...,
#         12165.36847933, 12629.83636811, 20041.12217028],
#        [36114.5523499 , 18269.45257136, 28009.01599409, ...,
#         19444.34971703, 20041.12217028, 32147.65495817]])

# %%
plt.figure(figsize=(12,12))
plt.imshow(counts_C[:12,:12])

# %%
counts_mu[:12]
# Out:
# array([2049.9921875, 1041.1328125, 1657.15625  , 1017.8203125,
#         920.765625 ,  446.84375  ,  457.6875   , 1018.1953125,
#        1046.015625 , 1726.453125 , 1067.1484375, 2175.6875   ])

# %%
plt.plot(np.random.multivariate_normal(counts_mu[:12], counts_C[:12, :12]))

# %%
plt.hist(counts_pos[0, 7, :], bins=np.linspace(600, 1300, 20),
        edgecolor='k');

# %%
plt.hist(counts_pos[0, 7, :], bins=np.linspace(600, 1300, 40),
        edgecolor='k');

# %%
plt.hist(counts_pos[0, 7, :], bins=np.linspace(600, 1300, 60),
        edgecolor='k');

# %%
plt.scatter(counts_pos[0, 0, :], counts_pos[0, 7, :],
           edgecolor='k', marker='o', alpha=0.7)
plt.grid(alpha=0.3)

# %%
plt.scatter(counts_pos[0, 7, :], counts_neg[0, 7, :],
           edgecolor='k', marker='o', alpha=0.7)
plt.grid(alpha=0.3)

# %%
X = np.zeros(shape=(nsamples,2))
X[:,0] = counts_pos[0, 7, :]
X[:,1] = counts_neg[0, 7, :]
point_mu, point_C = calculate_mean_covariance(X)

# %%
point_mu
# Out:
# array([1018.1953125, 1024.890625 ])

# %%
point_C
# Out:
# array([[11404.85131644, 11090.34436516],
#        [11090.34436516, 11081.67298228]])

# %%
np.sqrt(point_C[0,0]), np.sqrt(point_C[1,1])
# Out:
# (106.79349847456542, 105.26952542062429)

# %%
X_sample = np.random.multivariate_normal(point_mu, point_C, 10000)

# %%
plt.scatter(X_sample[:,0], X_sample[:,1], 
           alpha=0.7, edgecolor='k', marker='o')
plt.grid(alpha=0.3)

# %%
def expected_asymmetry(X_samples):
    asym = (X_samples[:,0] - X_samples[:,1]) / (X_samples[:,0] + X_samples[:,1])
    return asym

# %%
asym = expected_asymmetry(X_sample)

# %%
plt.hist(asym, edgecolor='k', bins=np.linspace(-0.1, 0.1, 40));

# %%
plt.hist(results[0, 7, :], edgecolor='k', bins=np.linspace(-0.1, 0.1, 40));
