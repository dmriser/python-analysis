# %% [markdown]
# # Compare Sectors

# %%
import matplotlib.pyplot as plt
import os 
import numpy as np 
import pandas as pd 

# %matplotlib inline

# %%
data_dir = os.path.abspath('../database/fit')
print(f'Opening files from {data_dir}')
# Out:
# Opening files from /Users/davidriser/repos/python-analysis/kaon-bsa/database/fit

# %%
data = {} 

for sect in range(1,7):
    data[sect] = pd.read_csv(f'{data_dir}/sector_{sect}.csv')
    data[sect]['sector'] = np.repeat(sect, len(data[sect]))
    print(f'Loaded sector {sect} with {len(data[sect])} entries.')
# Out:
# Loaded sector 1 with 25 entries.
# Loaded sector 2 with 25 entries.
# Loaded sector 3 with 25 entries.
# Loaded sector 4 with 25 entries.
# Loaded sector 5 with 25 entries.
# Loaded sector 6 with 25 entries.

# %%
fig = plt.figure(figsize = (8,6))
ax = fig.add_subplot(1,1,1)
for sect in range(1,7):
    xdf = data[sect][data[sect]['axis'] == "x"]
    ax.errorbar(xdf['axis_bin'], xdf['par_0'], xdf['err_0'], marker='o',
                linestyle='', label=f'Sector {sect}')
    ax.set_xlabel('Bin Index')
    
ax.grid(alpha=0.2)
fig.legend(frameon=False)

# %%
fig = plt.figure(figsize = (8,6))
ax = fig.add_subplot(1,1,1)
for sect in range(1,7):
    df = data[sect][data[sect]['axis'] == "z"]
    ax.errorbar(df['axis_bin'], df['par_0'], df['err_0'], marker='o',
                linestyle='', label=f'Sector {sect}')
    ax.set_xlabel('Bin Index')
    
ax.grid(alpha=0.2)
fig.legend(frameon=False)

# %%
fig = plt.figure(figsize = (8,6))
ax = fig.add_subplot(1,1,1)
for sect in range(1,7):
    df = data[sect][data[sect]['axis'] == "pt"]
    ax.errorbar(df['axis_bin'], df['par_0'], df['err_0'], marker='o',
                linestyle='', label=f'Sector {sect}')
    ax.set_xlabel('Bin Index')
    
ax.grid(alpha=0.2)
fig.legend(frameon=False)

# %%
fig = plt.figure(figsize = (8,6))
ax = fig.add_subplot(1,1,1)
for sect in range(1,7):
    df = data[sect][data[sect]['axis'] == "q2"]
    ax.errorbar(df['axis_bin'], df['par_0'], df['err_0'], marker='o',
                linestyle='', label=f'Sector {sect}')
    ax.set_xlabel('Bin Index')
    
ax.grid(alpha=0.2)
fig.legend(frameon=False)

# %%
fig = plt.figure(figsize = (8,6))
ax = fig.add_subplot(1,1,1)
for sect in range(1,7):
    df = data[sect][data[sect]['axis'] == "q2"]
    ax.errorbar(df['axis_bin'], df['par_2'], df['err_2'], marker='o',
                linestyle='', label=f'Sector {sect}')
    ax.set_xlabel('Bin Index')
    
ax.grid(alpha=0.2)
fig.legend(frameon=False)

# %%
sector_data = pd.concat([data[i] for i in range(1,7)])

# %%
sector_data
# Out:
#             axis  axis_bin  axis_max  axis_min  \
# 0   missing_mass         0  1.472757  0.331363
# 1   missing_mass         1  1.640777  1.472757
# 2   missing_mass         2  1.822382  1.640777
# 3   missing_mass         3  2.008805  1.822382
# 4   missing_mass         4  2.495670  2.008805
# ..           ...       ...       ...       ...
# 20             z         0  0.259865  0.121260
# 21             z         1  0.333941  0.259865
# 22             z         2  0.400212  0.333941
# 23             z         3  0.473620  0.400212
# 24             z         4  0.859047  0.473620
#
#                                          bootstraps_0  \
# 0   [0.04990231 0.04972599 0.03803553 0.04867986 0...
# 1   [0.05430857 0.0483783  0.04330752 0.03741036 0...
# 2   [0.03908775 0.04854838 0.0401843  0.02635401 0...
# 3   [0.01932192 0.02131089 0.03461932 0.03479827 0...
# 4   [ 0.00618676 -0.003911    0.00688198  0.003983...
# ..                                                ...
# 20  [ 0.02417994  0.03354498  0.05140638  0.031758...
# 21  [0.02118131 0.04564624 0.03958713 0.04674462 0...
# 22  [0.02147113 0.04771953 0.0417046  0.03816458 0...
# 23  [0.04560444 0.04394409 0.03595643 0.04992839 0...
# 24  [-0.00103241  0.0075053   0.00587134  0.019976...
#
#                                          bootstraps_1  \
# 0   [-1.19896904e-01  3.62812206e-02 -4.30086195e-...
# 1   [-0.02465727  0.00607121 -0.65856594 -0.201649...
# 2   [-2.70138413e-01 -3.11631739e-01 -1.95684016e-...
# 3   [ 0.4515016  -0.13977821  0.21727477 -0.681637...
# 4   [-1.31363515e-02  1.67914387e-02 -2.36360654e-...
# ..                                                ...
# 20  [ 3.59562904e-01  3.02078784e-01  5.87658882e-...
# 21  [-8.03170264e-01 -7.20937848e-02 -2.73469537e-...
# 22  [ 0.65886754 -0.4567317  -0.3619004  -0.385823...
# 23  [-2.20999986e-01 -3.25361520e-01  2.98084356e-...
# 24  [ 1.33460443e-02 -7.07146451e-02 -5.69455475e-...
#
#                                          bootstraps_2     err_0     err_1  \
# 0   [ 6.71006739e-02 -1.97620198e-01 -5.38751662e-...  0.009907  0.406648
# 1   [-0.33611256 -0.18233016 -0.7508126   0.243405...  0.010180  0.385396
# 2   [ 0.17187549  0.14691423  0.35896105  0.447501...  0.009252  0.360143
# 3   [-5.22769451e-01 -2.86782235e-01 -5.10674059e-...  0.009961  0.329168
# 4   [ 5.63788004e-02 -4.83487770e-02  3.44554931e-...  0.009604  0.302533
# ..                                                ...       ...       ...
# 20  [-0.5556211  -0.5803907  -0.6991292  -0.569374...  0.011139  0.318488
# 21  [-0.48368824 -0.04447309  0.18603122 -0.066538...  0.009195  0.339319
# 22  [-7.97076166e-01 -1.45317331e-01  4.86025251e-...  0.009717  0.425144
# 23  [ 0.07318808 -0.08741802  0.09271333 -0.559477...  0.008870  0.409266
# 24  [ 5.92448935e-03 -3.78234521e-03  1.46741439e-...  0.007846  0.373275
#
#        err_2     par_0     par_1     par_2  sector
# 0   0.403060  0.036806 -0.040616 -0.204493       1
# 1   0.361082  0.034495 -0.121594 -0.122874       1
# 2   0.475998  0.028967 -0.188972  0.184542       1
# 3   0.224876  0.032406 -0.173411 -0.357599       1
# 4   0.242949  0.004467 -0.091202 -0.097977       1
# ..       ...       ...       ...       ...     ...
# 20  0.277285  0.036407 -0.061022 -0.596382       6
# 21  0.345953  0.036214 -0.300113 -0.027249       6
# 22  0.331858  0.035017 -0.414175 -0.103679       6
# 23  0.433048  0.032412 -0.048385 -0.046029       6
# 24  0.233245  0.014565 -0.014769 -0.182974       6
#
# [150 rows x 14 columns]

# %%
sector_stats = sector_data.groupby(['axis', 'axis_bin']).aggregate({
    'par_0' : [np.mean, np.var],
    'par_1' : [np.mean, np.std],
    'par_2' : [np.mean, np.std]
}).reset_index()
sector_stats.columns = ['axis', 'axis_bin', 'par_0_mean', 'par_0_std', 'par_1_mean',
                       'par_1_std', 'par_2_mean', 'par_2_std']

# %%
sector_stats
# Out:
#             axis  axis_bin  par_0_mean  par_0_std  par_1_mean  par_1_std  \
# 0   missing_mass         0    0.024747   0.000119   -0.047206   0.084946
# 1   missing_mass         1    0.051250   0.000155   -0.124558   0.131690
# 2   missing_mass         2    0.034988   0.000053   -0.056597   0.148524
# 3   missing_mass         3    0.033312   0.000026   -0.165050   0.314933
# 4   missing_mass         4    0.024709   0.000138   -0.091386   0.165876
# 5             pt         0    0.026847   0.000182   -0.101240   0.113536
# 6             pt         1    0.034114   0.000082   -0.037475   0.152293
# 7             pt         2    0.037303   0.000215   -0.132103   0.134914
# 8             pt         3    0.039786   0.000108   -0.149274   0.220703
# 9             pt         4    0.032626   0.000093   -0.069677   0.189227
# 10            q2         0    0.032196   0.000052   -0.145867   0.215389
# 11            q2         1    0.028026   0.000204   -0.125919   0.214159
# 12            q2         2    0.039703   0.000068   -0.001935   0.141261
# 13            q2         3    0.031386   0.000214   -0.196560   0.120864
# 14            q2         4    0.038349   0.000173   -0.104143   0.169125
# 15             x         0    0.021812   0.000105   -0.131341   0.068865
# 16             x         1    0.039728   0.000128   -0.181884   0.307746
# 17             x         2    0.037416   0.000158   -0.032934   0.204987
# 18             x         3    0.036754   0.000116   -0.094815   0.129686
# 19             x         4    0.032954   0.000065   -0.086754   0.132956
# 20             z         0    0.025189   0.000150   -0.054943   0.283435
# 21             z         1    0.036996   0.000096   -0.035510   0.269453
# 22             z         2    0.034527   0.000040   -0.268339   0.379304
# 23             z         3    0.032178   0.000200   -0.131755   0.107614
# 24             z         4    0.028483   0.000245   -0.058732   0.140286
#
#     par_2_mean  par_2_std
# 0    -0.132682   0.204792
# 1    -0.223317   0.167093
# 2    -0.069297   0.164496
# 3    -0.175351   0.162515
# 4    -0.150495   0.101094
# 5    -0.103029   0.122450
# 6    -0.139348   0.201657
# 7    -0.117208   0.294405
# 8    -0.159278   0.107897
# 9    -0.214994   0.166453
# 10   -0.214311   0.153602
# 11   -0.109018   0.183329
# 12   -0.192697   0.115895
# 13   -0.092397   0.238963
# 14   -0.113011   0.320932
# 15   -0.135429   0.104642
# 16   -0.229236   0.194334
# 17   -0.182346   0.117237
# 18   -0.213286   0.231250
# 19   -0.025337   0.255025
# 20   -0.108648   0.286856
# 21   -0.108974   0.314720
# 22   -0.101294   0.235974
# 23   -0.131792   0.186899
# 24   -0.214220   0.154020

# %%
fig = plt.figure(figsize = (8,6))
ax = fig.add_subplot(1,1,1)

df = data[sect][data[sect]['axis'] == "q2"]
ax.errorbar(df['axis_bin'], df['par_0'], df['err_0'], marker='o', 
            linestyle='')
ax.set_xlabel('Bin Index')
ax.grid(alpha=0.4)

# %%
def max_likelihood_mean(x, x_err):
    return np.sum((x / x_err)**2) / np.sum(1.0 / x_err**2)
