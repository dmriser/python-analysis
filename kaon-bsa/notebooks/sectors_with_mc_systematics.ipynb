# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import glob
import os
import sys

# %matplotlib inline

# %%
os.listdir('../database/phi/random')
# Out:
# ['sector_5_280.csv',
#  'sector_1_60.csv',
#  'sector_2_234.csv',
#  'sector_4_351.csv',
#  'sector_3_21.csv',
#  'sector_3_401.csv',
#  'sector_6_394.csv',
#  'sector_3_234.csv',
#  'sector_2_385.csv',
#  'sector_4_475.csv',
#  'sector_3_427.csv',
#  'sector_2_401.csv',
#  'sector_3_375.csv',
#  'sector_2_429.csv',
#  'sector_4_237.csv',
#  'sector_4_262.csv',
#  'sector_3_87.csv',
#  'sector_6_64.csv',
#  'sector_4_406.csv',
#  'sector_4_421.csv',
#  'sector_3_45.csv',
#  'sector_5_228.csv',
#  'sector_4_487.csv',
#  'sector_4_283.csv',
#  'sector_4_104.csv',
#  'sector_4_258.csv',
#  'sector_5_408.csv',
#  'sector_2_16.csv',
#  'sector_2_8.csv',
#  'systematics_3.csv',
#  'sector_3_365.csv',
#  'sector_6_307.csv',
#  'sector_3_473.csv',
#  'sector_5_241.csv',
#  'sector_6_43.csv',
#  'sector_3_489.csv',
#  'sector_4_169.csv',
#  'sector_6_384.csv',
#  'sector_2_416.csv',
#  'sector_2_208.csv',
#  'sector_6_301.csv',
#  'sector_3_347.csv',
#  'sector_2_380.csv',
#  'sector_4_127.csv',
#  'sector_4_21.csv',
#  'sector_2_263.csv',
#  'sector_1_144.csv',
#  'sector_6_341.csv',
#  'sector_4_343.csv',
#  'sector_6_404.csv',
#  'sector_1_122.csv',
#  'sector_2_138.csv',
#  'sector_6_471.csv',
#  'sector_4_432.csv',
#  'sector_5_364.csv',
#  'sector_5_47.csv',
#  'sector_6_235.csv',
#  'sector_3_383.csv',
#  'sector_1_355.csv',
#  'sector_1_80.csv',
#  'sector_4_31.csv',
#  'sector_2_157.csv',
#  'sector_6_157.csv',
#  'sector_3_96.csv',
#  'sector_2_149.csv',
#  'sector_1_440.csv',
#  'sector_2_444.csv',
#  'sector_1_500.csv',
#  'sector_6_458.csv',
#  'sector_1_314.csv',
#  'sector_2_6.csv',
#  'sector_6_345.csv',
#  'sector_6_233.csv',
#  'sector_6_261.csv',
#  'sector_3_334.csv',
#  'sector_4_462.csv',
#  'sector_4_419.csv',
#  'sector_4_277.csv',
#  'sector_6_433.csv',
#  'sector_2_139.csv',
#  'sector_3_437.csv',
#  'sector_2_89.csv',
#  'sector_5_483.csv',
#  'sector_3_86.csv',
#  'sector_1_47.csv',
#  'sector_4_305.csv',
#  'sector_5_255.csv',
#  'sector_5_360.csv',
#  'sector_5_294.csv',
#  'sector_5_130.csv',
#  'sector_6_63.csv',
#  'sector_2_189.csv',
#  'sector_2_272.csv',
#  'sector_3_307.csv',
#  'sector_4_346.csv',
#  'sector_4_260.csv',
#  'sector_4_511.csv',
#  'sector_5_473.csv',
#  'sector_3_295.csv',
#  'sector_3_173.csv',
#  'sector_6_132.csv',
#  'sector_5_156.csv',
#  'sector_2_370.csv',
#  'sector_6_489.csv',
#  'sector_1_161.csv',
#  'sector_4_162.csv',
#  'sector_2_310.csv',
#  'sector_5_441.csv',
#  'sector_5_330.csv',
#  'sector_6_484.csv',
#  'sector_6_389.csv',
#  'sector_4_388.csv',
#  'sector_5_370.csv',
#  'sector_3_336.csv',
#  'sector_5_37.csv',
#  'sector_5_438.csv',
#  'sector_4_267.csv',
#  'sector_3_140.csv',
#  'sector_4_412.csv',
#  'sector_2_239.csv',
#  'sector_6_357.csv',
#  'sector_6_308.csv',
#  'sector_6_358.csv',
#  'sector_6_337.csv',
#  'sector_5_508.csv',
#  'sector_2_403.csv',
#  'sector_6_154.csv',
#  'sector_3_65.csv',
#  'sector_3_244.csv',
#  'sector_4_109.csv',
#  'sector_5_433.csv',
#  'sector_3_187.csv',
#  'sector_3_417.csv',
#  'sector_6_79.csv',
#  'sector_4_93.csv',
#  'sector_2_156.csv',
#  'sector_1_336.csv',
#  'sector_4_144.csv',
#  'sector_6_422.csv',
#  'sector_3_13.csv',
#  'sector_6_480.csv',
#  'sector_1_143.csv',
#  'sector_4_173.csv',
#  'sector_3_110.csv',
#  'sector_1_384.csv',
#  'sector_3_276.csv',
#  'sector_1_295.csv',
#  'sector_6_195.csv',
#  'sector_1_6.csv',
#  'sector_6_479.csv',
#  'sector_5_490.csv',
#  'sector_2_351.csv',
#  'sector_2_210.csv',
#  'sector_3_504.csv',
#  'sector_3_20.csv',
#  'sector_4_368.csv',
#  'sector_2_307.csv',
#  'sector_3_17.csv',
#  'sector_3_162.csv',
#  'sector_4_208.csv',
#  'sector_3_440.csv',
#  'sector_1_407.csv',
#  'sector_5_59.csv',
#  'sector_6_510.csv',
#  'sector_6_347.csv',
#  'sector_1_451.csv',
#  'sector_1_470.csv',
#  'sector_5_6.csv',
#  'sector_1_447.csv',
#  'sector_4_52.csv',
#  'sector_5_238.csv',
#  'sector_1_306.csv',
#  'sector_2_3.csv',
#  'sector_3_325.csv',
#  'sector_3_296.csv',
#  'sector_2_505.csv',
#  'sector_5_12.csv',
#  'sector_2_389.csv',
#  'sector_4_82.csv',
#  'sector_1_95.csv',
#  'sector_6_501.csv',
#  'sector_1_425.csv',
#  'sector_4_424.csv',
#  'sector_5_214.csv',
#  'sector_3_153.csv',
#  'sector_3_477.csv',
#  'sector_2_482.csv',
#  'sector_1_266.csv',
#  'sector_5_314.csv',
#  'sector_2_297.csv',
#  'sector_5_140.csv',
#  'sector_6_4.csv',
#  'sector_3_349.csv',
#  'sector_6_216.csv',
#  'sector_2_220.csv',
#  'sector_1_337.csv',
#  'sector_3_502.csv',
#  'sector_5_369.csv',
#  'sector_2_376.csv',
#  'sector_1_219.csv',
#  'sector_6_187.csv',
#  'sector_6_332.csv',
#  'sector_2_388.csv',
#  'sector_3_389.csv',
#  'sector_1_132.csv',
#  'sector_5_151.csv',
#  'sector_3_30.csv',
#  'sector_3_274.csv',
#  'sector_2_79.csv',
#  'sector_1_236.csv',
#  'sector_2_47.csv',
#  'sector_2_81.csv',
#  'sector_1_442.csv',
#  'sector_6_274.csv',
#  'sector_4_184.csv',
#  'sector_3_216.csv',
#  'sector_6_259.csv',
#  'sector_1_155.csv',
#  'sector_2_320.csv',
#  'sector_6_367.csv',
#  'sector_3_181.csv',
#  'sector_5_199.csv',
#  'sector_1_163.csv',
#  'sector_3_271.csv',
#  'sector_4_259.csv',
#  'sector_1_458.csv',
#  'sector_1_444.csv',
#  'sector_2_410.csv',
#  'sector_3_109.csv',
#  'sector_2_238.csv',
#  'sector_3_390.csv',
#  'sector_4_444.csv',
#  'sector_4_83.csv',
#  'sector_3_225.csv',
#  'sector_3_300.csv',
#  'sector_5_494.csv',
#  'sector_2_436.csv',
#  'sector_6_511.csv',
#  'sector_5_249.csv',
#  'sector_6_415.csv',
#  'sector_2_473.csv',
#  'sector_1_255.csv',
#  'sector_4_22.csv',
#  'sector_3_311.csv',
#  'sector_4_233.csv',
#  'sector_1_127.csv',
#  'sector_6_159.csv',
#  'sector_5_365.csv',
#  'sector_4_247.csv',
#  'sector_2_140.csv',
#  'sector_2_252.csv',
#  'sector_4_24.csv',
#  'sector_6_77.csv',
#  'sector_6_293.csv',
#  'sector_1_329.csv',
#  'sector_6_496.csv',
#  'sector_6_497.csv',
#  'sector_4_70.csv',
#  'sector_4_309.csv',
#  'sector_5_345.csv',
#  'sector_5_206.csv',
#  'sector_5_76.csv',
#  'sector_2_112.csv',
#  'sector_4_248.csv',
#  'sector_4_73.csv',
#  'sector_1_205.csv',
#  'sector_4_358.csv',
#  'sector_4_189.csv',
#  'sector_1_269.csv',
#  'sector_3_503.csv',
#  'sector_4_241.csv',
#  'sector_2_216.csv',
#  'sector_2_335.csv',
#  'sector_5_361.csv',
#  'sector_5_489.csv',
#  'sector_6_42.csv',
#  'sector_3_114.csv',
#  'sector_3_176.csv',
#  'sector_2_21.csv',
#  'sector_4_430.csv',
#  'sector_1_17.csv',
#  'sector_1_203.csv',
#  'sector_4_348.csv',
#  'sector_4_249.csv',
#  'sector_3_143.csv',
#  'sector_1_82.csv',
#  'sector_1_462.csv',
#  'sector_2_177.csv',
#  'sector_4_472.csv',
#  'sector_3_92.csv',
#  'sector_4_234.csv',
#  'sector_3_26.csv',
#  'sector_6_319.csv',
#  'sector_3_67.csv',
#  'sector_6_20.csv',
#  'sector_2_20.csv',
#  'sector_1_210.csv',
#  'sector_5_304.csv',
#  'sector_6_334.csv',
#  'sector_3_453.csv',
#  'sector_3_353.csv',
#  'sector_3_476.csv',
#  'sector_5_446.csv',
#  'sector_6_102.csv',
#  'sector_1_23.csv',
#  'sector_5_196.csv',
#  'sector_3_40.csv',
#  'sector_1_411.csv',
#  'sector_1_91.csv',
#  'sector_6_8.csv',
#  'sector_4_23.csv',
#  'sector_1_479.csv',
#  'sector_3_338.csv',
#  'sector_2_108.csv',
#  'sector_3_94.csv',
#  'sector_1_454.csv',
#  'sector_3_291.csv',
#  'sector_2_451.csv',
#  'sector_6_455.csv',
#  'sector_4_2.csv',
#  'sector_3_123.csv',
#  'sector_2_368.csv',
#  'sector_6_321.csv',
#  'sector_6_191.csv',
#  'sector_6_161.csv',
#  'sector_2_442.csv',
#  'sector_4_365.csv',
#  'sector_2_9.csv',
#  'sector_5_154.csv',
#  'sector_4_137.csv',
#  'sector_4_13.csv',
#  'sector_2_333.csv',
#  'sector_1_359.csv',
#  'sector_3_31.csv',
#  'sector_3_341.csv',
#  'sector_1_70.csv',
#  'sector_6_360.csv',
#  'sector_2_36.csv',
#  'sector_2_22.csv',
#  'sector_6_127.csv',
#  'sector_5_144.csv',
#  'sector_5_274.csv',
#  'sector_6_470.csv',
#  'sector_3_62.csv',
#  'sector_1_258.csv',
#  'sector_4_495.csv',
#  'sector_5_325.csv',
#  'sector_5_53.csv',
#  'sector_1_333.csv',
#  'sector_3_11.csv',
#  'sector_6_406.csv',
#  'sector_3_411.csv',
#  'sector_3_459.csv',
#  'sector_4_298.csv',
#  'sector_1_153.csv',
#  'sector_5_127.csv',
#  'sector_5_372.csv',
#  'sector_1_294.csv',
#  'sector_3_421.csv',
#  'sector_2_133.csv',
#  'sector_1_483.csv',
#  'sector_5_289.csv',
#  'sector_2_126.csv',
#  'sector_2_162.csv',
#  'sector_3_480.csv',
#  'sector_5_281.csv',
#  'sector_5_186.csv',
#  'sector_4_16.csv',
#  'systematics_6.csv',
#  'sector_6_170.csv',
#  'sector_4_130.csv',
#  'sector_3_351.csv',
#  'sector_4_373.csv',
#  'sector_1_484.csv',
#  'sector_3_179.csv',
#  'sector_1_362.csv',
#  'sector_5_92.csv',
#  'sector_1_370.csv',
#  'sector_1_467.csv',
#  'sector_2_17.csv',
#  'sector_5_1.csv',
#  'sector_2_465.csv',
#  'sector_2_427.csv',
#  'sector_1_300.csv',
#  'sector_4_264.csv',
#  'sector_6_382.csv',
#  'sector_6_275.csv',
#  'sector_4_352.csv',
#  'sector_1_510.csv',
#  'sector_1_318.csv',
#  'sector_1_189.csv',
#  'sector_4_156.csv',
#  'sector_2_197.csv',
#  'sector_4_278.csv',
#  'sector_5_455.csv',
#  'sector_6_450.csv',
#  'sector_4_372.csv',
#  'sector_1_353.csv',
#  'sector_1_296.csv',
#  'sector_4_291.csv',
#  'sector_6_14.csv',
#  'sector_2_58.csv',
#  'sector_6_237.csv',
#  'sector_2_417.csv',
#  'sector_2_38.csv',
#  'sector_5_324.csv',
#  'sector_2_200.csv',
#  'sector_4_316.csv',
#  'sector_6_81.csv',
#  'sector_6_432.csv',
#  'sector_2_340.csv',
#  'sector_5_390.csv',
#  'sector_6_338.csv',
#  'sector_2_313.csv',
#  'sector_3_233.csv',
#  'sector_5_165.csv',
#  'sector_4_320.csv',
#  'sector_3_93.csv',
#  'sector_6_41.csv',
#  'sector_6_410.csv',
#  'sector_4_275.csv',
#  'sector_4_33.csv',
#  'sector_1_148.csv',
#  'sector_3_197.csv',
#  'sector_4_446.csv',
#  'sector_2_99.csv',
#  'sector_5_381.csv',
#  'sector_4_55.csv',
#  'sector_2_262.csv',
#  'sector_5_143.csv',
#  'sector_3_23.csv',
#  'sector_4_133.csv',
#  'sector_3_256.csv',
#  'sector_1_191.csv',
#  'sector_3_119.csv',
#  'sector_1_368.csv',
#  'sector_1_222.csv',
#  'sector_5_5.csv',
#  'sector_6_414.csv',
#  'sector_2_206.csv',
#  'sector_6_475.csv',
#  'sector_2_266.csv',
#  'sector_4_301.csv',
#  'sector_1_486.csv',
#  'sector_2_490.csv',
#  'sector_3_9.csv',
#  'sector_6_370.csv',
#  'sector_5_484.csv',
#  'sector_5_204.csv',
#  'sector_5_286.csv',
#  'sector_6_145.csv',
#  'sector_1_316.csv',
#  'sector_5_506.csv',
#  'sector_6_281.csv',
#  'sector_4_200.csv',
#  'sector_3_82.csv',
#  'sector_2_359.csv',
#  'sector_5_431.csv',
#  'sector_2_470.csv',
#  'sector_4_221.csv',
#  'sector_4_501.csv',
#  'sector_1_76.csv',
#  'sector_4_122.csv',
#  'sector_2_406.csv',
#  'sector_2_402.csv',
#  'sector_6_354.csv',
#  'sector_3_25.csv',
#  'sector_5_486.csv',
#  'sector_5_477.csv',
#  'sector_6_37.csv',
#  'sector_3_74.csv',
#  'sector_2_230.csv',
#  'sector_3_236.csv',
#  'sector_2_219.csv',
#  'sector_2_159.csv',
#  'sector_5_284.csv',
#  'sector_5_461.csv',
#  'sector_6_256.csv',
#  'sector_6_180.csv',
#  'sector_6_91.csv',
#  'sector_1_421.csv',
#  'sector_2_260.csv',
#  'sector_4_150.csv',
#  'sector_2_408.csv',
#  'sector_2_506.csv',
#  'sector_1_373.csv',
#  'sector_1_232.csv',
#  'sector_1_195.csv',
#  'sector_4_196.csv',
#  'sector_4_499.csv',
#  'sector_1_422.csv',
#  'sector_5_384.csv',
#  'sector_3_2.csv',
#  'sector_4_27.csv',
#  'sector_5_148.csv',
#  'sector_2_460.csv',
#  'sector_2_469.csv',
#  'sector_3_78.csv',
#  'sector_5_392.csv',
#  'sector_6_419.csv',
#  'sector_2_387.csv',
#  'sector_5_39.csv',
#  'sector_2_196.csv',
#  'sector_1_217.csv',
#  'sector_2_119.csv',
#  'sector_3_509.csv',
#  'sector_2_211.csv',
#  'sector_2_80.csv',
#  'sector_4_403.csv',
#  'sector_3_97.csv',
#  'sector_6_205.csv',
#  'sector_6_424.csv',
#  'sector_5_373.csv',
#  'sector_5_71.csv',
#  'sector_5_183.csv',
#  'sector_2_236.csv',
#  'sector_4_308.csv',
#  'sector_1_406.csv',
#  'sector_1_449.csv',
#  'sector_2_51.csv',
#  'sector_4_282.csv',
#  'sector_5_79.csv',
#  'sector_3_407.csv',
#  'sector_1_94.csv',
#  'sector_1_22.csv',
#  'sector_2_129.csv',
#  'sector_4_306.csv',
#  'sector_5_43.csv',
#  'sector_2_277.csv',
#  'sector_4_461.csv',
#  'sector_2_181.csv',
#  'sector_5_348.csv',
#  'sector_1_452.csv',
#  'sector_4_86.csv',
#  'sector_6_303.csv',
#  'sector_6_270.csv',
#  'systematics_5.csv',
#  'sector_2_467.csv',
#  'sector_1_399.csv',
#  'sector_2_167.csv',
#  'sector_4_17.csv',
#  'sector_1_149.csv',
#  'sector_3_127.csv',
#  'sector_3_227.csv',
#  'sector_6_55.csv',
#  'sector_3_345.csv',
#  'sector_2_300.csv',
#  'sector_4_464.csv',
#  'sector_5_347.csv',
#  'sector_2_152.csv',
#  'sector_1_107.csv',
#  'sector_3_386.csv',
#  'sector_1_414.csv',
#  'sector_1_508.csv',
#  'sector_1_14.csv',
#  'sector_1_331.csv',
#  'sector_4_377.csv',
#  'sector_2_57.csv',
#  'sector_5_20.csv',
#  'sector_1_212.csv',
#  'sector_1_129.csv',
#  'sector_3_39.csv',
#  'sector_5_236.csv',
#  'sector_1_377.csv',
#  'sector_5_412.csv',
#  'sector_6_379.csv',
#  'sector_2_15.csv',
#  'sector_4_434.csv',
#  'sector_3_369.csv',
#  'sector_1_443.csv',
#  'sector_2_501.csv',
#  'sector_4_354.csv',
#  'sector_6_466.csv',
#  'sector_4_152.csv',
#  'sector_1_473.csv',
#  'sector_3_71.csv',
#  'sector_6_75.csv',
#  'sector_4_120.csv',
#  'sector_6_390.csv',
#  'sector_3_435.csv',
#  'sector_4_307.csv',
#  'sector_3_125.csv',
#  'sector_5_358.csv',
#  'sector_3_361.csv',
#  'sector_4_69.csv',
#  'sector_2_337.csv',
#  'sector_2_395.csv',
#  'sector_3_304.csv',
#  'sector_6_185.csv',
#  'sector_1_492.csv',
#  'sector_3_205.csv',
#  'sector_4_213.csv',
#  'sector_5_475.csv',
#  'sector_3_414.csv',
#  'sector_1_403.csv',
#  'sector_6_403.csv',
#  'sector_2_101.csv',
#  'sector_1_240.csv',
#  'sector_5_375.csv',
#  'sector_5_56.csv',
#  'sector_2_246.csv',
#  'sector_4_178.csv',
#  'sector_6_509.csv',
#  'sector_3_461.csv',
#  'sector_5_248.csv',
#  'sector_4_183.csv',
#  'sector_2_279.csv',
#  'sector_3_297.csv',
#  'sector_4_9.csv',
#  'sector_6_67.csv',
#  'sector_2_4.csv',
#  'sector_4_60.csv',
#  'sector_2_463.csv',
#  'sector_1_36.csv',
#  'sector_2_425.csv',
#  'sector_2_409.csv',
#  'sector_1_99.csv',
#  'sector_3_272.csv',
#  'sector_2_54.csv',
#  'sector_4_303.csv',
#  'sector_3_243.csv',
#  'sector_3_327.csv',
#  'sector_1_253.csv',
#  'sector_1_154.csv',
#  'sector_1_494.csv',
#  'sector_2_321.csv',
#  'sector_6_478.csv',
#  'sector_2_48.csv',
#  'sector_6_355.csv',
#  'sector_6_491.csv',
#  'sector_2_165.csv',
#  'sector_4_466.csv',
#  'sector_6_473.csv',
#  'sector_5_401.csv',
#  'sector_3_247.csv',
#  'sector_1_28.csv',
#  'sector_5_68.csv',
#  'sector_4_132.csv',
#  'sector_6_194.csv',
#  'sector_6_192.csv',
#  'sector_3_410.csv',
#  'sector_3_107.csv',
#  'sector_4_456.csv',
#  'sector_3_340.csv',
#  'sector_5_38.csv',
#  'sector_5_7.csv',
#  'sector_4_510.csv',
#  'sector_2_231.csv',
#  'sector_1_289.csv',
#  'sector_4_141.csv',
#  'sector_3_66.csv',
#  'sector_2_111.csv',
#  'sector_2_65.csv',
#  'sector_4_386.csv',
#  'sector_2_113.csv',
#  'sector_6_158.csv',
#  'sector_4_37.csv',
#  'sector_4_323.csv',
#  'sector_1_284.csv',
#  'sector_2_478.csv',
#  'sector_3_59.csv',
#  'sector_4_29.csv',
#  'sector_2_394.csv',
#  'sector_5_104.csv',
#  'sector_3_354.csv',
#  'sector_6_494.csv',
#  'sector_4_243.csv',
#  'sector_2_353.csv',
#  'sector_1_178.csv',
#  'sector_4_402.csv',
#  'sector_2_369.csv',
#  'sector_5_161.csv',
#  'sector_4_471.csv',
#  'sector_4_206.csv',
#  'sector_4_110.csv',
#  'sector_3_0.csv',
#  'sector_1_427.csv',
#  'sector_6_399.csv',
#  'sector_4_481.csv',
#  'sector_3_315.csv',
#  'sector_4_212.csv',
#  'sector_1_416.csv',
#  'sector_6_51.csv',
#  'sector_6_173.csv',
#  'sector_4_355.csv',
#  'sector_4_47.csv',
#  'sector_4_413.csv',
#  'sector_5_322.csv',
#  'sector_1_346.csv',
#  'sector_5_432.csv',
#  'sector_5_276.csv',
#  'sector_6_467.csv',
#  'sector_1_40.csv',
#  'sector_4_255.csv',
#  'sector_5_189.csv',
#  'sector_6_271.csv',
#  'sector_1_322.csv',
#  'sector_6_188.csv',
#  'sector_4_186.csv',
#  'sector_2_13.csv',
#  'sector_6_175.csv',
#  'sector_6_142.csv',
#  'sector_3_486.csv',
#  'sector_5_450.csv',
#  'sector_6_448.csv',
#  'sector_3_48.csv',
#  'sector_5_332.csv',
#  'sector_1_59.csv',
#  'sector_1_412.csv',
#  'sector_6_442.csv',
#  'sector_1_397.csv',
#  'sector_5_296.csv',
#  'sector_6_459.csv',
#  'sector_2_67.csv',
#  'sector_2_2.csv',
#  'sector_6_302.csv',
#  'sector_1_109.csv',
#  'sector_3_147.csv',
#  'sector_5_155.csv',
#  'sector_6_108.csv',
#  'sector_2_332.csv',
#  'sector_3_400.csv',
#  'sector_2_245.csv',
#  'sector_2_390.csv',
#  'sector_1_305.csv',
#  'sector_1_180.csv',
#  'sector_1_44.csv',
#  'sector_1_455.csv',
#  'sector_1_185.csv',
#  'sector_3_16.csv',
#  'sector_6_378.csv',
#  'sector_1_257.csv',
#  'sector_4_438.csv',
#  'sector_4_7.csv',
#  'sector_4_232.csv',
#  'sector_5_471.csv',
#  'sector_1_175.csv',
#  'sector_5_293.csv',
#  'sector_1_478.csv',
#  'sector_5_107.csv',
#  'sector_2_475.csv',
#  'sector_6_255.csv',
#  'sector_6_486.csv',
#  'sector_3_266.csv',
#  'sector_1_391.csv',
#  'sector_2_322.csv',
#  'sector_3_322.csv',
#  'sector_5_77.csv',
#  'sector_2_93.csv',
#  'sector_6_35.csv',
#  'sector_1_126.csv',
#  'sector_3_277.csv',
#  'sector_5_303.csv',
#  'sector_1_164.csv',
#  'sector_4_20.csv',
#  'sector_3_208.csv',
#  'sector_2_304.csv',
#  'sector_2_349.csv',
#  'sector_4_74.csv',
#  'sector_5_245.csv',
#  'sector_4_34.csv',
#  'sector_5_48.csv',
#  'sector_4_296.csv',
#  'sector_4_124.csv',
#  'sector_5_145.csv',
#  'sector_6_136.csv',
#  'sector_4_176.csv',
#  'sector_3_294.csv',
#  'sector_3_211.csv',
#  'sector_6_190.csv',
#  'sector_2_153.csv',
#  'sector_2_227.csv',
#  'sector_6_244.csv',
#  'sector_5_19.csv',
#  'sector_3_113.csv',
#  'sector_4_44.csv',
#  'sector_1_323.csv',
#  'sector_4_38.csv',
#  'sector_2_154.csv',
#  'sector_3_159.csv',
#  'sector_4_1.csv',
#  'sector_6_362.csv',
#  'sector_3_358.csv',
#  'sector_6_84.csv',
#  'sector_5_202.csv',
#  'sector_2_18.csv',
#  'sector_2_92.csv',
#  'sector_5_137.csv',
#  'sector_1_140.csv',
#  'sector_5_323.csv',
#  'sector_3_117.csv',
#  'sector_2_87.csv',
#  'sector_3_204.csv',
#  'sector_4_294.csv',
#  'sector_4_179.csv',
#  'sector_4_321.csv',
#  'sector_6_400.csv',
#  'sector_5_90.csv',
#  'sector_3_467.csv',
#  'sector_4_459.csv',
#  'sector_2_109.csv',
#  'sector_6_352.csv',
#  'sector_2_496.csv',
#  'sector_1_338.csv',
#  'sector_1_177.csv',
#  'sector_6_139.csv',
#  'sector_2_293.csv',
#  'sector_4_240.csv',
#  'sector_3_388.csv',
#  'sector_4_11.csv',
#  'sector_2_317.csv',
#  'sector_3_426.csv',
#  'sector_3_36.csv',
#  'sector_3_424.csv',
#  'sector_3_101.csv',
#  'sector_4_80.csv',
#  'sector_2_329.csv',
#  'sector_3_150.csv',
#  'sector_2_96.csv',
#  'sector_1_192.csv',
#  'sector_1_268.csv',
#  'sector_1_389.csv',
#  'sector_5_464.csv',
#  'sector_4_217.csv',
#  'sector_6_141.csv',
#  'sector_1_249.csv',
#  'sector_2_255.csv',
#  'sector_6_258.csv',
#  'sector_5_502.csv',
#  'sector_1_75.csv',
#  'sector_5_95.csv',
#  'sector_3_275.csv',
#  'sector_2_375.csv',
#  'sector_1_234.csv',
#  'sector_5_126.csv',
#  'sector_4_483.csv',
#  'sector_1_57.csv',
#  'sector_4_304.csv',
#  'sector_6_326.csv',
#  'sector_6_251.csv',
#  'sector_2_130.csv',
#  'sector_6_56.csv',
#  'sector_5_223.csv',
#  'sector_2_504.csv',
#  'sector_3_191.csv',
#  'sector_1_301.csv',
#  'sector_2_77.csv',
#  'sector_2_60.csv',
#  'sector_2_28.csv',
#  'sector_3_469.csv',
#  'sector_5_343.csv',
#  'sector_3_451.csv',
#  'sector_3_160.csv',
#  'sector_5_496.csv',
#  'sector_6_122.csv',
#  'sector_2_52.csv',
#  'sector_4_160.csv',
#  'sector_5_418.csv',
#  'sector_1_184.csv',
#  'sector_6_48.csv',
#  'sector_2_426.csv',
#  'sector_6_344.csv',
#  'sector_1_152.csv',
#  'sector_6_287.csv',
#  'sector_3_144.csv',
#  'sector_5_159.csv',
#  'sector_5_46.csv',
#  'sector_4_478.csv',
#  'sector_6_482.csv',
#  'sector_6_7.csv',
#  'sector_3_332.csv',
#  'sector_4_155.csv',
#  'sector_5_437.csv',
#  'sector_4_335.csv',
#  'sector_6_44.csv',
#  'sector_1_46.csv',
#  'sector_1_15.csv',
#  'sector_3_185.csv',
#  'sector_1_392.csv',
#  'sector_5_253.csv',
#  'sector_3_57.csv',
#  'sector_5_101.csv',
#  'sector_5_173.csv',
#  'sector_5_371.csv',
#  'sector_3_170.csv',
#  'sector_2_83.csv',
#  'sector_3_394.csv',
#  'sector_2_418.csv',
#  'sector_5_400.csv',
#  'sector_3_103.csv',
#  'sector_6_95.csv',
#  'sector_3_374.csv',
#  'sector_3_88.csv',
#  'sector_4_332.csv',
#  'sector_2_137.csv',
#  'sector_4_100.csv',
#  'sector_3_134.csv',
#  'sector_1_167.csv',
#  'sector_5_201.csv',
#  'sector_6_324.csv',
#  'sector_4_367.csv',
#  'sector_3_329.csv',
#  'sector_6_184.csv',
#  'sector_3_224.csv',
#  'sector_3_395.csv',
#  'sector_3_408.csv',
#  'sector_2_117.csv',
#  'sector_2_346.csv',
#  'sector_2_386.csv',
#  'sector_1_68.csv',
#  'sector_2_228.csv',
#  'sector_1_302.csv',
#  'sector_5_363.csv',
#  'sector_3_51.csv',
#  'sector_3_460.csv',
#  'sector_4_165.csv',
#  'sector_6_387.csv',
#  'sector_5_33.csv',
#  'sector_1_5.csv',
#  'sector_5_74.csv',
#  'sector_4_506.csv',
#  'sector_6_228.csv',
#  'sector_4_330.csv',
#  'sector_2_184.csv',
#  'sector_4_507.csv',
#  'sector_5_208.csv',
#  'sector_2_259.csv',
#  'sector_5_449.csv',
#  'sector_4_149.csv',
#  'sector_1_34.csv',
#  'sector_5_295.csv',
#  'sector_3_458.csv',
#  'sector_5_36.csv',
#  'sector_1_506.csv',
#  'sector_4_371.csv',
#  'sector_2_282.csv',
#  'sector_6_318.csv',
#  'sector_4_312.csv',
#  'sector_5_261.csv',
#  'sector_4_407.csv',
#  'sector_6_325.csv',
#  'sector_6_217.csv',
#  'sector_5_8.csv',
#  'sector_1_394.csv',
#  'sector_5_266.csv',
#  'sector_5_269.csv',
#  'sector_2_374.csv',
#  'sector_4_228.csv',
#  'sector_1_62.csv',
#  'sector_1_344.csv',
#  'sector_1_7.csv',
#  'sector_3_303.csv',
#  'sector_3_422.csv',
#  'sector_3_428.csv',
#  'sector_4_436.csv',
#  'sector_6_439.csv',
#  'sector_5_505.csv',
#  'sector_4_329.csv',
#  'sector_6_306.csv',
#  'sector_6_313.csv',
#  'sector_6_222.csv',
#  'sector_2_341.csv',
#  'sector_4_63.csv',
#  'sector_6_111.csv',
#  'sector_4_423.csv',
#  'sector_4_39.csv',
#  'sector_5_222.csv',
#  'sector_4_286.csv',
#  'sector_5_207.csv',
#  'sector_2_142.csv',
#  'sector_5_180.csv',
#  'sector_5_501.csv',
#  'sector_4_356.csv',
#  'sector_4_405.csv',
#  'sector_5_185.csv',
#  'sector_4_445.csv',
#  'sector_3_245.csv',
#  'sector_2_62.csv',
#  'sector_6_242.csv',
#  'sector_5_210.csv',
#  'sector_6_342.csv',
#  'sector_6_333.csv',
#  'sector_2_24.csv',
#  'sector_4_194.csv',
#  'sector_5_227.csv',
#  'sector_5_299.csv',
#  'sector_6_372.csv',
#  'sector_2_459.csv',
#  'sector_2_122.csv',
#  'sector_4_166.csv',
#  'sector_5_435.csv',
#  'sector_5_167.csv',
#  'sector_3_363.csv',
#  'sector_1_24.csv',
#  'sector_2_84.csv',
#  'sector_5_22.csv',
#  'sector_6_359.csv',
#  'sector_4_56.csv',
#  'sector_1_89.csv',
#  'sector_4_398.csv',
#  ...]

# %%
data = {}

for sector in range(1,7):
    data[sector] = []
    
    for f in glob.glob('../database/phi/random/sector_{}_*'.format(sector)):
        data[sector].append(pd.read_csv(f))

# %%
data[1][0]
# Out:
#     axis  axis_bin  axis_max  axis_min  counts_neg  counts_pos    phi  \
# 0      x         0  0.178027  0.106815        1488        1559 -165.0
# 1      x         0  0.178027  0.106815         776         780 -135.0
# 2      x         0  0.178027  0.106815        1282        1326 -105.0
# 3      x         0  0.178027  0.106815         819         785  -75.0
# 4      x         0  0.178027  0.106815         811         767  -45.0
# ..   ...       ...       ...       ...         ...         ...    ...
# 235   q2         4  4.740613  2.320887         624         644   45.0
# 236   q2         4  4.740613  2.320887        1015        1020   75.0
# 237   q2         4  4.740613  2.320887        1055        1155  105.0
# 238   q2         4  4.740613  2.320887        1114        1143  135.0
# 239   q2         4  4.740613  2.320887        1842        1770  165.0
#
#      phi_bin      stat     sys_0     value  global_index
# 0          0  0.018107  0.000747  0.031110             0
# 1          1  0.025351  0.000082  0.003432             1
# 2          2  0.019577  0.000541  0.022525             2
# 3          3  0.024959  0.000679 -0.028300             3
# 4          4  0.025156  0.000893 -0.037227             4
# ..       ...       ...       ...       ...           ...
# 235        7  0.028077  0.000505  0.021059            55
# 236        8  0.022167  0.000079  0.003280            56
# 237        9  0.021233  0.001450  0.060412            57
# 238       10  0.021046  0.000412  0.017155            58
# 239       11  0.016633  0.000639 -0.026614            59
#
# [240 rows x 12 columns]

# %%
data[1][3].head(24)
# Out:
#    axis  axis_bin  axis_max  axis_min  counts_neg  counts_pos    phi  phi_bin  \
# 0     x         0  0.178027  0.106815        2118        2267 -165.0        0
# 1     x         0  0.178027  0.106815        1097        1089 -135.0        1
# 2     x         0  0.178027  0.106815        1767        1904 -105.0        2
# 3     x         0  0.178027  0.106815        1156        1117  -75.0        3
# 4     x         0  0.178027  0.106815        1121        1062  -45.0        4
# 5     x         0  0.178027  0.106815         453         523  -15.0        5
# 6     x         0  0.178027  0.106815         490         478   15.0        6
# 7     x         0  0.178027  0.106815         966         999   45.0        7
# 8     x         0  0.178027  0.106815        1000        1047   75.0        8
# 9     x         0  0.178027  0.106815        1765        1816  105.0        9
# 10    x         0  0.178027  0.106815        1072        1117  135.0       10
# 11    x         0  0.178027  0.106815        2159        2153  165.0       11
# 12    x         1  0.227745  0.178027        2374        2328 -165.0        0
# 13    x         1  0.227745  0.178027        1350        1215 -135.0        1
# 14    x         1  0.227745  0.178027        1714        1669 -105.0        2
# 15    x         1  0.227745  0.178027        1402        1308  -75.0        3
# 16    x         1  0.227745  0.178027         965         877  -45.0        4
# 17    x         1  0.227745  0.178027         441         407  -15.0        5
# 18    x         1  0.227745  0.178027         396         456   15.0        6
# 19    x         1  0.227745  0.178027         775         851   45.0        7
# 20    x         1  0.227745  0.178027        1169        1274   75.0        8
# 21    x         1  0.227745  0.178027        1563        1744  105.0        9
# 22    x         1  0.227745  0.178027        1206        1293  135.0       10
# 23    x         1  0.227745  0.178027        2262        2365  165.0       11
#
#         stat     sys_0     value  global_index
# 0   0.015086  0.001089  0.045366             0
# 1   0.021388  0.000117 -0.004886             1
# 2   0.016484  0.001196  0.049826             2
# 3   0.020969  0.000550 -0.022908             3
# 4   0.021389  0.000866 -0.036084             4
# 5   0.031862  0.002298  0.095756             5
# 6   0.032137  0.000397 -0.016551             6
# 7   0.022553  0.000538  0.022422             7
# 8   0.022092  0.000736  0.030655             8
# 9   0.016708  0.000456  0.019014             9
# 10  0.021366  0.000659  0.027446            10
# 11  0.015229  0.000045 -0.001858            11
# 12  0.014582  0.000313 -0.013062            12
# 13  0.019696  0.001686 -0.070269            13
# 14  0.017190  0.000426 -0.017759            14
# 15  0.019189  0.001111 -0.046310            15
# 16  0.023253  0.001531 -0.063784            16
# 17  0.034291  0.001285 -0.053530            17
# 18  0.034108  0.002257  0.094022            18
# 19  0.024751  0.001498  0.062404            19
# 20  0.020199  0.001377  0.057383            20
# 21  0.017343  0.001754  0.073074            21
# 22  0.019982  0.001116  0.046481            22
# 23  0.014695  0.000713  0.029720            23

# %%
data[1][2]['axis'].unique()
# Out:
# array(['x', 'z', 'pt', 'q2'], dtype=object)

# %%
4 * 5 * 12
# Out:
# 240

# %% [markdown]
# ### This Matrix
# 6 - Number of sectors
# 240 - Number of datapoints per trial (per sector)
# 128 - Number of MC trials

# %%
results = np.empty(shape=(6, 240, 512))

# %%
for sector in range(1, 7):
    for subfile in range(512):
        results[sector - 1, :, subfile] = data[sector][subfile]['value']

# %%
results.shape
# Out:
# (6, 240, 512)

# %% [markdown]
# ### Exercise 1:
# Calculate the average value over all trials of the 3rd sector and 12th datapoint.

# %%
np.mean(results[2, 12, :]), np.std(results[2, 12, :])
# Out:
# (-0.02523179253496094, 0.007034994671439596)

# %% [markdown]
# ### Exercise 2:
# Histogram the values for the same datapoint.

# %%
mu = np.mean(results[2, 12, :])
sig = np.std(results[2, 12, :])
plt.hist(results[2, 12, :], bins=np.linspace(mu - 4 * sig, mu + 4 * sig, 40), 
        edgecolor='k');

# %% [markdown]
# ### Exercise 3:
# Create an errorbar plot where the x-axis values are the 240 datapoints and the y-axis displays the mean and std for sector 1.

# %%
s1_mu = np.mean(results, axis = 2)[0]
s1_std = np.std(results, axis = 2)[0]

plt.figure(figsize=(12,6))
plt.errorbar(np.arange(240), s1_mu, s1_std, marker='.', linestyle='')
plt.xlabel('Datapoint')
plt.ylabel('Measured Value (+/- Std. Dev.)')
# Out:
# Text(0, 0.5, 'Measured Value (+/- Std. Dev.)')

# %% [markdown]
# ### Exercise 4:
# Create the same plot as above, but superimpose all sectors.  This will look messy (it's okay).

# %%
mu = np.mean(results, axis = 2)
sig = np.std(results, axis = 2)

plt.figure(figsize=(12,6))

for sector in range(1,7):
    plt.errorbar(np.arange(240), 
                 mu[sector-1], 
                 sig[sector-1], 
                 marker='.', linestyle='')

plt.xlabel('Datapoint')
plt.ylabel('Measured Value (+/- Std. Dev.)')
# Out:
# Text(0, 0.5, 'Measured Value (+/- Std. Dev.)')

# %% [markdown]
# ### Exercise 5:
# For datapoint 15, choose two sectors and create a scatterplot of the results from all random trials.

# %%
plt.scatter(results[1, 15, :], results[2, 15, :], edgecolor='k')
plt.axvline(results[1, 15, :].mean(), alpha=0.6)
plt.axhline(results[2, 15, :].mean(), alpha=0.6)
plt.grid(alpha = 0.5)
plt.title('Sectors 1 ({0:6.4f}) and 2 ({1:6.4f})'.format(
    results[1, 15, :].mean(), results[2, 15, :].mean()
))
# Out:
# Text(0.5, 1.0, 'Sectors 1 (-0.0636) and 2 (0.0054)')

# %% [markdown]
# ### Exercise 6:
# Write a function that performs the above and accepts the sectors and datapoint as arguments.

# %%
def scatter_two_sectors(data, sectors, index, 
                       fig=None, ax=None):
    """ 
    Create a scatterplot of the MC trials 
    for a datapoint given by index.  Return the 
    figure. 
    
    Inputs:
    -------
    data - the results array from above indexed by (sector, datapoint, trial)
    sectors - a tuple of length 2 that specifies the two sectors to compare
    index - the datapoint to plot
    
    Returns: 
    --------
    fig - The figure object for drawing.
    ax - The axis object for drawing. 
    
    """
    
    assert(len(sectors) == 2)
    
    if fig is None:
        fig = plt.figure()
        ax = fig.add_subplot(1,1,1)
    
    if ax is None:
        ax = fig.add_subplot(1,1,1)
        
    ax.scatter(data[sectors[0]-1, index, :], data[sectors[1]-1, index, :], edgecolor='k')
    ax.axvline(data[sectors[0]-1, index, :].mean(), alpha=0.6)
    ax.axhline(data[sectors[1]-1, index, :].mean(), alpha=0.6)
    ax.grid(alpha = 0.5)
    ax.set_title('Sectors {0} ({1:6.4f}) and {2} ({3:6.4f})'.format(
        sectors[0],
        data[sectors[0]-1, index, :].mean(),
        sectors[1],
        data[sectors[1]-1, index, :].mean()
    ))
    
    # Set the scale for both axes the same so that
    # if there is disagreement the y-sector will be 
    # offset. 
    axisrange = (np.mean(data[sectors[0]-1, index, :]) - 12 * np.std(data[sectors[0]-1, index, :]),
                 np.mean(data[sectors[0]-1, index, :]) + 12 * np.std(data[sectors[0]-1, index, :]))
    ax.set_xlim(axisrange)
    ax.set_ylim(axisrange)
    
    return fig, ax

# %%
fig, ax = scatter_two_sectors(data=results, sectors=(1,2), index=15)

# %% [markdown]
# ### Exercise 7:
# Choose one datapoint and compare all the sectors using the function above.  Plot the results in a grid.

# %%
index = 30

fig = plt.figure(figsize=(24,24))

for isect in range(1,7):
    for jsect in range(1,7):
        iax = (jsect - 1) + 6 * (isect - 1) + 1
        ax = fig.add_subplot(6, 6, iax)
        fig, ax = scatter_two_sectors(data = results, 
                           sectors = (isect, jsect),
                           index = index, fig = fig, ax = ax)
        
fig.tight_layout()

# %%
index = 15

fig = plt.figure(figsize=(24,24))

for isect in range(1,7):
    for jsect in range(1,7):
        iax = (jsect - 1) + 6 * (isect - 1) + 1
        ax = fig.add_subplot(6, 6, iax)
        fig, ax = scatter_two_sectors(data = results, 
                           sectors = (isect, jsect),
                           index = index, fig = fig, ax = ax)
        
fig.tight_layout()

# %%
results_mean = np.mean(results, axis=2)
results_std = np.std(results, axis=2)

# %%
def weighted_chi2(x, xerr):
    weights = 1.0 / xerr**2
    xbar = np.sum(x * weights) / np.sum(weights)
    chi2 = np.sum(weights * (x - xbar)**2)
    return chi2

# %%
psuedo_errors = np.sqrt(np.repeat(0.01, len(results_std[:,0]))**2 + results_std[:,0]**2)

# %%
weighted_chi2(results_mean[:, 0], results_std[:, 0])
# Out:
# 41.19986928306696

# %%
weighted_chi2(results_mean[:, 0], psuedo_errors)
# Out:
# 13.41552330947135

# %%
chi2 = [weighted_chi2(results_mean[:,i], results_std[:,i]) for i in range(240)]
chi2 = np.array(chi2)

# %%
chi2
# Out:
# array([ 41.19986928,  40.20964461,  29.51285756,  34.73950793,
#         15.80517244,  62.74584715,  23.4222195 ,  38.97245895,
#         31.65868691,  28.6884806 ,  17.75602319,  23.64929315,
#         20.85328238,  66.86920154,  18.96551931,  32.02863142,
#          9.71026255,  30.83611439,  64.05332922,  83.66321077,
#         53.67662554,  60.49719026,  10.41435857,  22.05369193,
#         46.94858322, 120.39202661,  30.9499195 ,  55.03952931,
#         32.94409729,  98.09995078,  20.8772987 ,  37.22212444,
#         40.6693973 ,  10.63978392,  15.94669818,  70.86515269,
#         86.30817353,  25.92513888,  12.62274605,  30.95561794,
#         14.13409302,  55.13173071,  32.4494613 ,  13.51640859,
#         44.54145205,  17.63772745,  24.5266294 ,  28.92678599,
#         91.83130038,  62.89019174,  44.85110139,  95.07761662,
#        106.35117178,  35.25008021, 129.11210542,   8.38884361,
#         38.64284225, 114.09541942,  90.10457343, 120.72885728,
#         83.76535155,  31.82805128,  39.61129221,  51.74570399,
#        105.29983835,  80.01235575,  83.65822141, 159.49060856,
#         15.20765641,  43.9814898 ,  50.42252403,  69.85101769,
#         70.76820324, 121.39511381,  58.51134092,  24.66933437,
#         35.11218696,  43.27663282,   3.16578153,  63.44348493,
#         64.93809128,  54.31250043,  28.22810582,  41.54226153,
#         75.22717266,  93.58516762, 104.5155863 ,  24.79378282,
#         32.96226745,  39.13303188,  27.43356905,  74.59809765,
#         27.61605996, 102.23616522,  22.47043597,  56.64808668,
#          9.38031185,  23.42074005,  20.14173625,  37.83798619,
#         23.84485579,  49.69455142, 139.00547984,  17.32004662,
#         22.84675484,   9.18117452,  40.76003214,  37.06089579,
#         36.29261578,  30.88244207,  17.25608791,  45.21731642,
#         21.37162738,  32.35778581,   2.6497423 ,  17.00944668,
#         21.16358167,  25.45738642,  30.00359917,  38.4128771 ,
#        106.64934526, 104.27901624,  17.2250145 ,  13.88203253,
#         40.23837607,  26.15510068,  37.7870405 ,  89.78838788,
#         46.09309918,  31.91626732,  11.18107709,  82.23172218,
#         51.73900474,  27.08526427,  82.18596734,  41.80332834,
#         12.78016552,  50.5184185 ,  14.54832861,  11.2355514 ,
#          7.49535305,  31.46810979,   5.85758346,  84.24966056,
#         45.82894729,  71.65640115,  53.68030786,  51.06937687,
#         31.10251571,  50.00349399,  21.06078903,  80.7535148 ,
#         39.148818  ,  64.34181817,  14.20969622,  31.8247748 ,
#         28.1132592 ,  33.4610422 ,  14.6997806 , 102.2493559 ,
#         60.42616729,  42.63394912,  39.74614047,  49.08147892,
#         24.23177229,  37.81882338,   5.91038775,  25.4842776 ,
#         28.09018304,  38.403173  ,  28.11761193,  46.01098246,
#         38.20444823,  30.33846581,  51.82793162,  21.29582106,
#         20.5480841 ,  49.84404816,  47.20123642,  23.7352326 ,
#         22.36361144,  25.63296304,  41.10508512,  18.70909026,
#         13.59641798,  16.70917137,  15.27847781,  30.62571813,
#         10.41972648,  12.65120976,  20.83463933,   8.35388958,
#         35.03680041,  70.30344608,  13.16531961,  28.50513227,
#         20.35497479,  53.91109458,  58.75228795,  37.45613677,
#         31.16331292,  11.83410941,  49.98136257,  42.04695609,
#         60.26737679,  85.33970464,  69.72387015,  31.2417616 ,
#         37.57011563,  51.03591944,  59.6381869 , 185.05728047,
#         14.49263326,  47.97330532,  58.41940994,  82.25436013,
#         16.52724504,  37.53610029, 101.76757277, 201.40719392,
#        100.72553317,  49.92176385,  22.64934997,  49.38842732,
#        104.75043032,  61.8769808 ,  64.81705461, 130.52257782,
#         94.4948617 ,  48.8038679 ,  15.19737983,  97.09466425,
#        121.25672548,  51.1028537 , 127.10991901,  35.68572141,
#         67.59075709, 116.14999306, 159.02522787, 166.32329764])

# %% [markdown]
# # Save Results

# %%
for isect in range(1,7):
    output = data[isect][0].copy()
    output['mc_mean'] = np.mean(results[isect-1, :, :], axis=1)
    output['mc_std'] = np.std(results[isect-1, :, :], axis=1)
    output.to_csv('../database/phi/random/systematics_{}.csv'.format(isect), index=False)

# %%
os.listdir('../database/phi/random')
# Out:
# ['sector_5_280.csv',
#  'sector_1_60.csv',
#  'sector_2_234.csv',
#  'sector_4_351.csv',
#  'sector_3_21.csv',
#  'sector_3_401.csv',
#  'sector_6_394.csv',
#  'sector_3_234.csv',
#  'sector_2_385.csv',
#  'sector_4_475.csv',
#  'sector_3_427.csv',
#  'sector_2_401.csv',
#  'sector_3_375.csv',
#  'sector_2_429.csv',
#  'sector_4_237.csv',
#  'sector_4_262.csv',
#  'sector_3_87.csv',
#  'sector_6_64.csv',
#  'sector_4_406.csv',
#  'sector_4_421.csv',
#  'sector_3_45.csv',
#  'sector_5_228.csv',
#  'sector_4_487.csv',
#  'sector_4_283.csv',
#  'sector_4_104.csv',
#  'sector_4_258.csv',
#  'sector_5_408.csv',
#  'sector_2_16.csv',
#  'sector_2_8.csv',
#  'systematics_3.csv',
#  'sector_3_365.csv',
#  'sector_6_307.csv',
#  'sector_3_473.csv',
#  'sector_5_241.csv',
#  'sector_6_43.csv',
#  'sector_3_489.csv',
#  'sector_4_169.csv',
#  'sector_6_384.csv',
#  'sector_2_416.csv',
#  'sector_2_208.csv',
#  'sector_6_301.csv',
#  'sector_3_347.csv',
#  'sector_2_380.csv',
#  'sector_4_127.csv',
#  'sector_4_21.csv',
#  'sector_2_263.csv',
#  'sector_1_144.csv',
#  'sector_6_341.csv',
#  'sector_4_343.csv',
#  'sector_6_404.csv',
#  'sector_1_122.csv',
#  'sector_2_138.csv',
#  'sector_6_471.csv',
#  'sector_4_432.csv',
#  'sector_5_364.csv',
#  'sector_5_47.csv',
#  'sector_6_235.csv',
#  'sector_3_383.csv',
#  'sector_1_355.csv',
#  'sector_1_80.csv',
#  'sector_4_31.csv',
#  'sector_2_157.csv',
#  'sector_6_157.csv',
#  'sector_3_96.csv',
#  'sector_2_149.csv',
#  'sector_1_440.csv',
#  'sector_2_444.csv',
#  'sector_1_500.csv',
#  'sector_6_458.csv',
#  'sector_1_314.csv',
#  'sector_2_6.csv',
#  'sector_6_345.csv',
#  'sector_6_233.csv',
#  'sector_6_261.csv',
#  'sector_3_334.csv',
#  'sector_4_462.csv',
#  'sector_4_419.csv',
#  'sector_4_277.csv',
#  'sector_6_433.csv',
#  'sector_2_139.csv',
#  'sector_3_437.csv',
#  'sector_2_89.csv',
#  'sector_5_483.csv',
#  'sector_3_86.csv',
#  'sector_1_47.csv',
#  'sector_4_305.csv',
#  'sector_5_255.csv',
#  'sector_5_360.csv',
#  'sector_5_294.csv',
#  'sector_5_130.csv',
#  'sector_6_63.csv',
#  'sector_2_189.csv',
#  'sector_2_272.csv',
#  'sector_3_307.csv',
#  'sector_4_346.csv',
#  'sector_4_260.csv',
#  'sector_4_511.csv',
#  'sector_5_473.csv',
#  'sector_3_295.csv',
#  'sector_3_173.csv',
#  'sector_6_132.csv',
#  'sector_5_156.csv',
#  'sector_2_370.csv',
#  'sector_6_489.csv',
#  'sector_1_161.csv',
#  'sector_4_162.csv',
#  'sector_2_310.csv',
#  'sector_5_441.csv',
#  'sector_5_330.csv',
#  'sector_6_484.csv',
#  'sector_6_389.csv',
#  'sector_4_388.csv',
#  'sector_5_370.csv',
#  'sector_3_336.csv',
#  'sector_5_37.csv',
#  'sector_5_438.csv',
#  'sector_4_267.csv',
#  'sector_3_140.csv',
#  'sector_4_412.csv',
#  'sector_2_239.csv',
#  'sector_6_357.csv',
#  'sector_6_308.csv',
#  'sector_6_358.csv',
#  'sector_6_337.csv',
#  'sector_5_508.csv',
#  'sector_2_403.csv',
#  'sector_6_154.csv',
#  'sector_3_65.csv',
#  'sector_3_244.csv',
#  'sector_4_109.csv',
#  'sector_5_433.csv',
#  'sector_3_187.csv',
#  'sector_3_417.csv',
#  'sector_6_79.csv',
#  'sector_4_93.csv',
#  'sector_2_156.csv',
#  'sector_1_336.csv',
#  'sector_4_144.csv',
#  'sector_6_422.csv',
#  'sector_3_13.csv',
#  'sector_6_480.csv',
#  'sector_1_143.csv',
#  'sector_4_173.csv',
#  'sector_3_110.csv',
#  'sector_1_384.csv',
#  'sector_3_276.csv',
#  'sector_1_295.csv',
#  'sector_6_195.csv',
#  'sector_1_6.csv',
#  'sector_6_479.csv',
#  'sector_5_490.csv',
#  'sector_2_351.csv',
#  'sector_2_210.csv',
#  'sector_3_504.csv',
#  'sector_3_20.csv',
#  'sector_4_368.csv',
#  'sector_2_307.csv',
#  'sector_3_17.csv',
#  'sector_3_162.csv',
#  'sector_4_208.csv',
#  'sector_3_440.csv',
#  'sector_1_407.csv',
#  'sector_5_59.csv',
#  'sector_6_510.csv',
#  'sector_6_347.csv',
#  'sector_1_451.csv',
#  'sector_1_470.csv',
#  'sector_5_6.csv',
#  'sector_1_447.csv',
#  'sector_4_52.csv',
#  'sector_5_238.csv',
#  'sector_1_306.csv',
#  'sector_2_3.csv',
#  'sector_3_325.csv',
#  'sector_3_296.csv',
#  'sector_2_505.csv',
#  'sector_5_12.csv',
#  'sector_2_389.csv',
#  'sector_4_82.csv',
#  'sector_1_95.csv',
#  'sector_6_501.csv',
#  'sector_1_425.csv',
#  'sector_4_424.csv',
#  'sector_5_214.csv',
#  'sector_3_153.csv',
#  'sector_3_477.csv',
#  'sector_2_482.csv',
#  'sector_1_266.csv',
#  'sector_5_314.csv',
#  'sector_2_297.csv',
#  'sector_5_140.csv',
#  'sector_6_4.csv',
#  'sector_3_349.csv',
#  'sector_6_216.csv',
#  'sector_2_220.csv',
#  'sector_1_337.csv',
#  'sector_3_502.csv',
#  'sector_5_369.csv',
#  'sector_2_376.csv',
#  'sector_1_219.csv',
#  'sector_6_187.csv',
#  'sector_6_332.csv',
#  'sector_2_388.csv',
#  'sector_3_389.csv',
#  'sector_1_132.csv',
#  'sector_5_151.csv',
#  'sector_3_30.csv',
#  'sector_3_274.csv',
#  'sector_2_79.csv',
#  'sector_1_236.csv',
#  'sector_2_47.csv',
#  'sector_2_81.csv',
#  'sector_1_442.csv',
#  'sector_6_274.csv',
#  'sector_4_184.csv',
#  'sector_3_216.csv',
#  'sector_6_259.csv',
#  'sector_1_155.csv',
#  'sector_2_320.csv',
#  'sector_6_367.csv',
#  'sector_3_181.csv',
#  'sector_5_199.csv',
#  'sector_1_163.csv',
#  'sector_3_271.csv',
#  'sector_4_259.csv',
#  'sector_1_458.csv',
#  'sector_1_444.csv',
#  'sector_2_410.csv',
#  'sector_3_109.csv',
#  'sector_2_238.csv',
#  'sector_3_390.csv',
#  'sector_4_444.csv',
#  'sector_4_83.csv',
#  'sector_3_225.csv',
#  'sector_3_300.csv',
#  'sector_5_494.csv',
#  'sector_2_436.csv',
#  'sector_6_511.csv',
#  'sector_5_249.csv',
#  'sector_6_415.csv',
#  'sector_2_473.csv',
#  'sector_1_255.csv',
#  'sector_4_22.csv',
#  'sector_3_311.csv',
#  'sector_4_233.csv',
#  'sector_1_127.csv',
#  'sector_6_159.csv',
#  'sector_5_365.csv',
#  'sector_4_247.csv',
#  'sector_2_140.csv',
#  'sector_2_252.csv',
#  'sector_4_24.csv',
#  'sector_6_77.csv',
#  'sector_6_293.csv',
#  'sector_1_329.csv',
#  'sector_6_496.csv',
#  'sector_6_497.csv',
#  'sector_4_70.csv',
#  'sector_4_309.csv',
#  'sector_5_345.csv',
#  'sector_5_206.csv',
#  'sector_5_76.csv',
#  'sector_2_112.csv',
#  'sector_4_248.csv',
#  'sector_4_73.csv',
#  'sector_1_205.csv',
#  'sector_4_358.csv',
#  'sector_4_189.csv',
#  'sector_1_269.csv',
#  'sector_3_503.csv',
#  'sector_4_241.csv',
#  'sector_2_216.csv',
#  'sector_2_335.csv',
#  'sector_5_361.csv',
#  'sector_5_489.csv',
#  'sector_6_42.csv',
#  'sector_3_114.csv',
#  'sector_3_176.csv',
#  'sector_2_21.csv',
#  'sector_4_430.csv',
#  'sector_1_17.csv',
#  'sector_1_203.csv',
#  'sector_4_348.csv',
#  'sector_4_249.csv',
#  'sector_3_143.csv',
#  'sector_1_82.csv',
#  'sector_1_462.csv',
#  'sector_2_177.csv',
#  'sector_4_472.csv',
#  'sector_3_92.csv',
#  'sector_4_234.csv',
#  'sector_3_26.csv',
#  'sector_6_319.csv',
#  'sector_3_67.csv',
#  'sector_6_20.csv',
#  'sector_2_20.csv',
#  'sector_1_210.csv',
#  'sector_5_304.csv',
#  'sector_6_334.csv',
#  'sector_3_453.csv',
#  'sector_3_353.csv',
#  'sector_3_476.csv',
#  'sector_5_446.csv',
#  'sector_6_102.csv',
#  'sector_1_23.csv',
#  'sector_5_196.csv',
#  'sector_3_40.csv',
#  'sector_1_411.csv',
#  'sector_1_91.csv',
#  'sector_6_8.csv',
#  'sector_4_23.csv',
#  'sector_1_479.csv',
#  'sector_3_338.csv',
#  'sector_2_108.csv',
#  'sector_3_94.csv',
#  'sector_1_454.csv',
#  'sector_3_291.csv',
#  'sector_2_451.csv',
#  'sector_6_455.csv',
#  'sector_4_2.csv',
#  'sector_3_123.csv',
#  'sector_2_368.csv',
#  'sector_6_321.csv',
#  'sector_6_191.csv',
#  'sector_6_161.csv',
#  'sector_2_442.csv',
#  'sector_4_365.csv',
#  'sector_2_9.csv',
#  'sector_5_154.csv',
#  'sector_4_137.csv',
#  'sector_4_13.csv',
#  'sector_2_333.csv',
#  'sector_1_359.csv',
#  'sector_3_31.csv',
#  'sector_3_341.csv',
#  'sector_1_70.csv',
#  'sector_6_360.csv',
#  'sector_2_36.csv',
#  'sector_2_22.csv',
#  'sector_6_127.csv',
#  'sector_5_144.csv',
#  'sector_5_274.csv',
#  'sector_6_470.csv',
#  'sector_3_62.csv',
#  'sector_1_258.csv',
#  'sector_4_495.csv',
#  'sector_5_325.csv',
#  'sector_5_53.csv',
#  'sector_1_333.csv',
#  'sector_3_11.csv',
#  'sector_6_406.csv',
#  'sector_3_411.csv',
#  'sector_3_459.csv',
#  'sector_4_298.csv',
#  'sector_1_153.csv',
#  'sector_5_127.csv',
#  'sector_5_372.csv',
#  'sector_1_294.csv',
#  'sector_3_421.csv',
#  'sector_2_133.csv',
#  'sector_1_483.csv',
#  'sector_5_289.csv',
#  'sector_2_126.csv',
#  'sector_2_162.csv',
#  'sector_3_480.csv',
#  'sector_5_281.csv',
#  'sector_5_186.csv',
#  'sector_4_16.csv',
#  'systematics_6.csv',
#  'sector_6_170.csv',
#  'sector_4_130.csv',
#  'sector_3_351.csv',
#  'sector_4_373.csv',
#  'sector_1_484.csv',
#  'sector_3_179.csv',
#  'sector_1_362.csv',
#  'sector_5_92.csv',
#  'sector_1_370.csv',
#  'sector_1_467.csv',
#  'sector_2_17.csv',
#  'sector_5_1.csv',
#  'sector_2_465.csv',
#  'sector_2_427.csv',
#  'sector_1_300.csv',
#  'sector_4_264.csv',
#  'sector_6_382.csv',
#  'sector_6_275.csv',
#  'sector_4_352.csv',
#  'sector_1_510.csv',
#  'sector_1_318.csv',
#  'sector_1_189.csv',
#  'sector_4_156.csv',
#  'sector_2_197.csv',
#  'sector_4_278.csv',
#  'sector_5_455.csv',
#  'sector_6_450.csv',
#  'sector_4_372.csv',
#  'sector_1_353.csv',
#  'sector_1_296.csv',
#  'sector_4_291.csv',
#  'sector_6_14.csv',
#  'sector_2_58.csv',
#  'sector_6_237.csv',
#  'sector_2_417.csv',
#  'sector_2_38.csv',
#  'sector_5_324.csv',
#  'sector_2_200.csv',
#  'sector_4_316.csv',
#  'sector_6_81.csv',
#  'sector_6_432.csv',
#  'sector_2_340.csv',
#  'sector_5_390.csv',
#  'sector_6_338.csv',
#  'sector_2_313.csv',
#  'sector_3_233.csv',
#  'sector_5_165.csv',
#  'sector_4_320.csv',
#  'sector_3_93.csv',
#  'sector_6_41.csv',
#  'sector_6_410.csv',
#  'sector_4_275.csv',
#  'sector_4_33.csv',
#  'sector_1_148.csv',
#  'sector_3_197.csv',
#  'sector_4_446.csv',
#  'sector_2_99.csv',
#  'sector_5_381.csv',
#  'sector_4_55.csv',
#  'sector_2_262.csv',
#  'sector_5_143.csv',
#  'sector_3_23.csv',
#  'sector_4_133.csv',
#  'sector_3_256.csv',
#  'sector_1_191.csv',
#  'sector_3_119.csv',
#  'sector_1_368.csv',
#  'sector_1_222.csv',
#  'sector_5_5.csv',
#  'sector_6_414.csv',
#  'sector_2_206.csv',
#  'sector_6_475.csv',
#  'sector_2_266.csv',
#  'sector_4_301.csv',
#  'sector_1_486.csv',
#  'sector_2_490.csv',
#  'sector_3_9.csv',
#  'sector_6_370.csv',
#  'sector_5_484.csv',
#  'sector_5_204.csv',
#  'sector_5_286.csv',
#  'sector_6_145.csv',
#  'sector_1_316.csv',
#  'sector_5_506.csv',
#  'sector_6_281.csv',
#  'sector_4_200.csv',
#  'sector_3_82.csv',
#  'sector_2_359.csv',
#  'sector_5_431.csv',
#  'sector_2_470.csv',
#  'sector_4_221.csv',
#  'sector_4_501.csv',
#  'sector_1_76.csv',
#  'sector_4_122.csv',
#  'sector_2_406.csv',
#  'sector_2_402.csv',
#  'sector_6_354.csv',
#  'sector_3_25.csv',
#  'sector_5_486.csv',
#  'sector_5_477.csv',
#  'sector_6_37.csv',
#  'sector_3_74.csv',
#  'sector_2_230.csv',
#  'sector_3_236.csv',
#  'sector_2_219.csv',
#  'sector_2_159.csv',
#  'sector_5_284.csv',
#  'sector_5_461.csv',
#  'sector_6_256.csv',
#  'sector_6_180.csv',
#  'sector_6_91.csv',
#  'sector_1_421.csv',
#  'sector_2_260.csv',
#  'sector_4_150.csv',
#  'sector_2_408.csv',
#  'sector_2_506.csv',
#  'sector_1_373.csv',
#  'sector_1_232.csv',
#  'sector_1_195.csv',
#  'sector_4_196.csv',
#  'sector_4_499.csv',
#  'sector_1_422.csv',
#  'sector_5_384.csv',
#  'sector_3_2.csv',
#  'sector_4_27.csv',
#  'sector_5_148.csv',
#  'sector_2_460.csv',
#  'sector_2_469.csv',
#  'sector_3_78.csv',
#  'sector_5_392.csv',
#  'sector_6_419.csv',
#  'sector_2_387.csv',
#  'sector_5_39.csv',
#  'sector_2_196.csv',
#  'sector_1_217.csv',
#  'sector_2_119.csv',
#  'sector_3_509.csv',
#  'sector_2_211.csv',
#  'sector_2_80.csv',
#  'sector_4_403.csv',
#  'sector_3_97.csv',
#  'sector_6_205.csv',
#  'sector_6_424.csv',
#  'sector_5_373.csv',
#  'sector_5_71.csv',
#  'sector_5_183.csv',
#  'sector_2_236.csv',
#  'sector_4_308.csv',
#  'sector_1_406.csv',
#  'sector_1_449.csv',
#  'sector_2_51.csv',
#  'sector_4_282.csv',
#  'sector_5_79.csv',
#  'sector_3_407.csv',
#  'sector_1_94.csv',
#  'sector_1_22.csv',
#  'sector_2_129.csv',
#  'sector_4_306.csv',
#  'sector_5_43.csv',
#  'sector_2_277.csv',
#  'sector_4_461.csv',
#  'sector_2_181.csv',
#  'sector_5_348.csv',
#  'sector_1_452.csv',
#  'sector_4_86.csv',
#  'sector_6_303.csv',
#  'sector_6_270.csv',
#  'systematics_5.csv',
#  'sector_2_467.csv',
#  'sector_1_399.csv',
#  'sector_2_167.csv',
#  'sector_4_17.csv',
#  'sector_1_149.csv',
#  'sector_3_127.csv',
#  'sector_3_227.csv',
#  'sector_6_55.csv',
#  'sector_3_345.csv',
#  'sector_2_300.csv',
#  'sector_4_464.csv',
#  'sector_5_347.csv',
#  'sector_2_152.csv',
#  'sector_1_107.csv',
#  'sector_3_386.csv',
#  'sector_1_414.csv',
#  'sector_1_508.csv',
#  'sector_1_14.csv',
#  'sector_1_331.csv',
#  'sector_4_377.csv',
#  'sector_2_57.csv',
#  'sector_5_20.csv',
#  'sector_1_212.csv',
#  'sector_1_129.csv',
#  'sector_3_39.csv',
#  'sector_5_236.csv',
#  'sector_1_377.csv',
#  'sector_5_412.csv',
#  'sector_6_379.csv',
#  'sector_2_15.csv',
#  'sector_4_434.csv',
#  'sector_3_369.csv',
#  'sector_1_443.csv',
#  'sector_2_501.csv',
#  'sector_4_354.csv',
#  'sector_6_466.csv',
#  'sector_4_152.csv',
#  'sector_1_473.csv',
#  'sector_3_71.csv',
#  'sector_6_75.csv',
#  'sector_4_120.csv',
#  'sector_6_390.csv',
#  'sector_3_435.csv',
#  'sector_4_307.csv',
#  'sector_3_125.csv',
#  'sector_5_358.csv',
#  'sector_3_361.csv',
#  'sector_4_69.csv',
#  'sector_2_337.csv',
#  'sector_2_395.csv',
#  'sector_3_304.csv',
#  'sector_6_185.csv',
#  'sector_1_492.csv',
#  'sector_3_205.csv',
#  'sector_4_213.csv',
#  'sector_5_475.csv',
#  'sector_3_414.csv',
#  'sector_1_403.csv',
#  'sector_6_403.csv',
#  'sector_2_101.csv',
#  'sector_1_240.csv',
#  'sector_5_375.csv',
#  'sector_5_56.csv',
#  'sector_2_246.csv',
#  'sector_4_178.csv',
#  'sector_6_509.csv',
#  'sector_3_461.csv',
#  'sector_5_248.csv',
#  'sector_4_183.csv',
#  'sector_2_279.csv',
#  'sector_3_297.csv',
#  'sector_4_9.csv',
#  'sector_6_67.csv',
#  'sector_2_4.csv',
#  'sector_4_60.csv',
#  'sector_2_463.csv',
#  'sector_1_36.csv',
#  'sector_2_425.csv',
#  'sector_2_409.csv',
#  'sector_1_99.csv',
#  'sector_3_272.csv',
#  'sector_2_54.csv',
#  'sector_4_303.csv',
#  'sector_3_243.csv',
#  'sector_3_327.csv',
#  'sector_1_253.csv',
#  'sector_1_154.csv',
#  'sector_1_494.csv',
#  'sector_2_321.csv',
#  'sector_6_478.csv',
#  'sector_2_48.csv',
#  'sector_6_355.csv',
#  'sector_6_491.csv',
#  'sector_2_165.csv',
#  'sector_4_466.csv',
#  'sector_6_473.csv',
#  'sector_5_401.csv',
#  'sector_3_247.csv',
#  'sector_1_28.csv',
#  'sector_5_68.csv',
#  'sector_4_132.csv',
#  'sector_6_194.csv',
#  'sector_6_192.csv',
#  'sector_3_410.csv',
#  'sector_3_107.csv',
#  'sector_4_456.csv',
#  'sector_3_340.csv',
#  'sector_5_38.csv',
#  'sector_5_7.csv',
#  'sector_4_510.csv',
#  'sector_2_231.csv',
#  'sector_1_289.csv',
#  'sector_4_141.csv',
#  'sector_3_66.csv',
#  'sector_2_111.csv',
#  'sector_2_65.csv',
#  'sector_4_386.csv',
#  'sector_2_113.csv',
#  'sector_6_158.csv',
#  'sector_4_37.csv',
#  'sector_4_323.csv',
#  'sector_1_284.csv',
#  'sector_2_478.csv',
#  'sector_3_59.csv',
#  'sector_4_29.csv',
#  'sector_2_394.csv',
#  'sector_5_104.csv',
#  'sector_3_354.csv',
#  'sector_6_494.csv',
#  'sector_4_243.csv',
#  'sector_2_353.csv',
#  'sector_1_178.csv',
#  'sector_4_402.csv',
#  'sector_2_369.csv',
#  'sector_5_161.csv',
#  'sector_4_471.csv',
#  'sector_4_206.csv',
#  'sector_4_110.csv',
#  'sector_3_0.csv',
#  'sector_1_427.csv',
#  'sector_6_399.csv',
#  'sector_4_481.csv',
#  'sector_3_315.csv',
#  'sector_4_212.csv',
#  'sector_1_416.csv',
#  'sector_6_51.csv',
#  'sector_6_173.csv',
#  'sector_4_355.csv',
#  'sector_4_47.csv',
#  'sector_4_413.csv',
#  'sector_5_322.csv',
#  'sector_1_346.csv',
#  'sector_5_432.csv',
#  'sector_5_276.csv',
#  'sector_6_467.csv',
#  'sector_1_40.csv',
#  'sector_4_255.csv',
#  'sector_5_189.csv',
#  'sector_6_271.csv',
#  'sector_1_322.csv',
#  'sector_6_188.csv',
#  'sector_4_186.csv',
#  'sector_2_13.csv',
#  'sector_6_175.csv',
#  'sector_6_142.csv',
#  'sector_3_486.csv',
#  'sector_5_450.csv',
#  'sector_6_448.csv',
#  'sector_3_48.csv',
#  'sector_5_332.csv',
#  'sector_1_59.csv',
#  'sector_1_412.csv',
#  'sector_6_442.csv',
#  'sector_1_397.csv',
#  'sector_5_296.csv',
#  'sector_6_459.csv',
#  'sector_2_67.csv',
#  'sector_2_2.csv',
#  'sector_6_302.csv',
#  'sector_1_109.csv',
#  'sector_3_147.csv',
#  'sector_5_155.csv',
#  'sector_6_108.csv',
#  'sector_2_332.csv',
#  'sector_3_400.csv',
#  'sector_2_245.csv',
#  'sector_2_390.csv',
#  'sector_1_305.csv',
#  'sector_1_180.csv',
#  'sector_1_44.csv',
#  'sector_1_455.csv',
#  'sector_1_185.csv',
#  'sector_3_16.csv',
#  'sector_6_378.csv',
#  'sector_1_257.csv',
#  'sector_4_438.csv',
#  'sector_4_7.csv',
#  'sector_4_232.csv',
#  'sector_5_471.csv',
#  'sector_1_175.csv',
#  'sector_5_293.csv',
#  'sector_1_478.csv',
#  'sector_5_107.csv',
#  'sector_2_475.csv',
#  'sector_6_255.csv',
#  'sector_6_486.csv',
#  'sector_3_266.csv',
#  'sector_1_391.csv',
#  'sector_2_322.csv',
#  'sector_3_322.csv',
#  'sector_5_77.csv',
#  'sector_2_93.csv',
#  'sector_6_35.csv',
#  'sector_1_126.csv',
#  'sector_3_277.csv',
#  'sector_5_303.csv',
#  'sector_1_164.csv',
#  'sector_4_20.csv',
#  'sector_3_208.csv',
#  'sector_2_304.csv',
#  'sector_2_349.csv',
#  'sector_4_74.csv',
#  'sector_5_245.csv',
#  'sector_4_34.csv',
#  'sector_5_48.csv',
#  'sector_4_296.csv',
#  'sector_4_124.csv',
#  'sector_5_145.csv',
#  'sector_6_136.csv',
#  'sector_4_176.csv',
#  'sector_3_294.csv',
#  'sector_3_211.csv',
#  'sector_6_190.csv',
#  'sector_2_153.csv',
#  'sector_2_227.csv',
#  'sector_6_244.csv',
#  'sector_5_19.csv',
#  'sector_3_113.csv',
#  'sector_4_44.csv',
#  'sector_1_323.csv',
#  'sector_4_38.csv',
#  'sector_2_154.csv',
#  'sector_3_159.csv',
#  'sector_4_1.csv',
#  'sector_6_362.csv',
#  'sector_3_358.csv',
#  'sector_6_84.csv',
#  'sector_5_202.csv',
#  'sector_2_18.csv',
#  'sector_2_92.csv',
#  'sector_5_137.csv',
#  'sector_1_140.csv',
#  'sector_5_323.csv',
#  'sector_3_117.csv',
#  'sector_2_87.csv',
#  'sector_3_204.csv',
#  'sector_4_294.csv',
#  'sector_4_179.csv',
#  'sector_4_321.csv',
#  'sector_6_400.csv',
#  'sector_5_90.csv',
#  'sector_3_467.csv',
#  'sector_4_459.csv',
#  'sector_2_109.csv',
#  'sector_6_352.csv',
#  'sector_2_496.csv',
#  'sector_1_338.csv',
#  'sector_1_177.csv',
#  'sector_6_139.csv',
#  'sector_2_293.csv',
#  'sector_4_240.csv',
#  'sector_3_388.csv',
#  'sector_4_11.csv',
#  'sector_2_317.csv',
#  'sector_3_426.csv',
#  'sector_3_36.csv',
#  'sector_3_424.csv',
#  'sector_3_101.csv',
#  'sector_4_80.csv',
#  'sector_2_329.csv',
#  'sector_3_150.csv',
#  'sector_2_96.csv',
#  'sector_1_192.csv',
#  'sector_1_268.csv',
#  'sector_1_389.csv',
#  'sector_5_464.csv',
#  'sector_4_217.csv',
#  'sector_6_141.csv',
#  'sector_1_249.csv',
#  'sector_2_255.csv',
#  'sector_6_258.csv',
#  'sector_5_502.csv',
#  'sector_1_75.csv',
#  'sector_5_95.csv',
#  'sector_3_275.csv',
#  'sector_2_375.csv',
#  'sector_1_234.csv',
#  'sector_5_126.csv',
#  'sector_4_483.csv',
#  'sector_1_57.csv',
#  'sector_4_304.csv',
#  'sector_6_326.csv',
#  'sector_6_251.csv',
#  'sector_2_130.csv',
#  'sector_6_56.csv',
#  'sector_5_223.csv',
#  'sector_2_504.csv',
#  'sector_3_191.csv',
#  'sector_1_301.csv',
#  'sector_2_77.csv',
#  'sector_2_60.csv',
#  'sector_2_28.csv',
#  'sector_3_469.csv',
#  'sector_5_343.csv',
#  'sector_3_451.csv',
#  'sector_3_160.csv',
#  'sector_5_496.csv',
#  'sector_6_122.csv',
#  'sector_2_52.csv',
#  'sector_4_160.csv',
#  'sector_5_418.csv',
#  'sector_1_184.csv',
#  'sector_6_48.csv',
#  'sector_2_426.csv',
#  'sector_6_344.csv',
#  'sector_1_152.csv',
#  'sector_6_287.csv',
#  'sector_3_144.csv',
#  'sector_5_159.csv',
#  'sector_5_46.csv',
#  'sector_4_478.csv',
#  'sector_6_482.csv',
#  'sector_6_7.csv',
#  'sector_3_332.csv',
#  'sector_4_155.csv',
#  'sector_5_437.csv',
#  'sector_4_335.csv',
#  'sector_6_44.csv',
#  'sector_1_46.csv',
#  'sector_1_15.csv',
#  'sector_3_185.csv',
#  'sector_1_392.csv',
#  'sector_5_253.csv',
#  'sector_3_57.csv',
#  'sector_5_101.csv',
#  'sector_5_173.csv',
#  'sector_5_371.csv',
#  'sector_3_170.csv',
#  'sector_2_83.csv',
#  'sector_3_394.csv',
#  'sector_2_418.csv',
#  'sector_5_400.csv',
#  'sector_3_103.csv',
#  'sector_6_95.csv',
#  'sector_3_374.csv',
#  'sector_3_88.csv',
#  'sector_4_332.csv',
#  'sector_2_137.csv',
#  'sector_4_100.csv',
#  'sector_3_134.csv',
#  'sector_1_167.csv',
#  'sector_5_201.csv',
#  'sector_6_324.csv',
#  'sector_4_367.csv',
#  'sector_3_329.csv',
#  'sector_6_184.csv',
#  'sector_3_224.csv',
#  'sector_3_395.csv',
#  'sector_3_408.csv',
#  'sector_2_117.csv',
#  'sector_2_346.csv',
#  'sector_2_386.csv',
#  'sector_1_68.csv',
#  'sector_2_228.csv',
#  'sector_1_302.csv',
#  'sector_5_363.csv',
#  'sector_3_51.csv',
#  'sector_3_460.csv',
#  'sector_4_165.csv',
#  'sector_6_387.csv',
#  'sector_5_33.csv',
#  'sector_1_5.csv',
#  'sector_5_74.csv',
#  'sector_4_506.csv',
#  'sector_6_228.csv',
#  'sector_4_330.csv',
#  'sector_2_184.csv',
#  'sector_4_507.csv',
#  'sector_5_208.csv',
#  'sector_2_259.csv',
#  'sector_5_449.csv',
#  'sector_4_149.csv',
#  'sector_1_34.csv',
#  'sector_5_295.csv',
#  'sector_3_458.csv',
#  'sector_5_36.csv',
#  'sector_1_506.csv',
#  'sector_4_371.csv',
#  'sector_2_282.csv',
#  'sector_6_318.csv',
#  'sector_4_312.csv',
#  'sector_5_261.csv',
#  'sector_4_407.csv',
#  'sector_6_325.csv',
#  'sector_6_217.csv',
#  'sector_5_8.csv',
#  'sector_1_394.csv',
#  'sector_5_266.csv',
#  'sector_5_269.csv',
#  'sector_2_374.csv',
#  'sector_4_228.csv',
#  'sector_1_62.csv',
#  'sector_1_344.csv',
#  'sector_1_7.csv',
#  'sector_3_303.csv',
#  'sector_3_422.csv',
#  'sector_3_428.csv',
#  'sector_4_436.csv',
#  'sector_6_439.csv',
#  'sector_5_505.csv',
#  'sector_4_329.csv',
#  'sector_6_306.csv',
#  'sector_6_313.csv',
#  'sector_6_222.csv',
#  'sector_2_341.csv',
#  'sector_4_63.csv',
#  'sector_6_111.csv',
#  'sector_4_423.csv',
#  'sector_4_39.csv',
#  'sector_5_222.csv',
#  'sector_4_286.csv',
#  'sector_5_207.csv',
#  'sector_2_142.csv',
#  'sector_5_180.csv',
#  'sector_5_501.csv',
#  'sector_4_356.csv',
#  'sector_4_405.csv',
#  'sector_5_185.csv',
#  'sector_4_445.csv',
#  'sector_3_245.csv',
#  'sector_2_62.csv',
#  'sector_6_242.csv',
#  'sector_5_210.csv',
#  'sector_6_342.csv',
#  'sector_6_333.csv',
#  'sector_2_24.csv',
#  'sector_4_194.csv',
#  'sector_5_227.csv',
#  'sector_5_299.csv',
#  'sector_6_372.csv',
#  'sector_2_459.csv',
#  'sector_2_122.csv',
#  'sector_4_166.csv',
#  'sector_5_435.csv',
#  'sector_5_167.csv',
#  'sector_3_363.csv',
#  'sector_1_24.csv',
#  'sector_2_84.csv',
#  'sector_5_22.csv',
#  'sector_6_359.csv',
#  'sector_4_56.csv',
#  'sector_1_89.csv',
#  'sector_4_398.csv',
#  ...]

# %%
results[0,:,:].shape
# Out:
# (240, 512)

# %%
X = results[0,:,:].transpose()
mu = X.mean(axis=0)

# %%
X.shape
# Out:
# (512, 240)

# %%
mu.shape
# Out:
# (240,)

# %%
C = np.matmul((X - mu).transpose(),(X - mu)) / 511

# %%
plt.imshow(C[:25,:25])

# %%
plt.figure(figsize=(12,12))
plt.imshow(C)

# %%
V = np.linalg.inv(C)

# %%
plt.imshow(V[:25,:25])

# %%
plt.plot(mu[:13])

# %%
for _ in range(100):
    plt.plot(np.random.multivariate_normal(mu[:49], C[:49,:49]), 
             linestyle='', marker='o', color='red', alpha=0.2)

# %%
plt.plot(results[0, :49, :], linestyle='',  marker='o', color='red', alpha=0.2);

# %%
counts_pos = np.empty(shape=(6,240,512))
counts_neg = np.empty(shape=(6,240,512))

for sector in range(1, 7):
    for subfile in range(512):
        counts_pos[sector - 1, :, subfile] = data[sector][subfile]['counts_pos']
        counts_neg[sector - 1, :, subfile] = data[sector][subfile]['counts_neg']

# %%
def calculate_mean_covariance(X):
    nrows, ncols = X.shape
    mu = X.mean(axis=0)
    C = np.matmul((X - mu).transpose(), (X - mu)) / (nrows - 1)
    return mu, C

# %%
counts_mu, counts_C = calculate_mean_covariance(counts_pos[0, :, :].transpose())

# %%
counts_mu
# Out:
# array([1900.78710938,  922.625     , 1613.078125  ,  934.35351562,
#         934.41992188,  444.53125   ,  408.07617188,  864.70507812,
#         907.36132812, 1552.55273438,  936.63476562, 1819.515625  ,
#        2040.16796875, 1052.13476562, 1449.23828125, 1128.71679688,
#         785.44140625,  363.80078125,  388.5703125 ,  762.95898438,
#        1118.31640625, 1527.52148438, 1110.10742188, 2050.73828125,
#        2019.65625   , 1189.98046875, 1403.26757812, 1183.64257812,
#         781.37304688,  357.77734375,  341.09179688,  758.359375  ,
#        1277.421875  , 1413.390625  , 1187.23046875, 1921.88867188,
#        2053.34960938, 1243.67773438, 1330.125     , 1254.59375   ,
#         803.96484375,  409.28125   ,  383.45898438,  806.42382812,
#        1330.71679688, 1379.08398438, 1272.74609375, 1984.31445312,
#        2104.02929688, 1407.05859375, 1253.69726562, 1196.6171875 ,
#         786.91796875,  400.50585938,  382.32421875,  824.3515625 ,
#        1264.84179688, 1318.07226562, 1365.26367188, 2099.71875   ,
#        2527.40625   , 1686.01953125, 1971.0546875 , 1513.70117188,
#        1528.70117188, 1045.11132812, 1076.42773438, 1366.15820312,
#        1420.91992188, 2074.93164062, 1728.30078125, 2610.61914062,
#        2689.16015625, 1584.09375   , 2120.54492188, 1538.03125   ,
#        1352.69726562,  697.77929688,  679.1640625 , 1261.96484375,
#        1572.30859375, 2237.79882812, 1666.64257812, 2620.5546875 ,
#        2722.73242188, 1502.13867188, 1998.86914062, 1482.59375   ,
#        1090.11328125,  525.66210938,  483.07617188, 1077.484375  ,
#        1530.32226562, 2069.98046875, 1453.05273438, 2616.015625  ,
#        2400.14257812, 1325.08007812, 1577.02734375, 1324.09765625,
#         813.48242188,  320.2890625 ,  369.359375  ,  846.08007812,
#        1417.32226562, 1576.02929688, 1323.91796875, 2394.59960938,
#        2109.14453125, 1275.24414062, 1193.45703125, 1243.453125  ,
#         726.609375  ,  358.53515625,  324.02148438,  723.515625  ,
#        1275.75      , 1151.10546875, 1303.09960938, 2072.21875   ,
#        2131.2265625 , 1463.21484375, 1183.44335938, 1164.00390625,
#         743.34960938,  485.921875  ,  446.20703125,  713.43164062,
#        1287.36914062, 1183.71289062, 1389.4921875 , 1961.1640625 ,
#        2204.12109375, 1183.40820312, 1335.58203125, 1392.08203125,
#         709.24023438,  189.359375  ,  162.31640625,  735.54296875,
#        1441.64257812, 1383.69726562, 1193.96484375, 2179.43554688,
#        2069.23046875, 1103.8203125 , 1560.88671875, 1210.4296875 ,
#         839.49414062,  358.59765625,  307.44921875,  869.8984375 ,
#        1244.23828125, 1625.02148438, 1126.16015625, 2095.56835938,
#        1943.09570312, 1095.68164062, 1460.59570312, 1063.55859375,
#         901.0390625 ,  452.65820312,  427.84179688,  880.89257812,
#        1055.45703125, 1559.8046875 , 1094.99414062, 1941.04101562,
#        1770.31640625,  969.3515625 , 1508.8984375 ,  867.84960938,
#         898.99414062,  489.359375  ,  559.70703125,  817.03320312,
#         869.95117188, 1438.38476562, 1067.37109375, 1698.96679688,
#        1935.16601562,  886.13085938, 1503.19921875,  947.3671875 ,
#         873.77539062,  426.43945312,  437.16601562,  829.29101562,
#         942.95117188, 1493.50390625,  918.546875  , 1872.43359375,
#        2025.72460938, 1098.28320312, 1412.24414062, 1218.18359375,
#         822.63671875,  414.46484375,  354.16992188,  836.140625  ,
#        1282.52148438, 1422.00195312, 1167.94335938, 1951.23046875,
#        2103.41992188, 1232.72460938, 1473.1328125 , 1231.20117188,
#         847.63476562,  389.67382812,  378.23632812,  827.0859375 ,
#        1252.28515625, 1524.33007812, 1266.09179688, 2082.28710938,
#        2034.42382812, 1279.38867188, 1362.05664062, 1153.73242188,
#         818.6796875 ,  404.06445312,  386.54101562,  810.27148438,
#        1275.74804688, 1453.546875  , 1226.36523438, 1971.609375  ,
#        2019.25585938, 1318.94921875, 1298.7734375 , 1147.43945312,
#         729.390625  ,  341.25390625,  347.40820312,  714.00976562,
#        1145.15234375, 1297.23828125, 1293.03515625, 1998.61523438])

# %%
counts_C
# Out:
# array([[47418.88413879, 20150.30161448, 36142.66050024, ...,
#         13705.16433005, 15684.52217619, 25330.04512827],
#        [20150.30161448,  9092.21526419, 15825.55772994, ...,
#          7093.03669276,  7948.26174168, 12838.77910959],
#        [36142.66050024, 15825.55772994, 28281.0584638 , ...,
#         11674.40404843, 13118.38276663, 21153.52718322],
#        ...,
#        [13705.16433005,  7093.03669276, 11674.40404843, ...,
#          9594.35406984, 10322.86831886, 16768.27777183],
#        [15684.52217619,  7948.26174168, 13118.38276663, ...,
#         10322.86831886, 11473.74044459, 18654.66325985],
#        [25330.04512827, 12838.77910959, 21153.52718322, ...,
#         16768.27777183, 18654.66325985, 30548.78904339]])

# %%
plt.figure(figsize=(12,12))
plt.imshow(counts_C[:12,:12])

# %%
counts_mu[:12]
# Out:
# array([1900.78710938,  922.625     , 1613.078125  ,  934.35351562,
#         934.41992188,  444.53125   ,  408.07617188,  864.70507812,
#         907.36132812, 1552.55273438,  936.63476562, 1819.515625  ])

# %%
plt.plot(np.random.multivariate_normal(counts_mu[:12], counts_C[:12, :12]))

# %%
plt.hist(counts_pos[0, 7, :], bins=np.linspace(600, 1300, 20),
        edgecolor='k');

# %%
plt.hist(counts_pos[0, 7, :], bins=np.linspace(600, 1300, 40),
        edgecolor='k');

# %%
plt.hist(counts_pos[0, 7, :], bins=np.linspace(600, 1300, 60),
        edgecolor='k');

# %%
plt.scatter(counts_pos[0, 0, :], counts_pos[0, 7, :],
           edgecolor='k', marker='o', alpha=0.7)
plt.grid(alpha=0.3)

# %%
plt.scatter(counts_pos[0, 7, :], counts_neg[0, 7, :],
           edgecolor='k', marker='o', alpha=0.7)
plt.grid(alpha=0.3)

# %%
X = np.zeros(shape=(512,2))
X[:,0] = counts_pos[0, 7, :]
X[:,1] = counts_neg[0, 7, :]
point_mu, point_C = calculate_mean_covariance(X)

# %%
point_mu
# Out:
# array([864.70507812, 847.51171875])

# %%
point_C
# Out:
# array([[7011.93829119, 6199.97508715],
#        [6199.97508715, 5613.33058647]])

# %%
np.sqrt(point_C[0,0]), np.sqrt(point_C[1,1])
# Out:
# (83.7373171960245, 74.92216351969958)

# %%
X_sample = np.random.multivariate_normal(point_mu, point_C, 10000)

# %%
plt.scatter(X_sample[:,0], X_sample[:,1], 
           alpha=0.7, edgecolor='k', marker='o')
plt.grid(alpha=0.3)

# %%
def expected_asymmetry(X_samples):
    asym = (X_samples[:,0] - X_samples[:,1]) / (X_samples[:,0] + X_samples[:,1])
    return asym

# %%
asym = expected_asymmetry(X_sample)

# %%
plt.hist(asym, edgecolor='k', bins=np.linspace(-0.1, 0.1, 40));

# %%
plt.hist(results[0, 7, :], edgecolor='k', bins=np.linspace(-0.1, 0.1, 40));
