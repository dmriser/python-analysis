# %% [markdown]
# # About
# This notebook compares methods for fitting the $\phi$ dependence of the beam spin asymmetry using the `phifitter` package.  Results are computed for measurements with systematic errors.

# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd

from phifitter import fitter
from phifitter import loss
from phifitter import physics_model

from statsmodels.tsa.stattools import acf as auto_correlate

# %matplotlib inline
plt.rc('font', size=18)
plt.rc('font', family='serif')

# %%
path_to_data = './results/phi/'
input_filename = 'sys.csv'
compression_type = None
important_cols = ['axis', 'axis_bin', 'axis_min', 'axis_max',
                 'phi', 'exp_val', 'std_dev', 'stat']

# %% [markdown]
# ### Load Dataset
# Dropping columns which aren't used in this analysis.

# %%
data = pd.read_csv(path_to_data+input_filename, compression=compression_type)
data = data[important_cols]

# %% [markdown]
# ### Setup Fitter
# The fitting is setup from `phifitter` package.

# %%
model = physics_model.BeamSpinAsymmetryModel()

# Parameter bounds, these are physically motivated
bounds = [[-1, 1], [-1, 1], [-1, 1]]
x0 = [0.0, 0.0, 0.0]

fitters = {}
fitters['single'] = fitter.SingleFitter(model=model, 
                                        loss_function=loss.chi2, 
                                        bounds=bounds)
fitters['regularized'] = fitter.SingleRegularizedFitter(model=model, 
                                        loss_function=loss.chi2, 
                                        bounds=bounds, 
                                        penalty=0.05)
fitters['replica'] = fitter.ReplicaFitter(model=model, 
                                        loss_function=loss.chi2, 
                                        bounds=bounds,
                                         n_replicas=100, 
                                         n_cores=4)

# flat prior 
def prior(p):
    return 1.0

fitters['bayesian-vegas'] = fitter.BayesianVegasFitter(model=model,
                                                      likelihood=loss.likelihood,
                                                      prior=prior,
                                                      bounds=bounds)

fitters['bayesian-mcmc'] = fitter.BayesianMCMCFitter(model=model,
                                                      likelihood=loss.likelihood,
                                                      prior=prior,
                                                      bounds=bounds,
                                                    n_iterations=4000,
                                                    burn_in=1000)

# %% [markdown]
# ### Split by bin, start fitting
# Here we go.  To start, let's just apply our methods to the z-axis.

# %%
data.query('axis == "z"', inplace=True)

results = {}
for key in fitters.keys():
    results[key] = []
    
for axis_bin in np.unique(data.axis_bin.values):
    print('Starting fit for %d' % axis_bin)
    
    # subset of total data for this bin 
    d = data.query('axis_bin == %d' % axis_bin)
    
    # error = np.sqrt(d.stat**2 + d.std_dev**2)
    error = d.stat
    for name in fitters.keys():
        results[name].append(fitters[name].fit(d.phi.values, d.exp_val.values, error))
# Out:
# Starting fit for 0
# /Users/davidriser/Library/Python/2.7/lib/python/site-packages/phifitter/fitter.py:381: RuntimeWarning: invalid value encountered in double_scalars
#   if np.random.uniform(0,1) < prob_prop/prob:
# Starting fit for 1
# Starting fit for 2
# Starting fit for 3
# Starting fit for 4
# Starting fit for 5
# Starting fit for 6
# Starting fit for 7
# Starting fit for 8
# Starting fit for 9

# %%
for name in results.keys():
    for i, b in enumerate(results[name]):
        print('Method %s, bin %d, loss %.3f, quality %.3f' % 
              (name, i, b.loss, b.quality))
# Out:
# Method bayesian-mcmc, bin 0, loss 1065508.895, quality 0.000
# Method bayesian-mcmc, bin 1, loss 833036.642, quality 0.000
# Method bayesian-mcmc, bin 2, loss 707853.707, quality 0.000
# Method bayesian-mcmc, bin 3, loss 606907.273, quality 0.000
# Method bayesian-mcmc, bin 4, loss 546604.225, quality 0.000
# Method bayesian-mcmc, bin 5, loss 490401.651, quality 0.000
# Method bayesian-mcmc, bin 6, loss 448835.318, quality 0.000
# Method bayesian-mcmc, bin 7, loss 412914.534, quality 0.000
# Method bayesian-mcmc, bin 8, loss 383637.790, quality 0.000
# Method bayesian-mcmc, bin 9, loss 340436.743, quality 0.000
# Method regularized, bin 0, loss 12.030, quality 0.443
# Method regularized, bin 1, loss 6.153, quality 0.908
# Method regularized, bin 2, loss 17.080, quality 0.147
# Method regularized, bin 3, loss 10.627, quality 0.561
# Method regularized, bin 4, loss 38.689, quality 0.000
# Method regularized, bin 5, loss 8.216, quality 0.768
# Method regularized, bin 6, loss 12.274, quality 0.424
# Method regularized, bin 7, loss 29.836, quality 0.003
# Method regularized, bin 8, loss 5.693, quality 0.931
# Method regularized, bin 9, loss 21.176, quality 0.048
# Method single, bin 0, loss 12.030, quality 0.443
# Method single, bin 1, loss 6.153, quality 0.908
# Method single, bin 2, loss 17.080, quality 0.147
# Method single, bin 3, loss 10.627, quality 0.561
# Method single, bin 4, loss 38.689, quality 0.000
# Method single, bin 5, loss 8.216, quality 0.768
# Method single, bin 6, loss 12.274, quality 0.424
# Method single, bin 7, loss 29.836, quality 0.003
# Method single, bin 8, loss 5.693, quality 0.931
# Method single, bin 9, loss 21.176, quality 0.048
# Method replica, bin 0, loss 13.166, quality 0.357
# Method replica, bin 1, loss 6.380, quality 0.896
# Method replica, bin 2, loss 17.126, quality 0.145
# Method replica, bin 3, loss 10.686, quality 0.556
# Method replica, bin 4, loss 39.386, quality 0.000
# Method replica, bin 5, loss 8.398, quality 0.753
# Method replica, bin 6, loss 12.702, quality 0.391
# Method replica, bin 7, loss 30.128, quality 0.003
# Method replica, bin 8, loss 5.707, quality 0.930
# Method replica, bin 9, loss 21.276, quality 0.046
# Method bayesian-vegas, bin 0, loss 12.271, quality 0.000
# Method bayesian-vegas, bin 1, loss 6.308, quality 0.042
# Method bayesian-vegas, bin 2, loss 17.402, quality 0.516
# Method bayesian-vegas, bin 3, loss 10.697, quality 0.000
# Method bayesian-vegas, bin 4, loss 39.714, quality 0.001
# Method bayesian-vegas, bin 5, loss 8.414, quality 0.000
# Method bayesian-vegas, bin 6, loss 12.389, quality 0.035
# Method bayesian-vegas, bin 7, loss 30.283, quality 0.000
# Method bayesian-vegas, bin 8, loss 5.807, quality 0.191
# Method bayesian-vegas, bin 9, loss 21.279, quality 0.002

# %% [markdown]
# ### Quality Control
# Here we need to check convergence metrics for the more complicated methods.

# %%
def plot_mcmc_auto_correlation(results, bin_index):
    
    
    fig = plt.figure(figsize=(30, 7))
    
    ax = fig.add_subplot(131)
    ax.plot(auto_correlate(results[bin_index].samples[:,0], nlags=100))    

    ax = fig.add_subplot(132)
    ax.plot(auto_correlate(results[bin_index].samples[:,1], nlags=100))    

    ax = fig.add_subplot(133)
    ax.plot(auto_correlate(results[bin_index].samples[:,2], nlags=100))    

    fig.tight_layout()

# %%
def plot_mcmc_trace(results, bin_index):

    fig = plt.figure(figsize=(30, 7))
    
    ax = fig.add_subplot(131)
    ax.plot(results[bin_index].samples[:,0])    
    ax = fig.add_subplot(132)
    ax.plot(results[bin_index].samples[:,1])    
    ax = fig.add_subplot(133)
    ax.plot(results[bin_index].samples[:,2])
    
    fig.tight_layout()

# %%
plot_mcmc_trace(results['bayesian-mcmc'], 2)

# %%
plot_mcmc_auto_correlation(results['bayesian-mcmc'], 2)
# Out:
# /Users/davidriser/Library/Python/2.7/lib/python/site-packages/statsmodels/tsa/stattools.py:476: RuntimeWarning: invalid value encountered in divide
#   acf = avf[:nlags + 1] / avf[0]

# %% [markdown]
# ### Analysis of Results
# Build the z-dependent results for each method and compare visually for each parameter.

# %%
x    = np.unique( data.axis_min + 0.5 * (data.axis_max - data.axis_min) )
y    = np.zeros( (len(fitters.keys()), len(x), 3) )
yerr = np.zeros( (len(fitters.keys()), len(x), 3) )

# Indexing Scheme 
# [method, bin, parameter]
for i, name in enumerate(results.keys()):
    for j, r in enumerate(results[name]):
        y[i,j,0] = results[name][j].fit_parameters[0] 
        y[i,j,1] = results[name][j].fit_parameters[1] 
        y[i,j,2] = results[name][j].fit_parameters[2] 
        
        yerr[i,j,0] = results[name][j].fit_errors[0] 
        yerr[i,j,1] = results[name][j].fit_errors[1] 
        yerr[i,j,2] = results[name][j].fit_errors[2]

# %%
fig = plt.figure(figsize=(16,9))
ax = fig.add_subplot(111)

#for index, name in enumerate(results.keys()):
for index, name in enumerate(['bayesian-mcmc', 'bayesian-vegas']):
    ax.errorbar(x, y[index,:,0], yerr[index,:,0], 
                 linestyle='', marker='.', label=name)

ax.set_ylim([-0.2, 0.2])
ax.set_xlim([0, 1])
ax.legend(frameon=False)

# %%
fig = plt.figure(figsize=(16,9))
ax = fig.add_subplot(111)

for index, name in enumerate(results.keys()):
    ax.errorbar(x, y[index,:,1], yerr[index,:,1], 
                 linestyle='', marker='.', label=name)

ax.set_ylim([-1, 1])
ax.set_xlim([0, 1])
ax.legend(frameon=False)

# %%
fig = plt.figure(figsize=(16,9))
ax = fig.add_subplot(111)

for index, name in enumerate(results.keys()):
    ax.errorbar(x, y[index,:,2], yerr[index,:,2], 
                 linestyle='', marker='.', label=name)

ax.set_ylim([-1, 1])
ax.set_xlim([0, 1])
ax.legend(frameon=False)
