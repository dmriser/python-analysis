# %% [markdown]
# # Systematics Notebook
# From results of the phi fitting.  Before running this notebook the output from `src/fit/run-fitter.py` is needed.

# %%
import glob 
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
import pickle
import sys
import time 

# %matplotlib inline

plt.rc('font', family='serif')
plt.rc('font', size=18)

# %% [markdown]
# ### Load Configurations
# There are several files with different results for phi-distributions.

# %%
database_files = glob.glob('database/fit/*.csv')
print('Found %d files in the database.' % len(database_files))
# Out:
# Found 25 files in the database.

# %%
def load_database_files(file_list):
    
    dataframe_store = {}
    for f in file_list:
        dataframe_store[f] = pd.read_csv(f)
        
    return dataframe_store

# %%
dataframe_store = load_database_files(database_files)

# %% [markdown]
# Finally, fit the nominal phi distributions.

# %%
nominal = pd.read_csv('database/fit/sys.csv')

# %% [markdown]
# ### Systematic Uncertainties

# %%
def database_filename_parser(file_name):
    file_name = file_name.split('variation_')[-1].strip('.csv')
    
    tokens = file_name.split('_')
    n_tokens = len(tokens)

    parameter_name = '_'.join(tokens[0:n_tokens-1])
    index = int(tokens[-1])
    
    return index, parameter_name

# %%
def build_parameter_variation_dict(path_to_db = 'database/fit/'):

    parameters = {}

    database_files = glob.glob(path_to_db + 'variation*.csv')
    
    for database_file in database_files:
        index, parameter = database_filename_parser(database_file)
        
        if parameter in parameters.keys():
            parameters[parameter][index] = pd.read_csv(database_file)
        else:
            parameters[parameter] = {}
            parameters[parameter][index] = pd.read_csv(database_file)
            
    return parameters

# %%
def load_systematic_sources_list(file_name):
    systematic_sources = pickle.load(open(file_name, 'rb'))
    
    reverse_dict = {}

    for key, value in systematic_sources.iteritems():
        reverse_dict[value] = key
    
    return reverse_dict

# %%
parameter_variation = build_parameter_variation_dict()

# %%
for key, value in parameter_variation.iteritems():
    print(key, value.keys())
# Out:
# ('dist_dcr3', [1, -1])
# ('dist_dcr1', [1, -1])
# ('dist_vz', [1, -1])
# ('dist_cc', [0, -1])
# ('dist_ec_edep', [1, -1])
# ('dist_ecsf', [1, -1])
# ('p_mes', [0, -1])
# ('alpha', [1, -1])
# ('missing_mass', [1, -1])
# ('dist_ecu', [1, -1])
# ('dist_ecw', [1, -1])
# ('dist_ecv', [1, -1])

# %%
systematic_sources = load_systematic_sources_list('systematic_sources.pkl')

# %%
def add_systematics(nominal_fit, parameter_variation, systematic_sources):

    nominal_fit_sys = nominal_fit.copy(deep=True)
    nominal_fit_sys['sys_total_0'] = np.zeros(len(nominal_fit_sys))
    nominal_fit_sys['sys_total_1'] = np.zeros(len(nominal_fit_sys))
    nominal_fit_sys['sys_total_2'] = np.zeros(len(nominal_fit_sys))
    
    for key in parameter_variation.keys():

        min_index = parameter_variation[key].keys()[0]    
        max_index = parameter_variation[key].keys()[-1]

        merged_data = pd.merge(parameter_variation[key][min_index], 
                 parameter_variation[key][max_index],
                 on = ['axis', 'axis_bin'])

        merged_data[systematic_sources[key] + '_par0'] = np.abs(merged_data.par_0_y - merged_data.par_0_x)
        merged_data[systematic_sources[key] + '_par1'] = np.abs(merged_data.par_1_y - merged_data.par_1_x)
        merged_data[systematic_sources[key] + '_par2'] = np.abs(merged_data.par_2_y - merged_data.par_2_x)

        merge_cols = ['axis', 'axis_bin', systematic_sources[key] + '_par0', 
                     systematic_sources[key] + '_par1', systematic_sources[key] + '_par2']

        nominal_fit_sys = pd.merge(nominal_fit_sys, merged_data[merge_cols], 
                                   on = ['axis', 'axis_bin'])
    
        nominal_fit_sys.sys_total_0 += nominal_fit_sys[systematic_sources[key] + '_par0']**2
        nominal_fit_sys.sys_total_1 += nominal_fit_sys[systematic_sources[key] + '_par1']**2
        nominal_fit_sys.sys_total_2 += nominal_fit_sys[systematic_sources[key] + '_par2']**2


    nominal_fit_sys.sys_total_0 = np.sqrt(nominal_fit_sys.sys_total_0)
    nominal_fit_sys.sys_total_1 = np.sqrt(nominal_fit_sys.sys_total_1)
    nominal_fit_sys.sys_total_2 = np.sqrt(nominal_fit_sys.sys_total_2)

    
    return nominal_fit_sys

# %%
nominal_fit_sys = add_systematics(nominal, parameter_variation, systematic_sources)

# %%
nominal_fit_sys.to_csv('results/fit/sys.csv', index=False)

# %%
nominal_fit_sys.head(24)
# Out:
#    axis  axis_bin  axis_max  axis_min     err_0     err_1     err_2     par_0  \
# 0    pt         0  0.202108  0.000284  0.005192  0.431005  0.505917  0.022703
# 1    pt         1  0.274544  0.202108  0.006773  0.411621  0.516845  0.026350
# 2    pt         2  0.328453  0.274544  0.007233  0.398686  0.426705  0.029421
# 3    pt         3  0.376169  0.328453  0.004955  0.391704  0.433300  0.034144
# 4    pt         4  0.422123  0.376169  0.008203  0.393624  0.487244  0.033847
# 5    pt         5  0.469541  0.422123  0.004816  0.402747  0.448046  0.032313
# 6    pt         6  0.521940  0.469541  0.007372  0.458481  0.459750  0.033803
# 7    pt         7  0.585257  0.521940  0.007066  0.389036  0.420212  0.034461
# 8    pt         8  0.674587  0.585257  0.006881  0.437974  0.536124  0.030766
# 9    pt         9  1.193084  0.674587  0.004335  0.435679  0.574297  0.019302
# 10   q2         0  1.173185  1.000001  0.005258  0.431993  0.412506  0.027022
# 11   q2         1  1.299205  1.173185  0.007981  0.442147  0.371594  0.031064
# 12   q2         2  1.416112  1.299205  0.006072  0.420441  0.526877  0.025280
# 13   q2         3  1.539892  1.416112  0.006164  0.441267  0.503321  0.027895
# 14   q2         4  1.679987  1.539892  0.006880  0.404844  0.518084  0.030168
# 15   q2         5  1.845621  1.679987  0.007768  0.450292  0.566626  0.029007
# 16   q2         6  2.051025  1.845621  0.007519  0.395451  0.515553  0.032842
# 17   q2         7  2.321366  2.051025  0.005424  0.389667  0.514889  0.027149
# 18   q2         8  2.734286  2.321366  0.005659  0.375773  0.451900  0.034937
# 19   q2         9  4.736822  2.734286  0.006191  0.397180  0.573547  0.029265
# 20    x         0  0.143282  0.106729  0.005770  0.500472  0.448280  0.022170
# 21    x         1  0.166495  0.143282  0.005966  0.392808  0.464191  0.022025
# 22    x         2  0.188544  0.166495  0.006648  0.377482  0.432971  0.036441
# 23    x         3  0.210731  0.188544  0.007813  0.440037  0.353965  0.031011
#
#        par_1     par_2     ...       sys_9_par2  sys_10_par0  sys_10_par1  \
# 0   0.035135 -0.305324     ...         0.020970     0.001066     0.023424
# 1  -0.458140 -0.025374     ...         0.014380     0.003295     0.019527
# 2   0.124094 -0.404097     ...         0.079441     0.000041     0.003665
# 3  -0.101711 -0.217505     ...         0.054347     0.000823     0.029208
# 4   0.041822 -0.339520     ...         0.075260     0.002379     0.097317
# 5  -0.295824 -0.189819     ...         0.038299     0.000583     0.125574
# 6   0.232640 -0.322405     ...         0.116290     0.001793     0.024666
# 7  -0.161264 -0.342975     ...         0.120403     0.002917     0.050213
# 8  -0.224303 -0.281907     ...         0.052712     0.005665     0.050647
# 9  -0.421409 -0.096595     ...         0.054196     0.000925     0.059188
# 10 -0.053730 -0.323816     ...         0.040261     0.002998     0.097415
# 11 -0.055720 -0.535436     ...         0.098996     0.003344     0.054628
# 12 -0.326313 -0.125472     ...         0.077897     0.000930     0.039112
# 13 -0.155919 -0.271254     ...         0.106417     0.000172     0.012205
# 14 -0.275725 -0.174943     ...         0.036916     0.000249     0.039253
# 15 -0.193470 -0.166516     ...         0.049414     0.000487     0.000772
# 16  0.006046 -0.281213     ...         0.003453     0.000627     0.027300
# 17 -0.212187 -0.215802     ...         0.015086     0.000817     0.101068
# 18 -0.026142 -0.246229     ...         0.085518     0.000328     0.069252
# 19  0.097902 -0.063219     ...         0.121442     0.001655     0.071213
# 20 -0.197135 -0.342679     ...         0.055100     0.001077     0.004810
# 21  0.008030 -0.377980     ...         0.039279     0.002133     0.054781
# 22 -0.213804 -0.284053     ...         0.040687     0.002717     0.010849
# 23 -0.210708 -0.533278     ...         0.007820     0.003303     0.003286
#
#     sys_10_par2  sys_5_par0  sys_5_par1  sys_5_par2  sys_12_par0  sys_12_par1  \
# 0      0.028128    0.000956    0.056018    0.037605     0.001519     0.047335
# 1      0.193278    0.001348    0.049193    0.031217     0.000926     0.000289
# 2      0.031996    0.000028    0.110571    0.024419     0.000715     0.010407
# 3      0.015899    0.000635    0.094364    0.016297     0.002553     0.067756
# 4      0.007849    0.000967    0.063191    0.009643     0.001310     0.004947
# 5      0.043258    0.000462    0.031886    0.086002     0.000874     0.004168
# 6      0.001540    0.000721    0.024062    0.107650     0.000565     0.087564
# 7      0.040496    0.000481    0.026368    0.027694     0.002617     0.006996
# 8      0.197729    0.002875    0.008774    0.118567     0.000760     0.063589
# 9      0.002949    0.000314    0.141209    0.071060     0.001399     0.022375
# 10     0.161513    0.003073    0.015720    0.105509     0.002847     0.170673
# 11     0.028904    0.000182    0.049402    0.105634     0.005100     0.065385
# 12     0.099080    0.001348    0.016509    0.032172     0.000124     0.046534
# 13     0.042291    0.003337    0.057516    0.104348     0.002389     0.106600
# 14     0.052275    0.000956    0.175153    0.139203     0.000277     0.042532
# 15     0.082334    0.001168    0.031805    0.059858     0.001773     0.007208
# 16     0.051078    0.000848    0.000666    0.061456     0.001510     0.071332
# 17     0.068238    0.000626    0.128163    0.012175     0.001162     0.001128
# 18     0.063168    0.000419    0.051269    0.044074     0.000359     0.025178
# 19     0.011711    0.000039    0.036239    0.002647     0.000040     0.005055
# 20     0.022803    0.002023    0.095204    0.027878     0.000842     0.156939
# 21     0.015531    0.001993    0.010815    0.220941     0.003025     0.023019
# 22     0.153858    0.000666    0.044086    0.031236     0.001981     0.001558
# 23     0.022600    0.001956    0.032355    0.042517     0.002905     0.074440
#
#     sys_12_par2
# 0      0.025574
# 1      0.018729
# 2      0.043842
# 3      0.016653
# 4      0.059945
# 5      0.084696
# 6      0.008329
# 7      0.031045
# 8      0.027354
# 9      0.146348
# 10     0.043387
# 11     0.156772
# 12     0.060392
# 13     0.124930
# 14     0.044270
# 15     0.026215
# 16     0.022542
# 17     0.016843
# 18     0.044322
# 19     0.039559
# 20     0.041519
# 21     0.044024
# 22     0.158863
# 23     0.051179
#
# [24 rows x 49 columns]
